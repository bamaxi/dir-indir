# %%
import re
from pathlib import Path
from collections import namedtuple
from itertools import chain
from typing import List, Tuple, Dict, Union, Optional

import bs4
from bs4 import BeautifulSoup as Soup
import pandas as pd
from pprint import pprint

from tqdm.auto import tqdm

# %%
Feats = Dict[str, str]
WordDict = Dict[str, Union[str, Feats]]

# %%
SYNTAGRUS_DIR = './syntagrus/syntagrus/syntagrus2020'
PARSER = 'lxml-xml'

syntagrus_dir = Path(SYNTAGRUS_DIR)

# %%
files = list(syntagrus_dir.glob('**/*.tgt'))

# %%
desired_cols = [
    'sent_num_file', 'left_context', 'text', 'right_context',
        'full_analysis', 'sent_pos_chain',
    'has_many_dos', 'has_many_ios',     # whether sentence has many objs with same deprel
    'has_nodetype_in_our_forms', 
    'verb_inf', 'verb',
    'verb_feats',                       # full verb features string
    'verb_has_neg',                     # binary: 1 - there is a "ne", 0 - there isn't
    'DO_group', 'IO_group',             # full NPs/PPs
        'DO_had_appos', 'IO_had_appos',
        'DO_has_relcl', 'IO_has_relcl',
            'DO_has_wh_relcl', 'IO_has_wh_relcl',
            'DO_has_participle', 'IO_has_participle',
    'DO_depth', 'IO_depth',
    'DO_length', 'IO_length', 
    'DO_pos_feat_chain', 'IO_pos_feat_chain',
    'DO',                               # word forms
    'DO_pos', 'DO_lemma',    
        'DO_animacy', 'DO_case',
        'DO_number',
    'IO',
    'IO_pos', 'IO_head', 'IO_head_pos', 'IO_lemma',
        'IO_animacy', 'IO_case',
        'IO_number',
    'order',                            # in terms of V/IO/DO
    ]
Res = namedtuple('res', desired_cols)

# %%
PRON_STR = (
    'я мы ты вы он она оно они '
    'себя '
    'свой мой наш твой ваш его её их '
    'кто что где откуда зачем когда сколько какой чей который каковой каков '
    'то тот этот столько такой таков сей оный '
    'всяк всякий каждый сам самый любой иной другой весь все '
    'никто ничто некого нечего нигде ниоткуда неоткуда незачем никогда нисколько никакой ничей '
    'некто нечто некий некоторый несколько '
)

PRONS = set(PRON_STR.split())


PRON_ONLY_MODIFIER_STR = 'кое- -либо -нибудь -то было'
PRON_ONLY_MODIFIERS = set(PRON_ONLY_MODIFIER_STR.split())

# %%
lemmas = 'кто бы то ни было, кое-кто, кому-нибудь, что-то, что-либо, кем бы то ни было, былое, коек, либонуть'

for lemma in lemmas.split(','):
    has_modif = any(re.search(rf'\b{modif}\b', lemma) for modif in PRON_ONLY_MODIFIERS)
    print(f'{lemma} {has_modif}')
# Out:
# кто бы то ни было True
#  кое-кто True
#  кому-нибудь True
#  что-то True
#  что-либо True
#  кем бы то ни было True
#  былое False
#  коек False
#  либонуть False

# %%
PRON_STR
# Out:
# 'я мы ты вы он она оно они себя свой мой наш твой ваш его её их кто что где откуда зачем когда сколько какой чей который каковой каков то тот этот столько такой таков сей оный всяк всякий каждый сам самый любой иной другой весь все никто ничто некого нечего нигде ниоткуда неоткуда незачем никогда нисколько никакой ничей некто нечто некий некоторый несколько '

# %%
common_features = {
    'is_composite': 'сл',
}

nominal_features = {
    'gender': 'муж жен сред',
    'number': 'ед мн',
    'case': 'им род парт дат вин твор пр местн зв',
    'animacy': 'неод од',
}

adjectival_features = {
    'brevity': 'кр',
}

comparative_features = {
    'comp_type': 'смяг',
    'comp': 'срав прев',
}

verb_format = {
    'representation': 'инф прич деепр',
    'mood': 'изъяв пов',
    'aspect': 'несов сов',
    'tense': 'непрош прош наст',
    'person': '1-л 2-л 3-л',
    'voice': 'страд',
    **adjectival_features,
    **nominal_features,
}

noun_format = {
    **nominal_features,
}

adjective_format = {
    **comparative_features,
    **adjectival_features,
    **nominal_features
}

adverb_format = {
    **comparative_features,
}

numeral_format = {
    **nominal_features
}

def get_pos_to_feats_format():
    pos_to_feats_format = {
        'V': dict(verb_format), 'S': dict(noun_format), 'A': dict(adjective_format),
        'ADV': dict(adverb_format), 'NUM': dict(numeral_format), 'COM': {},
    }
    
    for pos in pos_to_feats_format.keys():
        pos_to_feats_format[pos].update(common_features)

    
    for pos, pos_format in pos_to_feats_format.items():
        for param, values in pos_format.items():
            pos_format[param] = values.split()
            
    return pos_to_feats_format

# %%
def is_sentence_with_accdo_io(
    tag: bs4.element.Tag,
    first_object_possible_roles: List[str] = ['1-компл'],
    second_object_possible_roles: List[str] = ['2-компл'],
) -> bool:
    is_sentence = tag.name == 'S'
    if not is_sentence:
        return False
    
    sent_str = str(tag)
    
    first_object_rel_str = (
        f'{first_object_possible_roles[0]}' if len(first_object_possible_roles) == 1
        else '(?:{})'.format('|'.join(second_object_possible_roles))
    )
    
    first_object_pat = re.compile(
        rf'^<W DOM=".*" FEAT="(?:\w+ )*?ВИН(?: \w+)*?".*LINK="{first_object_rel_str}">.*?$',
        re.MULTILINE
    )
    first_object = re.search(
        first_object_pat,
        sent_str)
    if not first_object:
        return False
    
    second_object_rel_str = (
        f'{second_object_possible_roles[0]}' if len(second_object_possible_roles) == 1
        else '(?:{})'.format('|'.join(second_object_possible_roles))
    )
    second_object = re.search(rf'LINK="{second_object_rel_str}"', sent_str)
    if not second_object:
        return False
    else:
        return True

# %%
def get_soup(filename: Path) -> bs4.BeautifulSoup:
    with open(filename, 'r', encoding='utf-8') as f:
        text = f.read()
        soup = Soup(text, PARSER)
    
    return soup

# %%
def find_sentences_do_io(
    body: bs4.element.Tag,
    is_sentence_with_do_io_kwargs = {}
) -> List[bs4.element.Tag]:
    
    sents = body.find_all(
        lambda tag: is_sentence_with_accdo_io(tag, **is_sentence_with_do_io_kwargs),
        recursive=False
    )
    
    return sents

# %%
file = syntagrus_dir / Path('2019/baden-baden.tgt')

# %%
file_soup = get_soup(file).find('body')

# %%
sents = file_soup.find_all('S')

# %%
ss = find_sentences_do_io(file_soup)

# %%
ss
# Out:
# [<S ID="9">
#  <W DOM="2" FEAT="S ЕД МУЖ ИМ ОД" ID="1" KSNAME="ОН" LEMMA="ОН" LINK="предик">Он</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="2" LEMMA="ЧУВСТВОВАТЬ">чувствовал</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ВИН ОД" ID="3" LEMMA="СЕБЯ" LINK="1-компл">себя</W>
#  <W DOM="2" FEAT="ADV" ID="4" LEMMA="ЗДЕСЬ" LINK="обст">здесь</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ТВОР ОД" ID="5" KSNAME="РУССКИЙ2" LEMMA="РУССКИЙ" LINK="2-компл">русским</W>,
#  <W DOM="5" FEAT="V СОВ СТРАД ПРИЧ ПРОШ ЕД МУЖ ТВОР" ID="6" LEMMA="ТЕРЯТЬ" LINK="опред">потерянным</W>
#  <W DOM="6" FEAT="CONJ" ID="7" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="7" FEAT="V СОВ СТРАД ПРИЧ ПРОШ ЕД МУЖ ТВОР" ID="8" KSNAME="ОТРЫВАТЬ1" LEMMA="ОТРЫВАТЬ" LINK="соч-союзн">оторванным</W>
#  <W DOM="8" FEAT="PR" ID="9" LEMMA="ОТ" LINK="2-компл">от</W>
#  <W DOM="9" FEAT="S МН МУЖ РОД НЕОД" ID="10" LEMMA="КОРЕНЬ" LINK="предл">корней</W>…
#  </S>,
#  <S ID="10">
#  <W DOM="2" FEAT="A ЕД СРЕД ИМ" ID="1" KSNAME="ЭТОТ" LEMMA="ЭТОТ" LINK="опред">Это</W>
#  <W DOM="6" FEAT="S ЕД СРЕД ИМ НЕОД" ID="2" LEMMA="ЧУВСТВО" LINK="предик">чувство</W>
#  <W DOM="2" FEAT="S ЕД СРЕД РОД НЕОД" ID="3" LEMMA="РОДСТВО" LINK="1-компл">родства</W>
#  <W DOM="3" FEAT="PR" ID="4" KSNAME="С3" LEMMA="С" LINK="1-компл">с</W>
#  <W DOM="4" FEAT="S ЕД МУЖ ТВОР ОД" ID="5" KSNAME="НЕГО1" LEMMA="ОН" LINK="предл">ним</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="6" KSNAME="ДАВАТЬ1" LEMMA="ДАВАТЬ">дает</W>
#  <W DOM="6" FEAT="S ЕД ЖЕН ДАТ ОД" ID="7" LEMMA="Я" LINK="2-компл">мне</W>
#  <W DOM="6" FEAT="S МН ЖЕН ВИН НЕОД" ID="8" LEMMA="СИЛА" LINK="1-компл">силы</W>
#  <W DOM="8" FEAT="V НЕСОВ ИНФ" ID="9" LEMMA="ЖИТЬ" LINK="1-компл">жить</W>
#  <W DOM="9" FEAT="ADV" ID="10" LEMMA="ЗДЕСЬ" LINK="1-компл">здесь</W>.
#  </S>,
#  <S ID="14">
#  <W DOM="2" FEAT="ADV" ID="1" LEMMA="НАКОНЕЦ" LINK="вводн">Наконец</W>,
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="2" LEMMA="ПРЕКЛОНЯТЬ">преклоняет</W>
#  <W DOM="4" FEAT="A МН ВИН НЕОД" ID="3" LEMMA="СВОЙ" LINK="опред">свои</W>
#  <W DOM="2" FEAT="S МН ЖЕН ВИН НЕОД" ID="4" LEMMA="ВЕТВЬ" LINK="1-компл">ветви</W>
#  <W DOM="2" FEAT="PR" ID="5" LEMMA="К" LINK="обст">к</W>
#  <W DOM="5" FEAT="S ЕД ЖЕН ДАТ НЕОД" ID="6" LEMMA="ВОДА" LINK="предл">воде</W>
#  <W DOM="9" FEAT="A ЕД ЖЕН ИМ" ID="7" LEMMA="РОЗОВЫЙ" LINK="опред">розовая</W>
#  <W DOM="9" FEAT="A ЕД ЖЕН ИМ" ID="8" LEMMA="МАХРОВЫЙ" LINK="опред">махровая</W>
#  <W DOM="2" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="9" LEMMA="САКУРА" LINK="предик">сакура</W>,
#  <W DOM="2" FEAT="CONJ" ID="10" KSNAME="И1" LEMMA="И" LINK="сент-соч">и</W>
#  <W DOM="12" FEAT="A МН ИМ" ID="11" KSNAME="ВЕСЬ" LEMMA="ВЕСЬ" LINK="опред">все</W>
#  <W DOM="14" FEAT="S МН СРЕД ИМ НЕОД" ID="12" KSNAME="ДЕРЕВО1" LEMMA="ДЕРЕВО" LINK="предик">деревья</W>
#  <W DOM="12" FEAT="ADV" ID="13" KSNAME="ВОКРУГ2" LEMMA="ВОКРУГ" LINK="атриб">вокруг</W>
#  <W DOM="10" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="14" LEMMA="ПРЕВРАЩАТЬСЯ" LINK="соч-союзн">превращаются</W>
#  <W DOM="14" FEAT="PR" ID="15" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="18" FEAT="A МН ВИН НЕОД" ID="16" LEMMA="ОГРОМНЫЙ" LINK="опред">огромные</W>
#  <W DOM="18" FEAT="A МН ВИН НЕОД" ID="17" LEMMA="БЕЛОСНЕЖНЫЙ" LINK="опред">белоснежные</W>
#  <W DOM="15" FEAT="S МН МУЖ ВИН НЕОД" ID="18" LEMMA="КОРАЛЛ" LINK="предл">кораллы</W>…
#  </S>,
#  <S ID="19">
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="1" LEMMA="ПОЯВЛЯТЬСЯ">Появляется</W>
#  <W DOM="3" FEAT="A ЕД ЖЕН ИМ" ID="2" LEMMA="РАЗНООБРАЗНЫЙ" LINK="опред">разнообразная</W>
#  <W DOM="1" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="3" LEMMA="ПУБЛИКА" LINK="предик">публика</W>,
#  <W DOM="3" FEAT="V НЕСОВ ПРИЧ НЕПРОШ ЕД ЖЕН ИМ" ID="4" LEMMA="ЗАПОЛНЯТЬ" LINK="опред">заполняющая</W>
#  <W DOM="4" FEAT="S ЕД МУЖ ТВОР ОД" ID="5" LEMMA="СЕБЯ" LINK="2-компл">собой</W>
#  <W DOM="4" FEAT="S МН ЖЕН ВИН НЕОД" ID="6" LEMMA="АЛЛЕЯ" LINK="1-компл">аллеи</W>
#  <W DOM="6" FEAT="S МН МУЖ РОД НЕОД" ID="7" LEMMA="ПАРК" LINK="атриб">парков</W>.
#  </S>,
#  <S ID="38">
#  <W DOM="2" FEAT="S ЕД ЖЕН ИМ ОД" ID="1" LEMMA="Я" LINK="предик">Я</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="2" LEMMA="ДОПОЛНЯТЬ">дополнила</W>
#  <W DOM="2" FEAT="S ЕД ЖЕН ВИН ОД" ID="3" LEMMA="ОНА" LINK="1-компл">ее</W>
#  <W DOM="5" FEAT="NUM ТВОР" ID="4" KSNAME="НЕСКОЛЬКО1" LEMMA="НЕСКОЛЬКО" LINK="количест">несколькими</W>
#  <W DOM="2" FEAT="S МН ЖЕН ТВОР НЕОД" ID="5" LEMMA="КАРТИНА" LINK="2-компл">картинами</W>:
#  "<W DOM="7" FEAT="A ЕД ЖЕН ИМ" ID="6" LEMMA="БЕЛЫЙ" LINK="опред">Белая</W>
#  <W DOM="5" FEAT="S ЕД ЖЕН ИМ ОД" ID="7" LEMMA="ЛОШАДЬ" LINK="разъяснит">лошадь</W>",
#  "<W DOM="7" FEAT="S ЕД МУЖ ИМ ОД" ID="8" KSNAME="ЛЕВ1" LEMMA="ЛЕВ" LINK="сочин">Лев</W>
#  <W DOM="8" FEAT="CONJ" ID="9" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="9" FEAT="S ЕД МУЖ ИМ ОД" ID="10" LEMMA="ВОЛК" LINK="соч-союзн">волк</W>"
#  <W DOM="8" FEAT="CONJ" ID="11" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  "<W DOM="11" FEAT="S ЕД СРЕД ИМ НЕОД" ID="12" LEMMA="ПОХИЩЕНИЕ" LINK="соч-союзн">Похищение</W>
#  <W DOM="12" FEAT="S ЕД ЖЕН РОД НЕОД" ID="13" LEMMA="ЕВРОПА" LINK="1-компл">Европы</W>"
#  <W DOM="7" FEAT="S ЕД МУЖ РОД ОД" ID="14" KSNAME="СЕРОВ" LEMMA="СЕРОВ" LINK="атриб">Серова</W> -
#  <W DOM="16" FEAT="ADV" ID="15" LEMMA="ПОЧЕМУ-ТО" LINK="обст">почему-то</W>
#  <W DOM="2" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД СРЕД" ID="16" LEMMA="ЗАХОТЕТЬСЯ" LINK="разъяснит">захотелось</W>
#  <W DOM="16" FEAT="V СОВ ИНФ" ID="17" LEMMA="ДЕЛАТЬ" LINK="2-компл">сделать</W>
#  <W DOM="17" FEAT="S МН ЖЕН ВИН НЕОД" ID="18" LEMMA="КОПИЯ" LINK="1-компл">копии</W>.
#  </S>,
#  <S ID="52">
#  <W DOM="8" FEAT="ADV" ID="1" LEMMA="ОДНАЖДЫ" LINK="обст">Однажды</W>,
#  <W DOM="8" FEAT="V СОВ ДЕЕПР ПРОШ" ID="2" KSNAME="ВЫВОДИТЬ4" LEMMA="ВЫВОДИТЬ" LINK="обст">выведя</W>
#  <W DOM="2" FEAT="PR" ID="3" KSNAME="НА1" LEMMA="НА" LINK="обст">на</W>
#  <W DOM="3" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="4" LEMMA="ПРОГУЛКА" LINK="предл">прогулку</W>
#  <W DOM="6" FEAT="A ЕД МУЖ ВИН ОД" ID="5" LEMMA="НАШ" LINK="опред">нашего</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ВИН ОД" ID="6" LEMMA="ПЕС" LINK="1-компл">пса</W>,
#  <W DOM="8" FEAT="S ЕД ЖЕН ИМ ОД" ID="7" LEMMA="Я" LINK="предик">я</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="8" LEMMA="ЗНАКОМИТЬСЯ">познакомилась</W>
#  <W DOM="8" FEAT="PR" ID="9" KSNAME="С3" LEMMA="С" LINK="1-компл">с</W>
#  <W DOM="12" FEAT="A ЕД ЖЕН ТВОР" ID="10" KSNAME="ОДИН2" LEMMA="ОДИН" LINK="опред">одной</W>
#  <W DOM="12" FEAT="A ЕД ЖЕН ТВОР" ID="11" LEMMA="МИЛЫЙ" LINK="опред">милой</W>
#  <W DOM="9" FEAT="S ЕД ЖЕН ТВОР ОД" ID="12" LEMMA="ЖЕНЩИНА" LINK="предл">женщиной</W>
#  <W DOM="14" FEAT="A ЕД МУЖ РОД" ID="13" LEMMA="ВОСТОЧНЫЙ" LINK="опред">восточного</W>
#  <W DOM="12" FEAT="S ЕД МУЖ РОД НЕОД" ID="14" KSNAME="ВИД2" LEMMA="ВИД" LINK="атриб">вида</W>,
#  <W DOM="12" FEAT="V СОВ СТРАД ПРИЧ ПРОШ ЕД ЖЕН ТВОР" ID="15" KSNAME="ОБВЕШИВАТЬ1" LEMMA="ОБВЕШИВАТЬ" LINK="опред">обвешенной</W>
#  <W DOM="15" FEAT="S ЕД СРЕД ТВОР НЕОД" ID="16" LEMMA="МНОЖЕСТВО" LINK="2-компл">множеством</W>
#  <W DOM="18" FEAT="A МН РОД" ID="17" LEMMA="ПЕСТРЫЙ" LINK="опред">пестрых</W>
#  <W DOM="16" FEAT="S МН ЖЕН РОД НЕОД" ID="18" LEMMA="БУСЫ" LINK="квазиагент">бус</W>.
#  </S>,
#  <S ID="58">
#  <W DOM="2" FEAT="ADV" ID="1" LEMMA="ПОСТОЯННО" LINK="обст">Постоянно</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="2" KSNAME="ЕСТЬ1" LEMMA="ЕСТЬ">ест</W>
#  <W DOM="4" FEAT="A ЕД ЖЕН ВИН" ID="3" LEMMA="СВЕЖИЙ" LINK="опред">свежую</W>
#  <W DOM="2" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="4" LEMMA="ТРАВА" LINK="1-компл">траву</W>
#  <W DOM="2" FEAT="CONJ" ID="5" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="5" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="6" LEMMA="ПИТЬ" LINK="соч-союзн">пьет</W>
#  <W DOM="6" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="7" LEMMA="ВОДА" LINK="1-компл">воду</W>
#  <W DOM="6" FEAT="PR" ID="8" LEMMA="ИЗ" LINK="2-компл">из</W>
#  <W DOM="8" FEAT="S МН МУЖ РОД НЕОД" ID="9" LEMMA="РУЧЕЙ" LINK="предл">ручьев</W>
#  <W DOM="9" FEAT="CONJ" ID="10" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="10" FEAT="S МН ЖЕН РОД НЕОД" ID="11" LEMMA="РЕКА" LINK="соч-союзн">рек</W>,
#  <W DOM="16" FEAT="S МН РОД" ID="12" LEMMA="КОТОРЫЙ" LINK="предик">которых</W>,
#  <W DOM="16" FEAT="PR" ID="13" LEMMA="К" LINK="вводн">к</W>
#  <W DOM="13" FEAT="S ЕД СРЕД ДАТ НЕОД" ID="14" LEMMA="СЧАСТЬЕ" LINK="предл">счастью</W>,
#  <W DOM="16" FEAT="ADV" ID="15" KSNAME="ТУТ1" LEMMA="ТУТ" LINK="обст">тут</W>
#  <W DOM="9" FEAT="ADV" ID="16" KSNAME="МНОГО1" LEMMA="МНОГО" LINK="релят">много</W>.
#  </S>,
#  <S CLASS="LF" ID="59">
#  <W DOM="3" FEAT="ADV" ID="1" LEMMA="ОДНАЖДЫ" LINK="огранич">Однажды</W>
#  <W DOM="3" FEAT="S ЕД МУЖ ВИН ОД" ID="2" KSNAME="ОН" LEMMA="ОН" LINK="1-компл">его</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="3" LEMMA="ВИДЕТЬ">увидел</W>
#  <W DOM="3" FEAT="PR" ID="4" KSNAME="В3" LEMMA="В" LINK="обст">в</W>
#  <W DOM="4" FEAT="S ЕД МУЖ МЕСТН НЕОД" ID="5" KSNAME="ЛЕС1" LEMMA="ЛЕС" LINK="предл">лесу</W>
#  <W DOM="7" FEAT="A ЕД МУЖ ИМ" ID="6" LEMMA="НАШ" LINK="опред">наш</W>
#  <W DOM="3" FEAT="S ЕД МУЖ ИМ ОД" ID="7" LEMMA="СОСЕД" LINK="предик">сосед</W> -
#  <W DOM="9" FEAT="A ЕД МУЖ ИМ" ID="8" KSNAME="МОЛОДОЙ1" LEMMA="МОЛОДОЙ" LINK="опред">молодой</W>
#  <W DOM="7" FEAT="S ЕД МУЖ ИМ ОД" ID="9" LEMMA="ПАРЕНЬ" LINK="разъяснит">парень</W> -
#  <W DOM="3" FEAT="CONJ" ID="10" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="12" FEAT="PART" ID="11" KSNAME="НЕ1" LEMMA="НЕ" LINK="огранич">не</W>
#  <W DOM="10" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="12" KSNAME="ПОВЕРИТЬ" LEMMA="ПОВЕРИТЬ" LINK="соч-союзн">поверил</W>
#  <W DOM="14" FEAT="A МН ДАТ" ID="13" LEMMA="СВОЙ" LINK="опред">своим</W>
#  <W DOM="12" FEAT="S МН МУЖ ДАТ НЕОД" ID="14" LEMMA="ГЛАЗ" LINK="2-компл">глазам</W>:
#  <W DOM="12" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="15" KSNAME="БЕЖАТЬ1" LEMMA="БЕЖАТЬ" LINK="разъяснит">бежит</W>
#  <W DOM="15" FEAT="S ЕД ЖЕН ИМ ОД" ID="16" LEMMA="КОСУЛЯ" LINK="предик">косуля</W>,
#  <W DOM="15" FEAT="CONJ" ID="17" KSNAME="А1" LEMMA="А" LINK="сент-соч">а</W>
#  <W DOM="20" FEAT="PR" ID="18" KSNAME="ЗА2" LEMMA="ЗА" LINK="обст">за</W>
#  <W DOM="18" FEAT="S ЕД ЖЕН ТВОР ОД" ID="19" LEMMA="ОНА" LINK="предл">ней</W>
#  <W DOM="17" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="20" KSNAME="БЕЖАТЬ1" LEMMA="БЕЖАТЬ" LINK="соч-союзн" NODETYPE="FANTOM"/>
#  <W DOM="20" FEAT="S ЕД МУЖ ИМ ОД" ID="21" LEMMA="ВОЛК" LINK="предик">волк</W>…
#  <LF LFARG="5" LFFUNC="_LOC" LFVAL="4"/>
#  </S>,
#  <S CLASS="LF" ID="62">
#  <W DOM="3" FEAT="S ЕД ЖЕН ИМ ОД" ID="1" LEMMA="Я" LINK="предик">Я</W>
#  <W DOM="3" FEAT="ADV" ID="2" LEMMA="ВСЕГДА" LINK="огранич">всегда</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="3" LEMMA="ЧУВСТВОВАТЬ">чувствую</W>
#  <W DOM="3" FEAT="S ЕД МУЖ ВИН ОД" ID="4" LEMMA="СЕБЯ" LINK="1-компл">себя</W>
#  <W DOM="3" FEAT="PR" ID="5" KSNAME="В3" LEMMA="В" LINK="обст">в</W>
#  <W DOM="5" FEAT="S ЕД МУЖ МЕСТН НЕОД" ID="6" KSNAME="ЛЕС1" LEMMA="ЛЕС" LINK="предл">лесу</W>
#  <W DOM="3" FEAT="CONJ" ID="7" KSNAME="КАК1" LEMMA="КАК" LINK="2-компл">как</W>
#  <W DOM="7" FEAT="ADV" ID="8" LEMMA="ДОМА" LINK="сравн-союзн">дома</W>,
#  <W DOM="3" FEAT="CONJ" ID="9" LEMMA="НО" LINK="сочин">но</W>
#  <W DOM="19" FEAT="ADV" ID="10" LEMMA="ОДНАЖДЫ" LINK="обст">однажды</W>,
#  <W DOM="19" FEAT="V СОВ ДЕЕПР ПРОШ" ID="11" LEMMA="ВИДЕТЬ" LINK="обст">увидев</W>
#  <W DOM="11" FEAT="PR" ID="12" KSNAME="В2" LEMMA="В" LINK="обст">в</W>
#  <W DOM="14" FEAT="NUM" ID="13" KSNAME="ЧИСЛ-БОЛЬШ" LEMMA="20" LINK="количест">20</W>
#  <W DOM="12" FEAT="S МН МУЖ ПР НЕОД" ID="14" LEMMA="ШАГ" LINK="предл">шагах</W>
#  <W DOM="16" FEAT="A ЕД МУЖ ВИН ОД" ID="15" LEMMA="ОГРОМНЫЙ" LINK="опред">огромного</W>
#  <W DOM="11" FEAT="S ЕД МУЖ ВИН ОД" ID="16" KSNAME="КАБАН1" LEMMA="КАБАН" LINK="1-компл">кабана</W>,
#  <W DOM="16" FEAT="V НЕСОВ ПРИЧ НЕПРОШ ЕД МУЖ ВИН ОД" ID="17" LEMMA="ПЕРЕСЕКАТЬ" LINK="опред">пересекающего</W>
#  <W DOM="17" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="18" LEMMA="ТРОПА" LINK="1-компл">тропу</W>,
#  <W DOM="9" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="19" LEMMA="ИСПУГАТЬСЯ" LINK="соч-союзн">испугалась</W>.
#  <LF LFARG="6" LFFUNC="_LOC" LFVAL="5"/>
#  </S>,
#  <S CLASS="LF" ID="67">
#  <W DOM="6" FEAT="PR" ID="1" KSNAME="В3" LEMMA="В" LINK="обст">В</W>
#  <W DOM="3" FEAT="A ЕД МУЖ ПР" ID="2" LEMMA="ОГРОМНЫЙ" LINK="опред">огромном</W>
#  <W DOM="1" FEAT="S ЕД МУЖ МЕСТН НЕОД" ID="3" KSNAME="ТАЗ1" LEMMA="ТАЗ" LINK="предл">тазу</W>
#  <W DOM="5" FEAT="A ЕД СРЕД ИМ" ID="4" KSNAME="ВЕСЬ" LEMMA="ВЕСЬ" LINK="опред">все</W>
#  <W DOM="6" FEAT="S ЕД СРЕД ИМ НЕОД" ID="5" KSNAME="ЭТО" LEMMA="ЭТО" LINK="предик">это</W>
#  <W DOM="_root" FEAT="V НЕСОВ СТРАД ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="6" KSNAME="ПЕРЕМЕШИВАТЬ1" LEMMA="ПЕРЕМЕШИВАТЬ">перемешивается</W>,
#  <W DOM="6" FEAT="V НЕСОВ СТРАД ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="7" LEMMA="РАСКЛАДЫВАТЬ" LINK="сочин">раскладывается</W>
#  <W DOM="7" FEAT="PR" ID="8" KSNAME="НА1" LEMMA="НА" LINK="обст">на</W>
#  <W DOM="8" FEAT="S МН ЖЕН ВИН НЕОД" ID="9" LEMMA="ПОРЦИЯ" LINK="предл">порции</W>
#  <W DOM="7" FEAT="CONJ" ID="10" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="10" FEAT="V НЕСОВ СТРАД ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="11" LEMMA="ЗАСОВЫВАТЬ" LINK="соч-союзн">засовывается</W>
#  <W DOM="11" FEAT="PR" ID="12" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="12" FEAT="S ЕД МУЖ ВИН НЕОД" ID="13" LEMMA="ХОЛОДИЛЬНИК" LINK="предл">холодильник</W>,
#  <W DOM="17" FEAT="PR" ID="14" KSNAME="ПОСЛЕ1" LEMMA="ПОСЛЕ" LINK="обст">после</W>
#  <W DOM="14" FEAT="S ЕД СРЕД РОД НЕОД" ID="15" KSNAME="ЧТО2" LEMMA="ЧТО" LINK="предл">чего</W>
#  <W DOM="17" FEAT="S ЕД МУЖ ИМ ОД" ID="16" KSNAME="ФИКТ-ЛИЧИМЯ" LEMMA="ЮМА" LINK="предик">Юма</W>
#  <W DOM="6" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="17" LEMMA="ВСТАВАТЬ" LINK="изъясн">встает</W>
#  <W DOM="17" FEAT="PR" ID="18" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="18" FEAT="S ЕД МУЖ ВИН НЕОД" ID="19" KSNAME="ТАЗ1" LEMMA="ТАЗ" LINK="предл">таз</W>
#  <W DOM="17" FEAT="CONJ" ID="20" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="22" FEAT="ADV" ID="21" LEMMA="ТЩАТЕЛЬНО" LINK="обст">тщательно</W>
#  <W DOM="20" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="22" LEMMA="ВЫЛИЗЫВАТЬ" LINK="соч-союзн">вылизывает</W>
#  <W DOM="22" FEAT="S ЕД МУЖ ВИН ОД" ID="23" KSNAME="ОН" LEMMA="ОН" LINK="1-компл">его</W>
#  <W DOM="22" FEAT="ADV" ID="24" KSNAME="ИЗНУТРИ2" LEMMA="ИЗНУТРИ" LINK="обст">изнутри</W>.
#  <LF LFARG="3" LFFUNC="_LOC" LFVAL="1"/>
#  <LF LFARG="19" LFFUNC="_LOC-AD" LFVAL="18"/>
#  </S>,
#  <S ID="71">
#  <W DOM="2" FEAT="S ЕД ЖЕН ВИН ОД" ID="1" LEMMA="СОБАКА" LINK="1-компл">Собаку</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="2" LEMMA="ЛЮБИТЬ">любит</W>
#  <W DOM="2" FEAT="ADV" ID="3" LEMMA="БЕЗМЕРНО" LINK="обст">безмерно</W>,
#  <W DOM="2" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="4" LEMMA="НАЗЫВАТЬ" LINK="сочин">называет</W>
#  <W DOM="6" FEAT="A ЕД МУЖ ТВОР" ID="5" LEMMA="ЛУЧШИЙ" LINK="опред">лучшим</W>
#  <W DOM="4" FEAT="S ЕД МУЖ ТВОР ОД" ID="6" LEMMA="ДРУГ" LINK="2-компл">другом</W>,
#  <W DOM="4" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="7" KSNAME="ЗАСЫПАТЬ1" LEMMA="ЗАСЫПАТЬ" LINK="сочин">засыпает</W>
#  <W DOM="9" FEAT="PART" ID="8" LEMMA="ЛИШЬ" LINK="огранич">лишь</W>
#  <W DOM="7" FEAT="CONJ" ID="9" LEMMA="ПРИ УСЛОВИИ ЧТО" LINK="обст">при условии, что</W>
#  <W DOM="11" FEAT="S ЕД МУЖ ИМ ОД" ID="10" KSNAME="ФИКТ-ЛИЧИМЯ" LEMMA="ЮМА" LINK="предик">Юма</W>
#  <W DOM="9" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="11" LEMMA="ЛЕЖАТЬ" LINK="подч-союзн">лежит</W>
#  <W DOM="11" FEAT="PR" ID="12" KSNAME="У1" LEMMA="У" LINK="неакт-компл">у</W>
#  <W DOM="12" FEAT="S ЕД МУЖ РОД ОД" ID="13" KSNAME="НЕГО1" LEMMA="ОН" LINK="предл">него</W>
#  <W DOM="11" FEAT="PR" ID="14" KSNAME="ПОД2" LEMMA="ПОД" LINK="1-компл">под</W>
#  <W DOM="14" FEAT="S ЕД МУЖ ТВОР НЕОД" ID="15" LEMMA="БОК" LINK="предл">боком</W>.
#  </S>,
#  <S CLASS="LF" ID="80">
#  <W DOM="2" FEAT="A ЕД ЖЕН ИМ" ID="1" LEMMA="ПЕРВЫЙ" LINK="опред">Первая</W>
#  <W DOM="_root" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="2" LEMMA="ОШИБКА">ошибка</W>,
#  <W DOM="5" FEAT="S ЕД ЖЕН ВИН" ID="3" LEMMA="КОТОРЫЙ" LINK="1-компл">которую</W>
#  <W DOM="5" FEAT="S ЕД ЖЕН ИМ ОД" ID="4" LEMMA="Я" LINK="предик">я</W>
#  <W DOM="2" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="5" KSNAME="ДОПУСКАТЬ1" LEMMA="ДОПУСКАТЬ" LINK="релят">допустила</W>:
#  <W DOM="2" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="6" LEMMA="ПОЯВЛЯТЬСЯ" LINK="разъяснит">появилась</W>
#  <W DOM="6" FEAT="PR" ID="7" KSNAME="НА3" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="7" FEAT="S ЕД МУЖ МЕСТН НЕОД" ID="8" LEMMA="ЛУГ" LINK="предл">лугу</W>
#  <W DOM="6" FEAT="PR" ID="9" KSNAME="В2" LEMMA="В" LINK="обст">в</W>
#  <W DOM="11" FEAT="A ЕД ЖЕН ПР" ID="10" KSNAME="ПРОСТОЙ1" LEMMA="ПРОСТОЙ" LINK="опред">простой</W>
#  <W DOM="9" FEAT="S ЕД ЖЕН ПР НЕОД" ID="11" LEMMA="ОДЕЖДА" LINK="предл">одежде</W>
#  <W DOM="9" FEAT="CONJ" ID="12" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="12" FEAT="PR" ID="13" LEMMA="БЕЗ" LINK="соч-союзн">без</W>
#  <W DOM="13" FEAT="S ЕД МУЖ РОД НЕОД" ID="14" LEMMA="МАКИЯЖ" LINK="предл">макияжа</W>.
#  <LF LFARG="2" LFFUNC="_OPER1" LFVAL="5"/>
#  <LF LFARG="8" LFFUNC="_LOC" LFVAL="7"/>
#  </S>,
#  <S ID="84">
#  <W DOM="3" FEAT="A ЕД ЖЕН ИМ" ID="1" LEMMA="ВТОРОЙ" LINK="опред">Вторая</W>
#  <W DOM="3" FEAT="A ЕД ЖЕН ИМ" ID="2" LEMMA="МОЙ" LINK="опред">моя</W>
#  <W DOM="4" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="3" LEMMA="ОШИБКА" LINK="предик">ошибка</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="4" KSNAME="БЫТЬ" LEMMA="БЫТЬ">была</W>
#  <W DOM="6" FEAT="ADV" ID="5" LEMMA="СОВСЕМ" LINK="огранич">совсем</W>
#  <W DOM="4" FEAT="A ЕД ЖЕН ТВОР" ID="6" LEMMA="НЕПРОСТИТЕЛЬНЫЙ" LINK="присвяз">непростительной</W>:
#  <W DOM="8" FEAT="S ЕД ЖЕН ИМ ОД" ID="7" LEMMA="Я" LINK="предик">я</W>
#  <W DOM="4" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="8" LEMMA="ПЫТАТЬСЯ" LINK="разъяснит">попыталась</W>
#  <W DOM="14" FEAT="A ЕД ЖЕН ВИН" ID="9" KSNAME="ОДИН2" LEMMA="ОДИН" LINK="опред">одну</W>
#  <W DOM="14" FEAT="A ЕД ЖЕН ВИН" ID="10" LEMMA="МИЛЫЙ" LINK="опред">милую</W>,
#  <W DOM="10" FEAT="CONJ" ID="11" KSNAME="КАК1" LEMMA="КАК" LINK="вводн">как</W>
#  <W DOM="13" FEAT="S ЕД ЖЕН ДАТ ОД" ID="12" LEMMA="Я" LINK="2-компл">мне</W>
#  <W DOM="11" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД СРЕД" ID="13" KSNAME="КАЗАТЬСЯ" LEMMA="КАЗАТЬСЯ" LINK="сравн-союзн">показалось</W>,
#  <W DOM="15" FEAT="S ЕД ЖЕН ВИН ОД" ID="14" LEMMA="ДАМА" LINK="1-компл">даму</W>
#  <W DOM="8" FEAT="V СОВ ИНФ" ID="15" LEMMA="ПРИГЛАШАТЬ" LINK="1-компл">пригласить</W>
#  <W DOM="15" FEAT="PR" ID="16" KSNAME="НА1" LEMMA="НА" LINK="3-компл">на</W>
#  <W DOM="18" FEAT="A ЕД ЖЕН ВИН" ID="17" LEMMA="СВОЙ" LINK="опред">свою</W>
#  <W DOM="16" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="18" LEMMA="ВЫСТАВКА" LINK="предл">выставку</W>.
#  </S>,
#  <S CLASS="LF" ID="89">
#  <W DOM="4" FEAT="ADV" ID="1" LEMMA="ЧАСТЕНЬКО" LINK="обст">Частенько</W>
#  <W DOM="4" FEAT="PR" ID="2" KSNAME="НА3" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="2" FEAT="S ЕД МУЖ МЕСТН НЕОД" ID="3" LEMMA="ЛУГ" LINK="предл">лугу</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="4" LEMMA="ПОЯВЛЯТЬСЯ">появляется</W>
#  <W DOM="4" FEAT="S ЕД ЖЕН ИМ ОД" ID="5" LEMMA="ДАМА" LINK="предик">дама</W>
#  <W DOM="5" FEAT="PR" ID="6" KSNAME="С3" LEMMA="С" LINK="атриб">с</W>
#  <W DOM="8" FEAT="A ЕД МУЖ ТВОР" ID="7" KSNAME="ФИКТ-ПРИЛ" LEMMA="70-КИЛОГРАММОВЫЙ" LINK="опред">70-килограммовым</W>
#  <W DOM="6" FEAT="S ЕД МУЖ ТВОР ОД" ID="8" LEMMA="МАСТИФ" LINK="предл">мастифом</W>,
#  <W DOM="12" FEAT="S ЕД МУЖ ВИН ОД" ID="9" LEMMA="КОТОРЫЙ" LINK="1-компл">которого</W>
#  <W DOM="12" FEAT="S ЕД ЖЕН ИМ ОД" ID="10" LEMMA="ОНА" LINK="предик">она</W>
#  <W DOM="12" FEAT="ADV" ID="11" LEMMA="НЕЖНО" LINK="обст">нежно</W>
#  <W DOM="8" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="12" LEMMA="НАЗЫВАТЬ" LINK="релят">называет</W>
#  "<W DOM="12" FEAT="S ЕД МУЖ ИМ ОД" ID="13" KSNAME="ФИКТ-ЛИЧИМЯ" LEMMA="МОЙЗЕ" LINK="2-компл">Мойзе</W>-
#  <W DOM="13" FEAT="S ЕД ЖЕН ИМ ОД" ID="14" KSNAME="МЫШКА1" LEMMA="МЫШКА" LINK="аппоз">мышка</W>",
#  <W DOM="16" FEAT="PART" ID="15" KSNAME="НЕ1" LEMMA="НЕ" LINK="огранич">не</W>
#  <W DOM="12" FEAT="V НЕСОВ ДЕЕПР НЕПРОШ" ID="16" KSNAME="ОБРАЩАТЬ2" LEMMA="ОБРАЩАТЬ" LINK="обст">обращая</W>
#  <W DOM="16" FEAT="S ЕД СРЕД РОД НЕОД" ID="17" LEMMA="ВНИМАНИЕ" LINK="1-компл">внимания</W>
#  <W DOM="19" FEAT="PART" ID="18" KSNAME="НИ2" LEMMA="НИ" LINK="огранич">ни</W>
#  <W DOM="16" FEAT="PR" ID="19" KSNAME="НА1" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="19" FEAT="S ЕД МУЖ ВИН ОД" ID="20" LEMMA="КТО" LINK="предл">кого</W>
#  <W DOM="20" FEAT="ADV" ID="21" KSNAME="ВОКРУГ2" LEMMA="ВОКРУГ" LINK="атриб">вокруг</W>.
#  <LF LFARG="17" LFFUNC="_OPER1" LFVAL="16"/>
#  <LF LFARG="3" LFFUNC="_LOC" LFVAL="2"/>
#  <LF LFARG="17" LFFUNC="_CAUSFUNC0" LFVAL="16"/>
#  </S>,
#  <S CLASS="LF" ID="98">
#  <W DOM="9" FEAT="ADV" ID="1" LEMMA="ОДНАЖДЫ" LINK="обст">Однажды</W>,
#  <W DOM="9" FEAT="PR" ID="2" KSNAME="ПО1" LEMMA="ПО" LINK="вводн">по</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ДАТ НЕОД" ID="3" KSNAME="СОВЕТ1" LEMMA="СОВЕТ" LINK="предл">совету</W>
#  <W DOM="3" FEAT="S МН МУЖ РОД ОД" ID="4" LEMMA="СОСЕД" LINK="квазиагент">соседей</W>,
#  <W DOM="8" FEAT="A ЕД СРЕД ТВОР" ID="5" LEMMA="РАННИЙ" LINK="опред">ранним</W>
#  <W DOM="8" FEAT="A ЕД СРЕД ТВОР" ID="6" LEMMA="СОЛНЕЧНЫЙ" LINK="опред">солнечным</W>
#  <W DOM="8" FEAT="A ЕД СРЕД ТВОР" ID="7" LEMMA="МАЙСКИЙ" LINK="опред">майским</W>
#  <W DOM="9" FEAT="S ЕД СРЕД ТВОР НЕОД" ID="8" LEMMA="УТРО" LINK="обст">утром</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ МН" ID="9" LEMMA="ОТПРАВЛЯТЬСЯ">отправились</W>
#  <W DOM="9" FEAT="S МН ИМ ОД" ID="10" LEMMA="МЫ" LINK="предик">мы</W>
#  <W DOM="10" FEAT="PR" ID="11" KSNAME="С3" LEMMA="С" LINK="атриб">с</W>
#  <W DOM="11" FEAT="S ЕД МУЖ ТВОР ОД" ID="12" KSNAME="ФИКТ-ЛИЧИМЯ" LEMMA="ЮМА" LINK="предл">Юмой</W>
#  <W DOM="9" FEAT="PR" ID="13" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="17" FEAT="V СОВ СТРАД ПРИЧ ПРОШ ЕД МУЖ ВИН НЕОД" ID="14" KSNAME="ЗАБРАСЫВАТЬ3" LEMMA="ЗАБРАСЫВАТЬ" LINK="опред">заброшенный</W>
#  <W DOM="17" FEAT="A ЕД МУЖ ВИН НЕОД" ID="15" LEMMA="ГОРОДСКОЙ" LINK="опред">городской</W>
#  <W DOM="17" FEAT="A ЕД МУЖ ВИН НЕОД" ID="16" LEMMA="ЯБЛОНЕВЫЙ" LINK="опред">яблоневый</W>
#  <W DOM="13" FEAT="S ЕД МУЖ ВИН НЕОД" ID="17" LEMMA="САД" LINK="предл">сад</W>,
#  <W DOM="22" FEAT="ADV" ID="18" LEMMA="ГДЕ" LINK="2-компл">где</W>
#  <W DOM="21" FEAT="ADV" ID="19" KSNAME="ЯКОБЫ1" LEMMA="ЯКОБЫ" LINK="огранич">якобы</W>
#  <W DOM="21" FEAT="ADV" ID="20" LEMMA="МОЖНО" LINK="присвяз">можно</W>
#  <W DOM="17" FEAT="V НЕСОВ ИЗЪЯВ ПРОШ ЕД СРЕД" ID="21" KSNAME="БЫТЬ" LEMMA="БЫТЬ" LINK="релят">было</W>
#  <W DOM="21" FEAT="V СОВ ИНФ" ID="22" LEMMA="БРАТЬ" LINK="предик">взять</W>
#  <W DOM="22" FEAT="PR" ID="23" KSNAME="В1" LEMMA="В" LINK="3-компл">в</W>
#  <W DOM="23" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="24" LEMMA="АРЕНДА" LINK="предл">аренду</W>
#  <W DOM="22" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="25" KSNAME="ПАРА1" LEMMA="ПАРА" LINK="1-компл">пару</W>
#  <W DOM="25" FEAT="S МН ЖЕН РОД НЕОД" ID="26" LEMMA="ЯБЛОНЯ" LINK="квазиагент">яблонь</W>
#  (<W DOM="26" FEAT="V НЕСОВ ИНФ" ID="27" LEMMA="УХАЖИВАТЬ" LINK="примыкат">ухаживать</W>
#  <W DOM="27" FEAT="PR" ID="28" KSNAME="ЗА2" LEMMA="ЗА" LINK="1-компл">за</W>
#  <W DOM="28" FEAT="S МН ТВОР ОД" ID="29" LEMMA="ОНИ" LINK="предл">ними</W>
#  <W DOM="27" FEAT="CONJ" ID="30" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="32" FEAT="ADV" ID="31" LEMMA="ПОТОМ" LINK="обст">потом</W>
#  <W DOM="30" FEAT="V СОВ ИНФ" ID="32" KSNAME="СОБИРАТЬ1" LEMMA="СОБИРАТЬ" LINK="соч-союзн">собрать</W>
#  <W DOM="32" FEAT="PR" ID="33" KSNAME="С1" LEMMA="С" LINK="2-компл">с</W>
#  <W DOM="33" FEAT="S МН РОД ОД" ID="34" LEMMA="ОНИ" LINK="предл">них</W>
#  <W DOM="32" FEAT="S ЕД МУЖ ВИН НЕОД" ID="35" LEMMA="УРОЖАЙ" LINK="1-компл">урожай</W>).
#  <LF LFARG="35" LFFUNC="_REAL1" LFVAL="32"/>
#  <LF LFARG="3" LFFUNC="_ADV2-UN" LFVAL="2"/>
#  </S>,
#  <S ID="103">
#  <W DOM="3" FEAT="S ЕД ЖЕН ИМ ОД" ID="1" LEMMA="Я" LINK="предик">Я</W>
#  <W DOM="3" FEAT="ADV" ID="2" LEMMA="НЕМНОГО" LINK="огранич">немного</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="3" KSNAME="ОТХОДИТЬ1" LEMMA="ОТХОДИТЬ">отошла</W>
#  <W DOM="3" FEAT="PR" ID="4" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="4" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="5" LEMMA="СТОРОНА" LINK="предл">сторону</W>,
#  <W DOM="3" FEAT="V СОВ ДЕЕПР ПРОШ" ID="6" KSNAME="РЕШАТЬ2" LEMMA="РЕШАТЬ" LINK="обст">решив</W>
#  <W DOM="6" FEAT="V СОВ ИНФ" ID="7" KSNAME="ПРОПУСКАТЬ1" LEMMA="ПРОПУСКАТЬ" LINK="1-компл">пропустить</W>
#  <W DOM="7" FEAT="S МН ВИН ОД" ID="8" LEMMA="ОНИ" LINK="1-компл">их</W> -
#  <W DOM="10" FEAT="S МН ИМ ОД" ID="9" LEMMA="ОНИ" LINK="предик">они</W>
#  <W DOM="3" FEAT="V НЕСОВ ИЗЪЯВ ПРОШ МН" ID="10" LEMMA="НАПРАВЛЯТЬСЯ" LINK="разъяснит">направлялись</W>
#  <W DOM="10" FEAT="PR" ID="11" LEMMA="К" LINK="2-компл">к</W>
#  <W DOM="11" FEAT="S ЕД МУЖ ДАТ НЕОД" ID="12" KSNAME="ВЫХОД1" LEMMA="ВЫХОД" LINK="предл">выходу</W>.
#  </S>,
#  <S CLASS="LF" ID="104">
#  <W DOM="2" FEAT="S МН ИМ ОД" ID="1" LEMMA="ОНИ" LINK="предик">Они</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ МН" ID="2" KSNAME="ПРОХОДИТЬ1" LEMMA="ПРОХОДИТЬ">прошли</W>
#  <W DOM="2" FEAT="ADV" ID="3" KSNAME="МИМО2" LEMMA="МИМО" LINK="4-компл">мимо</W>,
#  <W DOM="5" FEAT="ADV" ID="4" KSNAME="ПРЯМО1" LEMMA="ПРЯМО" LINK="огранич">прямо</W>
#  <W DOM="7" FEAT="PR" ID="5" KSNAME="ПЕРЕД1" LEMMA="ПЕРЕД" LINK="обст">передо</W>
#  <W DOM="5" FEAT="S ЕД ЖЕН ТВОР ОД" ID="6" LEMMA="Я" LINK="предл">мной</W>
#  <W DOM="2" FEAT="V СОВ ИЗЪЯВ ПРОШ МН" ID="7" LEMMA="ЗАХЛОПЫВАТЬ" LINK="сочин">захлопнули</W>
#  <W DOM="7" FEAT="S МН СРЕД ВИН НЕОД" ID="8" LEMMA="ВОРОТА" LINK="1-компл">ворота</W>
#  <W DOM="7" FEAT="CONJ" ID="9" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="9" FEAT="V СОВ ИЗЪЯВ ПРОШ МН" ID="10" LEMMA="ЗАКРЫВАТЬ" LINK="соч-союзн">закрыли</W>
#  <W DOM="10" FEAT="PR" ID="11" KSNAME="НА1" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="11" FEAT="S ЕД МУЖ ВИН НЕОД" ID="12" KSNAME="ЗАМОК1" LEMMA="ЗАМОК" LINK="предл">замок</W>.
#  <LF LFARG="12" LFFUNC="_LABREAL1-2" LFPREP="11" LFVAL="10"/>
#  </S>,
#  <S ID="107">
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="1" LEMMA="НАЧИНАТЬ">Начала</W>
#  <W DOM="1" FEAT="V НЕСОВ ИНФ" ID="2" LEMMA="ИСКАТЬ" LINK="1-компл">искать</W>
#  <W DOM="2" FEAT="PR" ID="3" KSNAME="В2" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="3" FEAT="S ЕД МУЖ ПР ОД" ID="4" KSNAME="НЕГО1" LEMMA="ОН" LINK="предл">нем</W>
#  <W DOM="2" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="5" LEMMA="ДЫРКА" LINK="1-компл">дырку</W>,
#  <W DOM="13" FEAT="PR" ID="6" LEMMA="ЧЕРЕЗ" LINK="обст">через</W>
#  <W DOM="8" FEAT="NUM" ID="7" KSNAME="ЧИСЛ-БОЛЬШ" LEMMA="15" LINK="количест">15</W>
#  <W DOM="6" FEAT="S МН ЖЕН РОД НЕОД" ID="8" LEMMA="МИНУТА" LINK="предл">минут</W>
#  <W DOM="8" FEAT="S ЕД СРЕД РОД НЕОД" ID="9" LEMMA="РАЗВИНЧИВАНИЕ" LINK="квазиагент">развинчивания</W>
#  <W DOM="11" FEAT="A ЕД ЖЕН РОД" ID="10" LEMMA="КОЛЮЧИЙ" LINK="опред">колючей</W>
#  <W DOM="9" FEAT="S ЕД ЖЕН РОД НЕОД" ID="11" LEMMA="ПРОВОЛОКА" LINK="1-компл">проволоки</W>
#  <W DOM="13" FEAT="S МН ЖЕН ИМ НЕОД" ID="12" LEMMA="РУКА" LINK="предик">руки</W>
#  <W DOM="1" FEAT="V НЕСОВ ИЗЪЯВ ПРОШ МН" ID="13" KSNAME="БЫТЬ" LEMMA="БЫТЬ" LINK="сент-соч">были</W>
#  <W DOM="13" FEAT="A МН ИМ" ID="14" KSNAME="ВЕСЬ" LEMMA="ВЕСЬ" LINK="суб-копр">все</W>
#  <W DOM="13" FEAT="PR" ID="15" KSNAME="В2" LEMMA="В" LINK="присвяз">в</W>
#  <W DOM="15" FEAT="S ЕД ЖЕН ПР НЕОД" ID="16" LEMMA="КРОВЬ" LINK="предл">крови</W>,
#  <W DOM="13" FEAT="CONJ" ID="17" LEMMA="НО" LINK="сент-соч">но</W>
#  <W DOM="24" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="18" LEMMA="ДЫРКА" LINK="1-компл">дырку</W>
#  <W DOM="18" FEAT="S ЕД МУЖ ТВОР НЕОД" ID="19" LEMMA="РАЗМЕР" LINK="атриб">размером</W>
#  <W DOM="19" FEAT="PR" ID="20" KSNAME="С2" LEMMA="С" LINK="компл-аппоз">с</W>
#  <W DOM="20" FEAT="S ЕД ЖЕН ВИН ОД" ID="21" LEMMA="СОБАКА" LINK="предл">собаку</W>
#  <W DOM="24" FEAT="S ЕД ЖЕН ИМ ОД" ID="22" LEMMA="Я" LINK="предик">я</W>
#  <W DOM="24" FEAT="PART" ID="23" KSNAME="УЖЕ" LEMMA="УЖЕ" LINK="огранич">уже</W>
#  <W DOM="17" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="24" KSNAME="ПРОДЕЛЫВАТЬ2" LEMMA="ПРОДЕЛЫВАТЬ" LINK="соч-союзн">проделала</W>.
#  </S>,
#  <S ID="109">
#  <W DOM="2" FEAT="ADV" ID="1" KSNAME="ТУТ1" LEMMA="ТУТ" LINK="обст">Тут</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="2" LEMMA="ПОДЪЕЗЖАТЬ">подъехал</W>
#  <W DOM="4" FEAT="A ЕД МУЖ ИМ" ID="3" LEMMA="НЕКИЙ" LINK="опред">некий</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ИМ ОД" ID="4" LEMMA="МУЖЧИНА" LINK="предик">мужчина</W>
#  <W DOM="4" FEAT="PR" ID="5" KSNAME="НА2" LEMMA="НА" LINK="атриб">на</W>
#  <W DOM="5" FEAT="S ЕД МУЖ ПР НЕОД" ID="6" LEMMA="ВЕЛОСИПЕД" LINK="предл">велосипеде</W>,
#  <W DOM="2" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="7" KSNAME="ОТКРЫВАТЬ1" LEMMA="ОТКРЫВАТЬ" LINK="сочин">открыл</W>
#  <W DOM="7" FEAT="S МН СРЕД ВИН НЕОД" ID="8" LEMMA="ВОРОТА" LINK="1-компл">ворота</W>
#  <W DOM="7" FEAT="CONJ" ID="9" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>,
#  <W DOM="15" FEAT="V НЕСОВ ДЕЕПР НЕПРОШ" ID="10" LEMMA="ПРЯТАТЬ" LINK="обст">пряча</W>
#  <W DOM="10" FEAT="PR" ID="11" KSNAME="В1" LEMMA="В" LINK="3-компл">в</W>
#  <W DOM="11" FEAT="S ЕД МУЖ ВИН НЕОД" ID="12" LEMMA="ВОРОТНИК" LINK="предл">воротник</W>
#  <W DOM="14" FEAT="A ЕД ЖЕН ВИН" ID="13" LEMMA="УДОВЛЕТВОРЕННЫЙ" LINK="опред">удовлетворенную</W>
#  <W DOM="10" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="14" LEMMA="УЛЫБКА" LINK="1-компл">улыбку</W>,
#  <W DOM="9" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="15" KSNAME="СПРАШИВАТЬ1" LEMMA="СПРАШИВАТЬ" LINK="соч-союзн">спросил</W>:
#  "<W DOM="15" FEAT="CONJ" ID="16" KSNAME="А1" LEMMA="А" LINK="2-компл">А</W>
#  <W DOM="21" FEAT="S ЕД СРЕД ВИН НЕОД" ID="17" KSNAME="ЧТО2" LEMMA="ЧТО" LINK="обст">что</W>
#  <W DOM="17" FEAT="PART" ID="18" KSNAME="ЭТО2" LEMMA="ЭТО" LINK="огранич">это</W>
#  <W DOM="21" FEAT="S МН ИМ ОД" ID="19" LEMMA="ВЫ" LINK="предик">вы</W>
#  <W DOM="21" FEAT="S ЕД МУЖ ВИН НЕОД" ID="20" KSNAME="ЗАБОР1" LEMMA="ЗАБОР" LINK="1-компл">забор</W>
#  <W DOM="16" FEAT="V НЕСОВ ПОВ МН 2-Л" ID="21" KSNAME="ПОРТИТЬ" LEMMA="ПОРТИТЬ" LINK="соч-союзн">портите</W>?"
#  </S>,
#  <S CLASS="LF" ID="119">
#  <W DOM="3" FEAT="S ЕД МУЖ ИМ ОД" ID="1" LEMMA="КТО-ТО" LINK="предик">Кто-то</W>
#  <W DOM="3" FEAT="PART" ID="2" LEMMA="ДАЖЕ" LINK="огранич">даже</W>
#  <W DOM="_root" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД МУЖ" ID="3" LEMMA="ПРЕДУПРЕЖДАТЬ">предупредил</W>
#  <W DOM="3" FEAT="S ЕД ЖЕН ВИН ОД" ID="4" LEMMA="Я" LINK="1-компл">меня</W>,
#  <W DOM="3" FEAT="CONJ" ID="5" KSNAME="ЧТО1" LEMMA="ЧТО" LINK="2-компл">что</W>
#  <W DOM="5" FEAT="A КР ЕД СРЕД" ID="6" LEMMA="НУЖНЫЙ" LINK="подч-союзн">нужно</W>
#  <W DOM="6" FEAT="V СОВ ИНФ" ID="7" LEMMA="ПОЛУЧАТЬ" LINK="предик">получить</W>
#  <W DOM="7" FEAT="S ЕД СРЕД ВИН НЕОД" ID="8" KSNAME="РАЗРЕШЕНИЕ2" LEMMA="РАЗРЕШЕНИЕ" LINK="1-компл">разрешение</W>,
#  <W DOM="8" FEAT="CONJ" ID="9" LEMMA="ЧТОБЫ" LINK="1-компл">чтобы</W>
#  <W DOM="9" FEAT="V НЕСОВ ИНФ" ID="10" LEMMA="РИСОВАТЬ" LINK="инф-союзн">рисовать</W>
#  <W DOM="10" FEAT="PR" ID="11" KSNAME="НА2" LEMMA="НА" LINK="обст">на</W>
#  <W DOM="11" FEAT="S ЕД ЖЕН ПР НЕОД" ID="12" LEMMA="УЛИЦА" LINK="предл">улице</W>.
#  <LF LFARG="8" LFFUNC="_INCEPOPER3" LFVAL="7"/>
#  <LF LFARG="12" LFFUNC="_LOC" LFVAL="11"/>
#  </S>,
#  <S CLASS="LF" ID="122">
#  <W DOM="10" FEAT="ADV СРАВ" ID="1" KSNAME="МНОГО1" LEMMA="МНОГО" LINK="пролепт">Больше</W>
#  <W DOM="1" FEAT="S ЕД ЖЕН РОД НЕОД" ID="2" KSNAME="ПОЛОВИНА1" LEMMA="ПОЛОВИНА" LINK="сравнит">половины</W>
#  <W DOM="2" FEAT="S МН МУЖ РОД ОД" ID="3" LEMMA="ЧЕЛОВЕК" LINK="квазиагент">людей</W>,
#  <W DOM="6" FEAT="S МН ВИН ОД" ID="4" LEMMA="КОТОРЫЙ" LINK="1-компл">которых</W>
#  <W DOM="6" FEAT="S ЕД МУЖ ИМ ОД" ID="5" LEMMA="Я" LINK="предик">я</W>
#  <W DOM="3" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="6" LEMMA="ВСТРЕЧАТЬ" LINK="релят">встречаю</W>
#  <W DOM="6" FEAT="PR" ID="7" KSNAME="НА2" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="7" FEAT="S МН ЖЕН ПР НЕОД" ID="8" LEMMA="УЛИЦА" LINK="предл">улицах</W>
#  <W DOM="8" FEAT="S ЕД МУЖ РОД НЕОД" ID="9" LEMMA="БАДЕН" LINK="атриб">Бадена</W> -
#  <W DOM="13" FEAT="S ЕД СРЕД ИМ НЕОД" ID="10" KSNAME="ЭТО" LEMMA="ЭТО" LINK="предик">это</W>
#  <W DOM="13" FEAT="A МН ИМ" ID="11" LEMMA="ТОЩИЙ" LINK="опред">тощие</W>
#  <W DOM="13" FEAT="A МН ИМ" ID="12" LEMMA="НЕМЕЦКИЙ" LINK="опред">немецкие</W>
#  <W DOM="_root" FEAT="S МН ЖЕН ИМ ОД" ID="13" LEMMA="СТАРУХА">старухи</W>
#  (<W DOM="13" FEAT="A МН ИМ" ID="14" LEMMA="ТОЩИЙ" LINK="примыкат">тощие</W>
#  <W DOM="16" FEAT="PART" ID="15" KSNAME="НЕ1" LEMMA="НЕ" LINK="огранич">не</W>
#  <W DOM="14" FEAT="PR" ID="16" LEMMA="ОТ" LINK="атриб">от</W>
#  <W DOM="16" FEAT="S ЕД ЖЕН РОД НЕОД" ID="17" LEMMA="БОЛЕЗНЬ" LINK="предл">болезни</W>,
#  <W DOM="19" FEAT="S ЕД СРЕД ИМ НЕОД" ID="18" KSNAME="ДЕЛО1" LEMMA="ДЕЛО" LINK="предик">дело</W>
#  <W DOM="14" FEAT="PR" ID="19" KSNAME="В2" LEMMA="В" LINK="сент-соч">в</W>
#  <W DOM="19" FEAT="S ЕД ЖЕН ПР НЕОД" ID="20" LEMMA="МОДА" LINK="предл">моде</W>)
#  <W DOM="13" FEAT="PR" ID="21" KSNAME="В2" LEMMA="В" LINK="атриб">в</W>
#  <W DOM="23" FEAT="A ЕД ЖЕН ПР" ID="22" LEMMA="СПОРТИВНЫЙ" LINK="опред">спортивной</W>
#  <W DOM="21" FEAT="S ЕД ЖЕН ПР НЕОД" ID="23" LEMMA="ОДЕЖДА" LINK="предл">одежде</W>
#  <W DOM="25" FEAT="A МН РОД" ID="24" KSNAME="САМЫЙ" LEMMA="САМЫЙ" LINK="опред">самых</W>
#  <W DOM="26" FEAT="A МН РОД" ID="25" KSNAME="ДОРОГОЙ1" LEMMA="ДОРОГОЙ" LINK="опред">дорогих</W>
#  <W DOM="23" FEAT="S МН ЖЕН РОД НЕОД" ID="26" KSNAME="МАРКА1" LEMMA="МАРКА" LINK="атриб">марок</W>,
#  <W DOM="31" FEAT="S МН ИМ ОД" ID="27" KSNAME="ВСЕ3" LEMMA="ВСЕ" LINK="предик">все</W>
#  <W DOM="29" FEAT="ADV" ID="28" LEMMA="КОРОТКО" LINK="обст">коротко</W>
#  <W DOM="31" FEAT="V НЕСОВ СТРАД ПРИЧ ПРОШ МН ИМ" ID="29" LEMMA="СТРИЧЬ" LINK="опред">стриженные</W>
#  <W DOM="31" FEAT="A МН ИМ" ID="30" LEMMA="КРАШЕНЫЙ" LINK="опред">крашеные</W>
#  <W DOM="13" FEAT="S МН ЖЕН ИМ ОД" ID="31" LEMMA="БЛОНДИНКА" LINK="сент-соч">блондинки</W>,
#  <W DOM="31" FEAT="PR" ID="32" KSNAME="С3" LEMMA="С" LINK="атриб">с</W>
#  <W DOM="34" FEAT="A МН ТВОР" ID="33" LEMMA="СИЛИКОНОВЫЙ" LINK="опред">силиконовыми</W>
#  <W DOM="32" FEAT="S МН ЖЕН ТВОР НЕОД" ID="34" LEMMA="ГУБА" LINK="предл">губами</W>-
#  <W DOM="34" FEAT="S МН МУЖ ТВОР НЕОД" ID="35" LEMMA="ПЕЛЬМЕНЬ" LINK="аппоз">пельменями</W>,
#  <W DOM="37" FEAT="A МН ТВОР" ID="36" LEMMA="ПЛАСТИКОВЫЙ" LINK="опред">пластиковыми</W>
#  <W DOM="34" FEAT="S МН МУЖ ТВОР НЕОД" ID="37" KSNAME="ЗУБ1" LEMMA="ЗУБ" LINK="сочин">зубами</W>
#  <W DOM="39" FEAT="A ЕД ЖЕН РОД" ID="38" LEMMA="НЕИМОВЕРНЫЙ" LINK="опред">неимоверной</W>
#  <W DOM="37" FEAT="S ЕД ЖЕН РОД НЕОД" ID="39" LEMMA="БЕЛИЗНА" LINK="атриб">белизны</W>,
#  <W DOM="32" FEAT="PR" ID="40" KSNAME="В2" LEMMA="В" LINK="сочин">в</W>
#  <W DOM="42" FEAT="A МН ПР" ID="41" LEMMA="ОГРОМНЫЙ" LINK="опред">огромных</W>
#  <W DOM="40" FEAT="S МН МУЖ ПР НЕОД" ID="42" LEMMA="ОЧКИ" LINK="предл">очках</W>
#  <W DOM="42" FEAT="CONJ" ID="43" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="43" FEAT="S МН ЖЕН ПР НЕОД" ID="44" KSNAME="ШЛЯПА1" LEMMA="ШЛЯПА" LINK="соч-союзн">шляпах</W>,
#  <W DOM="40" FEAT="PR" ID="45" KSNAME="С3" LEMMA="С" LINK="сочин">с</W>
#  <W DOM="48" FEAT="A МН ТВОР" ID="46" LEMMA="УЖАСНЫЙ" LINK="опред">ужасными</W>
#  <W DOM="48" FEAT="A МН ТВОР" ID="47" LEMMA="МОРЩИНИСТЫЙ" LINK="опред">морщинистыми</W>
#  <W DOM="45" FEAT="S МН ЖЕН ТВОР НЕОД" ID="48" LEMMA="РУКА" LINK="предл">руками</W>
#  <W DOM="48" FEAT="PR" ID="49" KSNAME="В2" LEMMA="В" LINK="атриб">в</W>
#  <W DOM="51" FEAT="A МН ПР" ID="50" LEMMA="БРИЛЛИАНТОВЫЙ" LINK="опред">бриллиантовых</W>
#  <W DOM="49" FEAT="S МН СРЕД ПР НЕОД" ID="51" LEMMA="КОЛЬЦО" LINK="предл">кольцах</W>,
#  <W DOM="45" FEAT="PR" ID="52" KSNAME="С3" LEMMA="С" LINK="сочин">со</W>
#  <W DOM="54" FEAT="NUM ВИН" ID="53" LEMMA="СТО" LINK="количест">сто</W>
#  <W DOM="55" FEAT="S МН МУЖ РОД НЕОД" ID="54" KSNAME="РАЗ1" LEMMA="РАЗ" LINK="обст">раз</W>
#  <W DOM="58" FEAT="V СОВ СТРАД ПРИЧ ПРОШ МН ТВОР" ID="55" KSNAME="ОПЕРИРОВАТЬ1" LEMMA="ОПЕРИРОВАТЬ" LINK="опред">прооперированными</W>
#  <W DOM="55" FEAT="PR" ID="56" KSNAME="НА2" LEMMA="НА" LINK="обст">на</W>
#  <W DOM="56" FEAT="S МН ЖЕН ПР НЕОД" ID="57" LEMMA="НОГА" LINK="предл">ногах</W>
#  <W DOM="52" FEAT="S МН ЖЕН ТВОР НЕОД" ID="58" KSNAME="ВЕНА1" LEMMA="ВЕНА" LINK="предл">венами</W>
#  <W DOM="52" FEAT="CONJ" ID="59" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="59" FEAT="PR" ID="60" KSNAME="В2" LEMMA="В" LINK="соч-союзн">в</W>
#  <W DOM="62" FEAT="A МН ПР" ID="61" LEMMA="БЕЛОСНЕЖНЫЙ" LINK="опред">белоснежных</W>
#  <W DOM="60" FEAT="S МН ЖЕН ПР НЕОД" ID="62" LEMMA="КРОССОВКА" LINK="предл">кроссовках</W>.
#  <LF LFARG="8" LFFUNC="_LOC" LFVAL="7"/>
#  </S>,
#  <S CLASS="LF" ID="124">
#  <W DOM="13" FEAT="V НЕСОВ ДЕЕПР НЕПРОШ" ID="1" LEMMA="СИДЕТЬ" LINK="обст">Сидя</W>
#  <W DOM="1" FEAT="S МН МУЖ ВИН НЕОД" ID="2" LEMMA="ДЕНЬ" LINK="длительн">дни</W>
#  <W DOM="2" FEAT="ADV" ID="3" KSNAME="НАПРОЛЕТ" LEMMA="НАПРОЛЕТ" LINK="атриб">напролет</W>
#  <W DOM="1" FEAT="PR" ID="4" KSNAME="В2" LEMMA="В" LINK="1-компл">в</W>
#  <W DOM="4" FEAT="S ЕД СРЕД ПР НЕОД" ID="5" LEMMA="КАФЕ" LINK="предл">кафе</W>,
#  <W DOM="13" FEAT="S МН ИМ ОД" ID="6" LEMMA="ОНИ" LINK="предик">они</W>,
#  <W DOM="13" FEAT="PR" ID="7" KSNAME="В2" LEMMA="В" LINK="вводн">в</W>
#  <W DOM="7" FEAT="A ЕД СРЕД ПР" ID="8" LEMMA="ОБЩИЙ" LINK="предл">общем</W>,
#  <W DOM="10" FEAT="PART" ID="9" KSNAME="НИ2" LEMMA="НИ" LINK="огранич">ни</W>
#  <W DOM="13" FEAT="PR" ID="10" KSNAME="О2" LEMMA="О" LINK="2-компл">о</W>
#  <W DOM="10" FEAT="S ЕД СРЕД ПР НЕОД" ID="11" KSNAME="ЧТО2" LEMMA="ЧТО" LINK="предл">чем</W>
#  <W DOM="13" FEAT="PART" ID="12" KSNAME="НЕ1" LEMMA="НЕ" LINK="огранич">не</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="13" KSNAME="ГОВОРИТЬ2" LEMMA="ГОВОРИТЬ">говорят</W>,
#  <W DOM="16" FEAT="PART" ID="14" KSNAME="ТОЛЬКО1" LEMMA="ТОЛЬКО" LINK="огранич">только</W>
#  <W DOM="16" FEAT="ADV" ID="15" LEMMA="ЗЛОБНО" LINK="обст">злобно</W>
#  <W DOM="13" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="16" LEMMA="ОГЛЯДЫВАТЬ" LINK="сочин">оглядывают</W>
#  <W DOM="16" FEAT="S МН ВИН ОД" ID="17" LEMMA="ОКРУЖАЮЩИЕ" LINK="1-компл">окружающих</W>.
#  <LF LFARG="5" LFFUNC="_REAL1" LFPREP="4" LFVAL="1"/>
#  </S>,
#  <S ID="126">
#  <W DOM="11" FEAT="PR" ID="1" KSNAME="ПРИ" LEMMA="ПРИ" LINK="обст">При</W>
#  "<W DOM="1" FEAT="S ЕД СРЕД ПР НЕОД" ID="2" LEMMA="ПОХОЛОДАНИЕ" LINK="предл">похолодании</W>",
#  <W DOM="5" FEAT="ADV" ID="3" KSNAME="КОГДА1" LEMMA="КОГДА" LINK="обст">когда</W>
#  <W DOM="5" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="4" LEMMA="ТЕМПЕРАТУРА" LINK="предик">температура</W>
#  <W DOM="2" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="5" KSNAME="ПАДАТЬ2" LEMMA="ПАДАТЬ" LINK="релят">падает</W>
#  <W DOM="5" FEAT="PR" ID="6" KSNAME="ДО1" LEMMA="ДО" LINK="2-компл">до</W>
#  <W DOM="8" FEAT="S ЕД МУЖ ИМ НЕОД" ID="7" KSNAME="ПЛЮС1" LEMMA="ПЛЮС" LINK="огранич">плюс</W>
#  <W DOM="6" FEAT="NUM" ID="8" KSNAME="ЧИСЛ-БОЛЬШ" LEMMA="10" LINK="предл">10</W>,
#  <W DOM="11" FEAT="S МН ИМ ОД" ID="9" LEMMA="ОНИ" LINK="предик">они</W>
#  <W DOM="11" FEAT="ADV" ID="10" LEMMA="СРОЧНО" LINK="обст">срочно</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="11" LEMMA="ВОДРУЖАТЬ">водружают</W>
#  <W DOM="13" FEAT="A МН ВИН НЕОД" ID="12" LEMMA="ПЕСЦОВЫЙ" LINK="опред">песцовые</W>
#  <W DOM="11" FEAT="S МН ЖЕН ВИН НЕОД" ID="13" LEMMA="ШУБА" LINK="1-компл">шубы</W>
#  <W DOM="17" FEAT="A МН РОД" ID="14" LEMMA="РОЗОВЫЙ" LINK="опред">розовых</W>
#  <W DOM="14" FEAT="CONJ" ID="15" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="15" FEAT="A МН РОД" ID="16" LEMMA="БИРЮЗОВЫЙ" LINK="соч-союзн">бирюзовых</W>
#  <W DOM="13" FEAT="S МН МУЖ РОД НЕОД" ID="17" KSNAME="ТОН1" LEMMA="ТОН" LINK="атриб">тонов</W>
#  <W DOM="11" FEAT="PR" ID="18" KSNAME="НА1" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="21" FEAT="A МН ВИН НЕОД" ID="19" LEMMA="СВОЙ" LINK="опред">свои</W>
#  "<W DOM="21" FEAT="A МН ВИН НЕОД" ID="20" LEMMA="ХРУПКИЙ" LINK="опред">хрупкие</W>"
#  <W DOM="18" FEAT="S МН СРЕД ВИН НЕОД" ID="21" KSNAME="ПЛЕЧО1" LEMMA="ПЛЕЧО" LINK="предл">плечи</W>.
#  </S>,
#  <S ID="130">
#  <W DOM="2" FEAT="S МН ВИН ОД" ID="1" LEMMA="ОНИ" LINK="1-компл">Их</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="2" KSNAME="ВЫПИСЫВАТЬ2" LEMMA="ВЫПИСЫВАТЬ">выписывают</W>
#  <W DOM="2" FEAT="PR" ID="3" LEMMA="ИЗ-ЗА" LINK="2-компл">из-за</W>
#  <W DOM="3" FEAT="S ЕД ЖЕН РОД НЕОД" ID="4" LEMMA="ГРАНИЦА" LINK="предл">границы</W>
#  <W DOM="2" FEAT="PR" ID="5" LEMMA="В КАЧЕСТВЕ" LINK="обст">в качестве</W>
#  <W DOM="7" FEAT="V НЕСОВ ПРИЧ НЕПРОШ ЕД МУЖ РОД" ID="6" LEMMA="ОБСЛУЖИВАТЬ" LINK="опред">обслуживающего</W>
#  <W DOM="5" FEAT="S ЕД МУЖ РОД НЕОД" ID="7" LEMMA="ПЕРСОНАЛ" LINK="предл">персонала</W>.
#  </S>,
#  <S CLASS="LF" ID="146">
#  <W DOM="6" FEAT="PR" ID="1" KSNAME="С1" LEMMA="С" LINK="обст">С</W>
#  <W DOM="1" FEAT="S ЕД СРЕД РОД НЕОД" ID="2" KSNAME="НАЧАЛО1" LEMMA="НАЧАЛО" LINK="предл">начала</W>
#  <W DOM="4" FEAT="NUM" ID="3" LEMMA="XVIII" LINK="опред">XVIII</W>
#  <W DOM="2" FEAT="S ЕД МУЖ РОД НЕОД" ID="4" KSNAME="ВЕК" LEMMA="ВЕК" LINK="квазиагент">века</W>
#  <W DOM="6" FEAT="S ЕД МУЖ ИМ НЕОД" ID="5" LEMMA="БАДЕН" LINK="предик">Баден</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="6" LEMMA="ПРИОБРЕТАТЬ">приобретает</W>
#  <W DOM="6" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="7" LEMMA="ПОПУЛЯРНОСТЬ" LINK="1-компл">популярность</W>
#  <W DOM="6" FEAT="PR" ID="8" KSNAME="У1" LEMMA="У" LINK="1-несобст-компл">у</W>
#  <W DOM="10" FEAT="A ЕД ЖЕН РОД" ID="9" KSNAME="РУССКИЙ1" LEMMA="РУССКИЙ" LINK="опред">русской</W>
#  <W DOM="8" FEAT="S ЕД ЖЕН РОД НЕОД" ID="10" KSNAME="ЗНАТЬ2" LEMMA="ЗНАТЬ" LINK="предл">знати</W>,
#  <W DOM="6" FEAT="CONJ" ID="11" LEMMA="ТАК КАК" LINK="обст">так как</W>
#  <W DOM="13" FEAT="A ЕД ЖЕН ИМ" ID="12" LEMMA="БАДЕНСКИЙ" LINK="опред">баденская</W>
#  <W DOM="15" FEAT="S ЕД ЖЕН ИМ ОД" ID="13" LEMMA="ПРИНЦЕССА" LINK="предик">принцесса</W>
#  <W DOM="13" FEAT="S ЕД ЖЕН ИМ ОД" ID="14" LEMMA="ЛУИЗА" LINK="аппоз">Луиза</W>
#  <W DOM="11" FEAT="V СОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="15" KSNAME="ВЫХОДИТЬ1" LEMMA="ВЫХОДИТЬ" LINK="подч-союзн">вышла</W>
#  <W DOM="15" FEAT="ADV" ID="16" LEMMA="ЗАМУЖ" LINK="2-компл">замуж</W>
#  <W DOM="16" FEAT="PR" ID="17" KSNAME="ЗА1" LEMMA="ЗА" LINK="1-компл">за</W>
#  <W DOM="19" FEAT="A ЕД МУЖ ВИН ОД" ID="18" KSNAME="РУССКИЙ1" LEMMA="РУССКИЙ" LINK="опред">русского</W>
#  <W DOM="17" FEAT="S ЕД МУЖ ВИН ОД" ID="19" LEMMA="ЦАРЬ" LINK="предл">царя</W>
#  <W DOM="19" FEAT="S ЕД МУЖ ВИН ОД" ID="20" KSNAME="АЛЕКСАНДР" LEMMA="АЛЕКСАНДР" LINK="аппоз">Александра</W>
#  <W DOM="20" FEAT="NUM" ID="21" LEMMA="I" LINK="вспом">I</W>.
#  <LF LFARG="7" LFFUNC="_INCEPOPER1" LFVAL="6"/>
#  </S>,
#  <S ID="159">
#  <W DOM="12" FEAT="CONJ" ID="1" LEMMA="ЕСЛИ" LINK="обст">Если</W>
#  <W DOM="1" FEAT="V СОВ ИНФ" ID="2" LEMMA="ВСПОМИНАТЬ" LINK="инф-союзн">вспомнить</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ВИН ОД" ID="3" KSNAME="ГОГОЛЬ1" LEMMA="ГОГОЛЬ" LINK="1-компл">Гоголя</W>,
#  <W DOM="3" FEAT="S ЕД МУЖ ВИН ОД" ID="4" KSNAME="ДОСТОЕВСКИЙ" LEMMA="ДОСТОЕВСКИЙ" LINK="сочин">Достоевского</W>,
#  <W DOM="6" FEAT="PART" ID="5" KSNAME="ДА1" LEMMA="ДА" LINK="огранич">да</W>
#  <W DOM="9" FEAT="S ЕД СРЕД ИМ НЕОД" ID="6" KSNAME="ЧТО2" LEMMA="ЧТО" LINK="огранич">что</W>
#  <W DOM="6" FEAT="ADV" ID="7" LEMMA="ТАМ" LINK="вспом">там</W> -
#  "<W DOM="9" FEAT="A ЕД ЖЕН ВИН" ID="8" KSNAME="ПИКОВЫЙ2" LEMMA="ПИКОВЫЙ" LINK="опред">Пиковую</W>
#  <W DOM="4" FEAT="S ЕД ЖЕН ВИН ОД" ID="9" LEMMA="ДАМА" LINK="сочин">даму</W>",
#  <W DOM="12" FEAT="S МН ИМ ОД" ID="10" LEMMA="ВЫ" LINK="предик">вы</W>
#  <W DOM="12" FEAT="ADV" ID="11" LEMMA="СРАЗУ" LINK="обст">сразу</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 2-Л" ID="12" KSNAME="УЗНАВАТЬ1" LEMMA="УЗНАВАТЬ">узнаете</W>
#  <W DOM="14" FEAT="A МН ВИН ОД" ID="13" KSNAME="ВЕСЬ" LEMMA="ВЕСЬ" LINK="опред">всех</W>
#  <W DOM="12" FEAT="S МН МУЖ ВИН ОД" ID="14" KSNAME="ПЕРСОНАЖ1" LEMMA="ПЕРСОНАЖ" LINK="1-компл">персонажей</W>,
#  <W DOM="12" FEAT="A КР ЕД СРЕД" ID="15" LEMMA="ДОСТАТОЧНЫЙ" LINK="сент-соч">достаточно</W>
#  <W DOM="15" FEAT="V СОВ ИНФ" ID="16" KSNAME="ЗАХОДИТЬ1" LEMMA="ЗАХОДИТЬ" LINK="предик">зайти</W>
#  <W DOM="16" FEAT="PR" ID="17" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="17" FEAT="S ЕД СРЕД ВИН НЕОД" ID="18" LEMMA="КАЗИНО" LINK="предл">казино</W>
#  <W DOM="16" FEAT="PR" ID="19" KSNAME="НА1" LEMMA="НА" LINK="обст">на</W>
#  <W DOM="21" FEAT="NUM СЛ" ID="20" KSNAME="ПОЛ3" LEMMA="ПОЛ" LINK="количест">пол</W>
#  <W DOM="19" FEAT="S ЕД МУЖ РОД НЕОД" ID="21" KSNAME="ЧАС" LEMMA="ЧАС" LINK="предл">часа</W>!
#  </S>,
#  <S ID="173">
#  <W DOM="2" FEAT="A ЕД ЖЕН ИМ" ID="1" LEMMA="ПРЕСЫЩЕННЫЙ" LINK="опред">Пресыщенная</W>
#  <W DOM="8" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="2" LEMMA="ПУБЛИКА" LINK="предик">публика</W>,
#  <W DOM="8" FEAT="V НЕСОВ ДЕЕПР НЕПРОШ" ID="3" LEMMA="ПОПИВАТЬ" LINK="обст">попивая</W>
#  <W DOM="3" FEAT="S ЕД СРЕД ВИН НЕОД" ID="4" LEMMA="ШАМПАНСКОЕ" LINK="1-компл">шампанское</W>
#  <W DOM="4" FEAT="CONJ" ID="5" KSNAME="ИЛИ1" LEMMA="ИЛИ" LINK="сочин">или</W>
#  <W DOM="5" FEAT="S ЕД СРЕД ВИН НЕОД" ID="6" LEMMA="ВИНО" LINK="соч-союзн">вино</W>,
#  <W DOM="8" FEAT="ADV" ID="7" LEMMA="ЛЕНИВО" LINK="обст">лениво</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="8" LEMMA="СЛУШАТЬ">слушает</W>,
#  <W DOM="10" FEAT="ADV" ID="9" LEMMA="БЛАГОРОДНО" LINK="обст">благородно</W>
#  <W DOM="8" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="10" KSNAME="КЛАСТЬ" LEMMA="КЛАСТЬ" LINK="сочин">кладет</W>
#  <W DOM="10" FEAT="PR" ID="11" KSNAME="ПО4" LEMMA="ПО" LINK="1-компл">по</W>
#  <W DOM="13" FEAT="NUM" ID="12" KSNAME="ЧИСЛ-БОЛЬШ" LEMMA="5" LINK="количест">5</W>
#  <W DOM="11" FEAT="S МН МУЖ РОД НЕОД" ID="13" KSNAME="ЕВРО2" LEMMA="ЕВРО" LINK="предл">евро</W>
#  <W DOM="10" FEAT="PR" ID="14" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="16" FEAT="A ЕД ЖЕН ВИН" ID="15" LEMMA="ОБЩИЙ" LINK="опред">общую</W>
#  <W DOM="14" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="16" LEMMA="КАССА" LINK="предл">кассу</W>
#  <W DOM="10" FEAT="PR" ID="17" KSNAME="ЗА1" LEMMA="ЗА" LINK="обст">за</W>
#  <W DOM="19" FEAT="A ЕД СРЕД ВИН" ID="18" KSNAME="ФИКТ-ПРИЛ" LEMMA="2-ЧАСОВОЙ" LINK="опред">2-часовое</W>
#  <W DOM="17" FEAT="S ЕД СРЕД ВИН НЕОД" ID="19" KSNAME="ВЫСТУПЛЕНИЕ1" LEMMA="ВЫСТУПЛЕНИЕ" LINK="предл">выступление</W>
#  <W DOM="10" FEAT="CONJ" ID="20" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="20" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="21" KSNAME="ПЕРЕХОДИТЬ1" LEMMA="ПЕРЕХОДИТЬ" LINK="соч-союзн">переходит</W>,
#  <W DOM="23" FEAT="ADV" ID="22" LEMMA="ОЧЕНЬ" LINK="огранич">очень</W>
#  <W DOM="21" FEAT="A ЕД ЖЕН ИМ" ID="23" LEMMA="ДОВОЛЬНЫЙ" LINK="суб-копр">довольная</W>,
#  <W DOM="21" FEAT="PR" ID="24" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="24" FEAT="S ЕД СРЕД ВИН НЕОД" ID="25" LEMMA="КАЗИНО" LINK="предл">казино</W>
#  <W DOM="21" FEAT="V НЕСОВ ИНФ" ID="26" LEMMA="ИГРАТЬ" LINK="обст">играть</W>
#  <W DOM="26" FEAT="PR" ID="27" KSNAME="НА1" LEMMA="НА" LINK="обст">на</W>
#  <W DOM="27" FEAT="S МН МУЖ ВИН НЕОД" ID="28" LEMMA="МИЛЛИОН" LINK="предл">миллионы</W>.
#  </S>,
#  <S CLASS="LF" ID="186">
#  <W DOM="5" FEAT="PR" ID="1" KSNAME="В2" LEMMA="В" LINK="обст">В</W>
#  <W DOM="1" FEAT="S ЕД МУЖ ПР НЕОД" ID="2" LEMMA="КОНЕЦ" LINK="предл">конце</W>
#  <W DOM="2" FEAT="S ЕД ЖЕН РОД НЕОД" ID="3" LEMMA="ПРОЦЕДУРА" LINK="квазиагент">процедуры</W>
#  <W DOM="5" FEAT="S ЕД МУЖ ВИН ОД" ID="4" LEMMA="ТЫ" LINK="1-компл">тебя</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="5" KSNAME="ЗАВОРАЧИВАТЬ2" LEMMA="ЗАВОРАЧИВАТЬ">заворачивают</W>
#  <W DOM="5" FEAT="PR" ID="6" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="6" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="7" LEMMA="ПРОСТЫНЯ" LINK="предл">простыню</W>,
#  <W DOM="5" FEAT="CONJ" ID="8" KSNAME="И1" LEMMA="И" LINK="сент-соч">и</W>
#  <W DOM="10" FEAT="S ЕД МУЖ ИМ ОД" ID="9" LEMMA="ТЫ" LINK="предик">ты</W>
#  <W DOM="8" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 2-Л" ID="10" KSNAME="СПАТЬ" LEMMA="СПАТЬ" LINK="соч-союзн">спишь</W>
#  <W DOM="12" FEAT="NUM СЛ" ID="11" KSNAME="ПОЛ3" LEMMA="ПОЛ" LINK="количест">пол</W>
#  <W DOM="10" FEAT="S ЕД МУЖ РОД НЕОД" ID="12" KSNAME="ЧАС" LEMMA="ЧАС" LINK="длительн">часа</W>.
#  <LF LFARG="2" LFFUNC="_LOC" LFVAL="1"/>
#  </S>,
#  <S ID="193">
#  <W DOM="2" FEAT="A МН ИМ" ID="1" LEMMA="ВОСТОЧНЫЙ" LINK="опред">Восточные</W>
#  <W DOM="10" FEAT="S МН МУЖ ИМ ОД" ID="2" LEMMA="МУЖЧИНА" LINK="предик">мужчины</W>
#  <W DOM="2" FEAT="PART" ID="3" LEMMA="ЖЕ" LINK="огранич">же</W>,
#  <W DOM="10" FEAT="V СОВ ДЕЕПР ПРОШ" ID="4" LEMMA="ОСТАВЛЯТЬ" LINK="обст">оставив</W>
#  <W DOM="7" FEAT="A МН ВИН ОД" ID="5" LEMMA="СВОЙ" LINK="опред">своих</W>
#  <W DOM="7" FEAT="A МН ВИН ОД" ID="6" LEMMA="СМУГЛЫЙ" LINK="опред">смуглых</W>
#  <W DOM="4" FEAT="S МН ЖЕН ВИН ОД" ID="7" LEMMA="ЖЕНА" LINK="1-компл">жен</W>
#  <W DOM="7" FEAT="CONJ" ID="8" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="8" FEAT="S МН МУЖ ВИН ОД" ID="9" LEMMA="РЕБЕНОК" LINK="соч-союзн">детей</W>,
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ МН 3-Л" ID="10" LEMMA="СТРЕМИТЬСЯ">стремятся</W>
#  <W DOM="10" FEAT="PR" ID="11" KSNAME="В1" LEMMA="В" LINK="2-компл">в</W>
#  <W DOM="11" FEAT="S МН ЖЕН ВИН НЕОД" ID="12" LEMMA="САУНА" LINK="предл">сауны</W> -
#  <W DOM="14" FEAT="ADV" ID="13" LEMMA="ВДОВОЛЬ" LINK="обст">вдоволь</W>
#  <W DOM="10" FEAT="V СОВ ИНФ" ID="14" LEMMA="НАСМОТРЕТЬСЯ" LINK="разъяснит">насмотреться</W>
#  <W DOM="14" FEAT="PR" ID="15" KSNAME="НА1" LEMMA="НА" LINK="1-компл">на</W>
#  <W DOM="17" FEAT="A МН ВИН ОД" ID="16" LEMMA="ЕВРОПЕЙСКИЙ" LINK="опред">европейских</W>
#  <W DOM="15" FEAT="S МН ЖЕН ВИН ОД" ID="17" LEMMA="ЖЕНЩИНА" LINK="предл">женщин</W>
#  <W DOM="17" FEAT="PR" ID="18" KSNAME="В2" LEMMA="В" LINK="атриб">в</W>
#  <W DOM="18" FEAT="S ЕД СРЕД ПР НЕОД" ID="19" KSNAME="НЕГЛИЖЕ1" LEMMA="НЕГЛИЖЕ" LINK="предл">неглиже</W>.
#  </S>,
#  <S ID="197">
#  <W DOM="2" FEAT="A ЕД ЖЕН ИМ" ID="1" LEMMA="ПОСЛЕДНИЙ" LINK="опред">Последняя</W>
#  <W DOM="19" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="2" LEMMA="ВЫСТАВКА" LINK="предик">выставка</W>
#  <W DOM="2" FEAT="S ЕД МУЖ РОД ОД" ID="3" KSNAME="РИХТЕР1" LEMMA="РИХТЕР" LINK="1-компл">Рихтера</W>,
#  <W DOM="2" FEAT="V СОВ СТРАД ПРИЧ ПРОШ ЕД ЖЕН ИМ" ID="4" KSNAME="ПОСВЯЩАТЬ1" LEMMA="ПОСВЯЩАТЬ" LINK="опред">посвященная</W>
#  <W DOM="4" FEAT="S МН МУЖ ДАТ НЕОД" ID="5" LEMMA="ЛАГЕРЬ" LINK="2-компл">лагерям</W>
#  <W DOM="5" FEAT="CONJ" ID="6" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="6" FEAT="S ЕД МУЖ ДАТ НЕОД" ID="7" LEMMA="ФАШИЗМ" LINK="соч-союзн">фашизму</W>,
#  <W DOM="2" FEAT="PR" ID="8" KSNAME="С3" LEMMA="С" LINK="атриб">с</W>
#  <W DOM="14" FEAT="V СОВ СТРАД ПРИЧ ПРОШ МН ТВОР" ID="9" KSNAME="РАСКАТЫВАТЬ2" LEMMA="РАСКАТЫВАТЬ" LINK="опред">раскатанными</W>
#  <W DOM="9" FEAT="PR" ID="10" KSNAME="ПО1" LEMMA="ПО" LINK="обст">по</W>
#  <W DOM="12" FEAT="A МН ДАТ" ID="11" LEMMA="ОГРОМНЫЙ" LINK="опред">огромным</W>
#  <W DOM="10" FEAT="S МН МУЖ ДАТ НЕОД" ID="12" LEMMA="ХОЛСТ" LINK="предл">холстам</W>
#  <W DOM="14" FEAT="A ЕД ЖЕН ТВОР" ID="13" LEMMA="БОРДОВЫЙ" LINK="опред">бордовой</W>
#  <W DOM="8" FEAT="S ЕД ЖЕН ТВОР НЕОД" ID="14" LEMMA="КРАСКА" LINK="предл">краской</W>
#  <W DOM="14" FEAT="CONJ" ID="15" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="15" FEAT="S ЕД МУЖ ТВОР НЕОД" ID="16" LEMMA="ПЕСОК" LINK="соч-союзн">песком</W>,
#  <W DOM="14" FEAT="V НЕСОВ ПРИЧ НЕПРОШ МН ТВОР" ID="17" LEMMA="ИМИТИРОВАТЬ" LINK="опред">имитирующими</W>
#  <W DOM="17" FEAT="S ЕД ЖЕН ВИН НЕОД" ID="18" LEMMA="КРОВЬ" LINK="1-компл">кровь</W>,
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ ПРОШ ЕД ЖЕН" ID="19" KSNAME="БЫТЬ" LEMMA="БЫТЬ">была</W>
#  <W DOM="19" FEAT="A КР ЕД ЖЕН" ID="20" LEMMA="ЧУДОВИЩНЫЙ" LINK="присвяз">чудовищна</W>.
#  </S>,
#  <S CLASS="LF" ID="223">
#  <W DOM="_root" FEAT="CONJ" ID="1" LEMMA="НО">Но</W>
#  <W DOM="5" FEAT="PART" ID="2" LEMMA="ВСЕ ЖЕ" LINK="огранич">все же</W>
#  <W DOM="5" FEAT="PR" ID="3" KSNAME="В1" LEMMA="В" LINK="обст">в</W>
#  <W DOM="3" FEAT="S ЕД СРЕД ВИН НЕОД" ID="4" KSNAME="ЗАКЛЮЧЕНИЕ2" LEMMA="ЗАКЛЮЧЕНИЕ" LINK="предл">заключение</W>
#  <W DOM="1" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="5" LEMMA="ХОТЕТЬ" LINK="соч-союзн">хочу</W>
#  <W DOM="5" FEAT="V СОВ ИНФ" ID="6" LEMMA="СКАЗАТЬ" LINK="1-компл">сказать</W>,
#  <W DOM="6" FEAT="CONJ" ID="7" KSNAME="ЧТО1" LEMMA="ЧТО" LINK="1-компл">что</W>
#  <W DOM="9" FEAT="ADV" ID="8" LEMMA="ЧАСТО" LINK="обст">часто</W>
#  <W DOM="7" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="9" LEMMA="СМОТРЕТЬ" LINK="подч-союзн">смотрю</W>
#  <W DOM="9" FEAT="PR" ID="10" KSNAME="НА1" LEMMA="НА" LINK="1-компл">на</W>
#  <W DOM="12" FEAT="A ЕД СРЕД ВИН" ID="11" LEMMA="ДИВНЫЙ" LINK="опред">дивное</W>
#  <W DOM="10" FEAT="S ЕД СРЕД ВИН НЕОД" ID="12" KSNAME="НЕБО1" LEMMA="НЕБО" LINK="предл">небо</W>
#  <W DOM="12" FEAT="PR" ID="13" KSNAME="НАД" LEMMA="НАД" LINK="атриб">над</W>
#  <W DOM="13" FEAT="S ЕД МУЖ ТВОР НЕОД" ID="14" LEMMA="БАДЕН" LINK="предл">Баденом</W>,
#  <W DOM="12" FEAT="V СОВ СТРАД ПРИЧ ПРОШ ЕД СРЕД ВИН" ID="15" LEMMA="ПОКРЫВАТЬ" LINK="опред">покрытое</W>
#  <W DOM="18" FEAT="A МН ТВОР" ID="16" LEMMA="ЛЕГКИЙ" LINK="опред">легкими</W>
#  <W DOM="18" FEAT="A МН ТВОР" ID="17" LEMMA="ПЕРИСТЫЙ" LINK="опред">перистыми</W>
#  <W DOM="15" FEAT="S МН СРЕД ТВОР НЕОД" ID="18" LEMMA="ОБЛАКО" LINK="2-компл">облаками</W>,
#  <W DOM="10" FEAT="PR" ID="19" KSNAME="НА1" LEMMA="НА" LINK="сочин">на</W>
#  <W DOM="21" FEAT="A МН ВИН НЕОД" ID="20" LEMMA="РОЗОВЫЙ" LINK="опред">розовые</W>
#  <W DOM="19" FEAT="S МН МУЖ ВИН НЕОД" ID="21" LEMMA="ЗАКАТ" LINK="предл">закаты</W>,
#  <W DOM="19" FEAT="PR" ID="22" KSNAME="НА1" LEMMA="НА" LINK="сочин">на</W>
#  <W DOM="24" FEAT="A ЕД ЖЕН ВИН" ID="23" LEMMA="СЕРЕБРЯНЫЙ" LINK="опред">серебряную</W>
#  <W DOM="22" FEAT="S ЕД ЖЕН ВИН ОД" ID="24" KSNAME="ЗМЕЙКА1" LEMMA="ЗМЕЙКА" LINK="предл">змейку</W>
#  <W DOM="24" FEAT="S ЕД ЖЕН РОД НЕОД" ID="25" LEMMA="РЕКА" LINK="атриб">реки</W>,
#  <W DOM="22" FEAT="PR" ID="26" KSNAME="НА1" LEMMA="НА" LINK="сочин">на</W>
#  <W DOM="28" FEAT="A МН ВИН НЕОД" ID="27" LEMMA="ВЕКОВОЙ" LINK="опред">вековые</W>
#  <W DOM="26" FEAT="S МН ЖЕН ВИН НЕОД" ID="28" LEMMA="СЕКВОЙЯ" LINK="предл">секвойи</W>
#  <W DOM="28" FEAT="CONJ" ID="29" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="29" FEAT="S МН ЖЕН ВИН НЕОД" ID="30" LEMMA="СОСНА" LINK="соч-союзн">сосны</W>,
#  <W DOM="9" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="31" LEMMA="ВСПОМИНАТЬ" LINK="сочин">вспоминаю</W>
#  <W DOM="34" FEAT="A ЕД МУЖ ВИН ОД" ID="32" LEMMA="СВОЙ" LINK="опред">своего</W>
#  <W DOM="34" FEAT="A ЕД МУЖ ВИН ОД" ID="33" KSNAME="ЛЮБИМЫЙ1" LEMMA="ЛЮБИМЫЙ" LINK="опред">любимого</W>
#  <W DOM="31" FEAT="S ЕД МУЖ ВИН ОД" ID="34" KSNAME="ОТЕЦ1" LEMMA="ОТЕЦ" LINK="1-компл">отца</W>
#  <W DOM="31" FEAT="CONJ" ID="35" KSNAME="И1" LEMMA="И" LINK="сочин">и</W>
#  <W DOM="35" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="36" LEMMA="ЗАБЫВАТЬ" LINK="соч-союзн">забываю</W>
#  <W DOM="36" FEAT="PR" ID="37" KSNAME="О2" LEMMA="О" LINK="2-компл">о</W>
#  <W DOM="37" FEAT="S ЕД ЖЕН ПР НЕОД" ID="38" LEMMA="ГРУСТЬ" LINK="предл">грусти</W>,
#  <W DOM="37" FEAT="PR" ID="39" KSNAME="О2" LEMMA="О" LINK="сочин">о</W>
#  <W DOM="39" FEAT="S МН СРЕД ПР НЕОД" ID="40" LEMMA="СОЖАЛЕНИЕ" LINK="предл">сожалениях</W>,
#  <W DOM="39" FEAT="PR" ID="41" KSNAME="О2" LEMMA="О" LINK="сочин">об</W>
#  <W DOM="43" FEAT="V СОВ ПРИЧ ПРОШ МН ПР" ID="42" KSNAME="УХОДИТЬ1" LEMMA="УХОДИТЬ" LINK="опред">ушедших</W>
#  <W DOM="41" FEAT="S МН МУЖ ПР ОД" ID="43" LEMMA="ЧЕЛОВЕК" LINK="предл">людях</W>,
#  <W DOM="41" FEAT="PR" ID="44" KSNAME="О2" LEMMA="О" LINK="сочин">о</W>
#  <W DOM="46" FEAT="A МН ПР" ID="45" LEMMA="ПОТЕРЯННЫЙ" LINK="опред">потерянных</W>
#  <W DOM="44" FEAT="S МН СРЕД ПР НЕОД" ID="46" KSNAME="ОТНОШЕНИЕ1" LEMMA="ОТНОШЕНИЕ" LINK="предл">отношениях</W>.
#  <LF LFARG="18" LFFUNC="_ANTIMAGN" LFVAL="16"/>
#  </S>,
#  <S ID="225">
#  <W DOM="2" FEAT="S ЕД МУЖ ИМ ОД" ID="1" LEMMA="Я" LINK="предик">Я</W>
#  <W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 1-Л" ID="2" LEMMA="ВСПОМИНАТЬ">вспоминаю</W>
#  <W DOM="4" FEAT="A ЕД МУЖ ВИН НЕОД" ID="3" LEMMA="ЗНАМЕНИТЫЙ" LINK="опред">знаменитый</W>
#  <W DOM="2" FEAT="S ЕД МУЖ ВИН НЕОД" ID="4" LEMMA="АКАФИСТ" LINK="1-компл">Акафист</W>
#  <W DOM="4" FEAT="S ЕД МУЖ РОД ОД" ID="5" LEMMA="МИТРОПОЛИТ" LINK="квазиагент">митрополита</W>
#  <W DOM="5" FEAT="S ЕД МУЖ РОД ОД" ID="6" LEMMA="ТРИФОН" LINK="аппоз">Трифона</W>
#  "<W DOM="4" FEAT="S ЕД ЖЕН ИМ НЕОД" ID="7" KSNAME="СЛАВА1" LEMMA="СЛАВА" LINK="аппоз">Слава</W>
#  <W DOM="7" FEAT="S ЕД МУЖ ДАТ ОД" ID="8" LEMMA="БОГ" LINK="дат-сент">Богу</W>
#  <W DOM="7" FEAT="PR" ID="9" KSNAME="ЗА1" LEMMA="ЗА" LINK="атриб">за</W>
#  <W DOM="9" FEAT="S ЕД СРЕД ВИН НЕОД" ID="10" KSNAME="ВСЕ1" LEMMA="ВСЕ" LINK="предл">все</W>!",
#  <W DOM="2" FEAT="CONJ" ID="11" KSNAME="И1" LEMMA="И" LINK="сент-соч">и</W>
#  <W DOM="13" FEAT="S ЕД СРЕД ИМ НЕОД" ID="12" KSNAME="ВСЕ1" LEMMA="ВСЕ" LINK="предик">все</W>
#  <W DOM="11" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="13" LEMMA="ВСТАВАТЬ" LINK="соч-союзн">встает</W>
#  <W DOM="13" FEAT="PR" ID="14" KSNAME="НА1" LEMMA="НА" LINK="2-компл">на</W>
#  <W DOM="16" FEAT="A МН ВИН НЕОД" ID="15" LEMMA="СВОЙ" LINK="опред">свои</W>
#  <W DOM="14" FEAT="S МН СРЕД ВИН НЕОД" ID="16" LEMMA="МЕСТО" LINK="предл">места</W>,
#  <W DOM="13" FEAT="CONJ" ID="17" KSNAME="И1" LEMMA="И" LINK="сент-соч">и</W>
#  <W DOM="17" FEAT="ADV" ID="18" LEMMA="МОЖНО" LINK="соч-союзн">можно</W>
#  <W DOM="18" FEAT="V НЕСОВ ИНФ" ID="19" LEMMA="ЖИТЬ" LINK="предик">жить</W>
#  <W DOM="19" FEAT="ADV" ID="20" LEMMA="ДАЛЬШЕ" LINK="обст">дальше</W>…
#  </S>]

# %%
cur_sent = sents[1]
num_left = 2
num_right = 2

left = []
right = []
for i, prev_ in enumerate(cur_sent.previous_siblings):
    if prev_ is not None and not isinstance(prev_, str):
        left.append(prev_)
        
    if len(left) >= num_left or prev_ is None:
        break

for i, next_ in enumerate(cur_sent.next_siblings):
    if next_ is not None and not isinstance(next_, str):
        right.append(next_)
        
    if len(right) >= num_right or next_ is None:
        break

left_context = '' if not left else ' '.join(get_text_from_sentence(prev_) for prev_ in left)
right_context = '' if not right else ' '.join(get_text_from_sentence(next_) for next_ in right)

# %%
cur_sent['ID']
# Out:
# '2'

# %%
left_context
# Out:
# 'Мария Орлова'

# %%
right_context
# Out:
# 'Вот уже полтора года живу я в этом красивом, зеленом курортном, провинциальном, холодном и чопорном городишке. "Здесь русский дух…"'

# %%
res, tokens, text = parse_sent(sents[45], get_pos_to_feats_format(), return_tokens_list_text=True)

# %%
res
# Out:
# []

# %%
tokens
# Out:
# Sentence([Word({'form': 'лошадей', 'id': 1, 'dom': 2, 'link': 'предик', 'lemma': 'лошадь', 'feat': {'gender': 'жен', 'number': 'мн', 'case': 'род', 'animacy': 'од'}, 'pos': 'S'}, children={1: [Word({'form': 'породистых', 'id': 3, 'dom': 1, 'link': 'оп-опред', 'lemma': 'породистый', 'feat': {'number': 'мн', 'case': 'род'}, 'pos': 'A'}, children={1: [Word({'form': 'и', 'id': 4, 'dom': 3, 'link': 'сочин', 'lemma': 'и', 'feat': {}, 'pos': 'CONJ'}, children={1: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 3: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'и', 'id': 4, 'dom': 3, 'link': 'сочин', 'lemma': 'и', 'feat': {}, 'pos': 'CONJ'}, children={1: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 3: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 4: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]}), Word({'form': 'много', 'id': 2, 'dom': _root, 'link': '_root', 'lemma': 'много', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'лошадей', 'id': 1, 'dom': 2, 'link': 'предик', 'lemma': 'лошадь', 'feat': {'gender': 'жен', 'number': 'мн', 'case': 'род', 'animacy': 'од'}, 'pos': 'S'}, children={1: [Word({'form': 'породистых', 'id': 3, 'dom': 1, 'link': 'оп-опред', 'lemma': 'породистый', 'feat': {'number': 'мн', 'case': 'род'}, 'pos': 'A'}, children={1: [Word({'form': 'и', 'id': 4, 'dom': 3, 'link': 'сочин', 'lemma': 'и', 'feat': {}, 'pos': 'CONJ'}, children={1: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 3: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'и', 'id': 4, 'dom': 3, 'link': 'сочин', 'lemma': 'и', 'feat': {}, 'pos': 'CONJ'}, children={1: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 2: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'огранич', 'lemma': 'не', 'feat': {}, 'pos': 'PART'}, children={})]})], 3: [Word({'form': 'очень', 'id': 6, 'dom': 4, 'link': 'соч-союзн', 'lemma': 'очень', 'feat': {}, 'pos': 'ADV'}, children={1: [Word({'form': 'не', 'id': 5, 'dom': 6, 'link': 'о ...

# %%
def get_text_from_sentence(sent: bs4.element.Tag) -> str:
    return (''.join(fragment for fragment in sent.strings).strip()
        .replace('\n', ' ').replace('  ', ' ')
    )

# %%
def parse_feat(
    feat: str,
    pos_to_feats_formats: Dict[str, Dict[str, List[str]]],
) -> Dict[str, str]:
    result = {}
    
    features = feat.split()
    pos = features[0]
    
    result['pos'] = pos
    if pos not in pos_to_feats_formats:
        if len(features) > 1:
            print(f'`{pos}` not in pos_to_feats_formats, '
                  f'but there are {len(features) - 1} values unparsed: '
                  f'`{features[1:]}`'
            )
        
        return result
    
    feats_left_str = ' '.join(features[1:]).lower()
    for param, possible_values in pos_to_feats_formats[pos].items():

        for value in possible_values:
            value_regex = rf'\b{value}\b'
            value_match = re.search(value_regex, feats_left_str)

            if value_match:
                result[param] = value_match.group(0)
                feats_left_str = feats_left_str.replace(value_match.group(0), '')
                break
                
    if feats_left_str.replace(' ', '') != '':  # are there only spaces left?
        print(f"all params from pos_to_feats_formats were parsed, "
              f"but there is something left in string `{feats_left_str.strip()}` "
              f"orig `{feat}`"
        )
    
    return result

# %%
class Word(object):
    def __init__(
        self, word_dict: Dict[str, str], children: Optional[Dict[int, List['Word']]] = None,
        mandatory_attributes = ['dom', 'id']
    ):
        if any(attr not in word_dict for attr in mandatory_attributes):
            raise ValueError(f'no `dom` or `id` in word_dict `{word_dict}`')
        
        self.attrs = ['dom', 'feat', 'id', 'lemma', 'link', 'form']
        self.id = word_dict['id']
        self.dom = word_dict['dom']
        link = word_dict.get('link')
        self.link = link if link else '_root'
        self.form = word_dict['form']
        self.lemma = word_dict['lemma']
        
        # TODO: add condition to only do the search for non-verbs?
        #   (to prevent `bylo` in `(kto) by to ni bylo` from messing up `bylo` verb)
        if (any(
                re.search(rf'\b{modif}\b', self.lemma)
                for modif in PRON_ONLY_MODIFIERS
            ) or any(self.lemma == pron for pron in PRONS)
        ):
            self.pos = 'PRON'
        else:
            self.pos = word_dict['pos'] 
        
        self.feat = word_dict['feat']
        if 'ksname' in word_dict:
            self.ksname = word_dict['ksname']
            self.attrs.append('ksname')
        if 'nodetype'in word_dict:
            self.nodetype = word_dict['nodetype']
            
        if any(attr not in self.__dict__ for attr in word_dict):
            print(f'word_dict not parsed fully: {word_dict}')
        
        self.children: Dict[int, List['Word']] = {}
        if children:
            self.children = children
        self.parent = None
    
    
    def add_child(self, child: 'Word', depth: int):
        self.children.setdefault(depth, []).append(child)
        if depth == 1:
            child.parent = self
        if self.parent:
            self.parent.add_child(child, depth+1) 
       
    
    def filter_out_appos_groups(self) -> Dict[int, List['Word']]:
        # TODO: exclude groups that depend on target word but are linearly away
        full_group = self.group
        children = self.children 
        
        words_in_appos_groups = list(chain(
            *[appos_head.group
              for appos_head in full_group
              if appos_head.link == 'оп-опред']
        ))
        
        # NEW
#         potential_distant_dependents = list(chain(
#             *[dep_head.group
#               for dep_head in direct_dependents[0]
#               if dep_head.id != self.id + 1
#              ]
#         ))
#         potential_distant_dependents = []
#         for pot_dist_dep in potential_distant_dependents:
#             if pot_dist
        # NEW: save whether word group has appositive dependents
        if not words_in_appos_groups:
            self.has_appos = 0
            return children

        else:
            self.has_appos=1
            filtered_children_dict = {}
            for depth, children in self.children.items():
                for child in children:
                    if child in words_in_appos_groups:
                        continue
                    filtered_children_dict.setdefault(depth, []).append(child)

            return filtered_children_dict
    
    
    def get_children_depth(self, exclude_appos_groups=False):
        if exclude_appos_groups:
            children = self.filter_out_appos_groups()
        else:
            children = self.children
        return max(children.keys(), default=0)    
    children_depth = property(get_children_depth)
    
    def get_children_depth_no_appos(self):
        return self.get_children_depth(exclude_appos_groups=True)
    no_appos_children_depth = property(get_children_depth_no_appos)
    
    
    def get_group(self, depth=None, add_root=True, exclude_appos_groups=False):
        if exclude_appos_groups:
            children_dct = self.filter_out_appos_groups()
        else:
            children_dct = self.children
        if depth:
            children = list(chain(*[children_dct[d] for d in children_dct.keys() if d <= depth]))
        else:
            children = list(chain(*children_dct.values()))        
        if add_root:
            children += [self]
        return children
    group = property(get_group)
    
    
    def get_group_str(self, **kwargs):
        group = self.get_group(**kwargs)
        try:
            group_str = ' '.join([
                child.form
                for child in sorted(group, key = lambda word: int(getattr(word, 'id')))
            ])
        except (TypeError) as e:
            print(self, *group, sep='\n')
            raise(e)
            
        return group_str
    group_str = property(get_group_str) 
    
    def get_group_no_appos(self, **kwargs):
        return self.get_group(exclude_appos_groups=True, **kwargs)
    no_appos_group = property(get_group_no_appos)
    
    def get_group_str_no_appos(self, **kwargs):
        return self.get_group_str(exclude_appos_groups=True, **kwargs)
    no_appos_group_str = property(get_group_str_no_appos)
    
    
    def to_dict(self):
        # можно бы и word_dict...
        return {attr: getattr(self, attr) for attr in self.attrs}
    
    
    def __repr__(self):
        return (
            f"""Word({{'form': '{self.form}', 'id': {self.id}, """
            f"""'dom': {self.dom}, 'link': '{self.link}', """
            f"""'lemma': '{self.lemma}', 'feat': {self.feat}, """
            f"""'pos': '{self.pos}'}}, children={self.children})"""
        )
    
    
    def __str__(self):
        children = chain(*self.children.values())
        parent = self.parent
        return (
            f"""<Word({{'form': '{self.form}', 'id': {self.id}, """
            f"""'dom': {self.dom}, 'link': '{self.link}', 'pos': '{self.pos}' """
            f"""'lemma': '{self.lemma}', 'feat': {self.feat}}}, """
            f"""children={[(child.id, child.form) for child in children]}), """
            f"""parent={None if not parent else (parent.id, parent.form)}>"""
        )

# %%
class TokensList(list):
    def filter(self, **kwargs):
        if not kwargs:
            return 
        
        res = TokensList()
        
        def get_val(attr, word):
            if 'feat__' in attr:
                return getattr(word, 'feat').get(attr.split('__')[1])
            else:
                return None or getattr(word, attr)

        for word in self:
            if all(get_val(attr, word) == value for attr, value in kwargs.items()):
                res.append(word)        
        return res    
    
    def __repr__(self):
        list_repr = super().__repr__()
        return f'{self.__class__.__name__}({list_repr})'
    

class Sentence(TokensList):
    pass

# %%
def make_tree(
    root: Word,
    depth: int,
    words: List[Word],    
) -> None:    
    children = [word for word in words if word.dom == root.id]

    for word in children:
        root.add_child(word, 1)
        make_tree(word, 1, words)

# %%
def make_full_tree(
    words: List[WordDict],
) -> None:  
    
#     for word in words:
#         id_to_word[word.id] = word
    
    root = next(word for word in words if word.dom == '_root')
    words.root = root
    
    depth = 1
    make_tree(root, depth, words)

# %%
def get_pos_chain(
    words: List, include_feat=False, include_feat_name=False,
    word_sep=' ', pos_feat_sep='+', feat_sep='|',
    feat_name_val_sep = '=',
) -> str:
    
    word_strs = []
    for word in words:
        word_str = word.pos
        if include_feat and include_feat_name:
            feat_str = feat_sep.join(
                [f'{feat}{feat_name_val_sep}{val}'
                for feat, val in word.feat.items()]
            )
        elif include_feat:
            feat_str = feat_sep.join(word.feat.values())
        else:
            feat_str = ''
            
        word_str += f'{pos_feat_sep}{feat_str}' if feat_str else ''
        word_strs.append(word_str)
        
    return word_sep.join(word_strs)

# %%
def feats_dict_to_str(feats_dict: Dict[str, Union[str, int]]) -> str:
    return '|'.join([f'{feat}={val}' for feat, val in feats_dict.items()])

# %%
def has_relative_clause(word_group: List[Word]) -> bool:
    has_wh_relcl = any(word.link == 'релят' for word in word_group)
    has_participle = False
    
    # тоже можно изменить на any
    for word in word_group:
        if word.pos == 'V' and word.feat.get('representation') == 'прич':
            has_participle = True
            break
    has_relcl = has_wh_relcl or has_participle
    return has_relcl, has_wh_relcl, has_participle

# %%
def get_data_from_sent(
    full_analysis: str, text: str, words: Sentence,
    sent_number: int, context: Tuple[str],
    exclude_appos_descriptions=True
) -> List[Res]:
    res = []
    
    sent_chain = get_pos_chain(words)
    
    for verb in words.filter(pos='V'):
        dos = words.filter(dom=verb.id, feat__case='вин', link='1-компл')
        secos = words.filter(dom=verb.id, link='2-компл')
        
        if not (dos and secos):
            continue
        
        has_many_dos, has_many_ios = 0, 0
        if len(dos) >= 2:
            has_many_dos = 1
            print(len(dos))
        if len(secos) >= 2:
            has_many_ios = 1
            print(len(secos))
        do = dos[0]
        seco = secos[0]
        
        if exclude_appos_descriptions:
            do_group, do_group_str = do.no_appos_group, do.no_appos_group_str
            seco_group, seco_group_str = seco.no_appos_group, seco.no_appos_group_str
            do_children_depth = do.no_appos_children_depth
            seco_children_depth = seco.no_appos_children_depth
        else:
            do_group, do_group_str = do.group, do.group_str
            seco_group, seco_group_str = seco.group, seco.group_str
            do_children_depth = do.children_depth
            seco_children_depth = seco.children_depth
        
        do_had_appos = do.__dict__.get('has_appos', '')
        seco_had_appos = seco.__dict__.get('has_appos', '')
        
        (do_has_relcl, do_has_wh_relcl, 
         do_has_participle) = has_relative_clause(do_group)
        (seco_has_relcl, seco_has_wh_relcl, 
         seco_has_participle) = has_relative_clause(seco_group)
        
        do_pos_feat_chain = get_pos_chain(
            do_group, include_feat=True, include_feat_name=True
        )
        seco_pos_feat_chain = get_pos_chain(
            seco_group, include_feat=True, include_feat_name=True
        )
        
        verb_feats = feats_dict_to_str(verb.feat)
        verb_has_neg = 1 if words.filter(dom=verb.id, pos='PART', lemma='не') else 0
        
        seco_head_pos = 'PR' if seco.pos == 'PR' else 'V'
        if seco_head_pos == 'PR':
            seco_head = seco.form
            seco = words.filter(dom=seco.id, link='предл')[0]
        else:
            seco_head = verb.form
        
        id_to_role = {do.id: 'DO', verb.id: 'V', seco.id: 'IO'}
        order = sorted(
            [verb] + [do, seco],
            key=lambda token: token.id,
        )
        roles_order = ' '.join(id_to_role[token.id] for token in order)
        
        has_nodetype_in_our_forms = 0
        if any('nodetype' in word.__dict__ for word in chain(*[[verb], do_group, seco_group])):
            has_nodetype_in_our_forms = 1
        
        res.append(Res(
            sent_number, context[0], text, context[1],
                full_analysis, sent_chain,
            has_many_dos, has_many_ios,
            has_nodetype_in_our_forms,
            verb.lemma, verb.form,
            verb_feats, verb_has_neg,
            do_group_str, seco_group_str, 
                do_had_appos, seco_had_appos,
                do_has_relcl, seco_has_relcl,
                    do_has_wh_relcl, seco_has_wh_relcl,
                    do_has_participle, seco_has_participle,
                do_children_depth, seco_children_depth,
                    len(do_group), len(seco_group),
                do_pos_feat_chain, seco_pos_feat_chain,
            do.form,
            do.pos, do.lemma, do.feat.get('animacy', ''),
                do.feat.get('case', ''), do.feat.get('number', ''),
            seco.form,
            seco.pos, seco_head, seco_head_pos, seco.lemma,
                seco.feat.get('animacy', ''), seco.feat.get('case', ''),
                seco.feat.get('number', ''),
            roles_order
        ))
        
    return res

# %%
def get_context(
    sent: bs4.element.Tag,
    left_context_len = 2,
    right_context_len = 2,
):
    left = []
    right = []
    for i, prev_ in enumerate(sent.previous_siblings):
        if prev_ is not None and not isinstance(prev_, str):
            left.append(prev_)

        if len(left) >= num_left or prev_ is None:
            break

    for i, next_ in enumerate(sent.next_siblings):
        if next_ is not None and not isinstance(next_, str):
            right.append(next_)

        if len(right) >= num_right or next_ is None:
            break

    left_context = '' if not left else ' '.join(get_text_from_sentence(prev_) for prev_ in left)
    right_context = '' if not right else ' '.join(get_text_from_sentence(next_) for next_ in right) 
    
    return left_context, right_context

# %%
def parse_sent(
    sent: bs4.element.Tag,
    pos_to_feats_formats: Dict[str, Dict[str, List[str]]],
    return_tokens_list_text: bool = False,
    return_context: bool = True,
    left_context_len: int = 2, right_context_len: int = 2,
    word_tag: str = 'W',
    data_from_sent_kwargs={},
):
    
    words = Sentence()
    for word in sent.find_all(word_tag, recursive=False):
        word_res = {}
        for attr, value in word.attrs.items():
            attr = attr.lower()
            if attr not in ['dom', 'id'] or value == '_root':
                word_res[attr] = value
            else:
                word_res[attr] = int(value)
                
#         word_res = {
#             attr.lower(): (value if (attr not in ['DOM', 'ID'] or value == '_root') else int(value))
#             for attr, value in word.attrs.items()
#         }
        word_res['lemma'] = word_res.get('lemma', '').lower()
        word_res['feat'] = parse_feat(word_res['feat'], pos_to_feats_formats)
        word_res['pos'] = word_res['feat'].pop('pos')
        word_form = word.string or ''
        word_res['form'] = word_form.lower()
        word_obj = Word(word_res)
        
        words.append(word_obj)
    
    make_full_tree(words)
    sent_number = sent.get('ID')
    text = get_text_from_sentence(sent)
    
    left_context, right_context = '', ''
    if return_context:
        left_context, right_context = get_context(sent, left_context_len, right_context_len)
    context = (left_context, right_context)

    res = get_data_from_sent(str(sent), text, words, sent_number, context, **data_from_sent_kwargs)
    if not return_tokens_list_text:
        return res
    else:
        return res, words, text

# %%
file = syntagrus_dir / Path('2019/baden-baden.tgt')

# %%
file_soup = get_soup(file).find('body')

# %%
sents = file_soup.find_all('S')

# %%
res, tokens, text = parse_sent(sents[9], get_pos_to_feats_format(), return_tokens_list_text=True)

# %%
res
# Out:
# [res(sent_num_file='10', left_context='Он чувствовал себя здесь русским, потерянным и оторванным от корней… Тургенев в течение семи лет бродил тут с собакой по окрестным лесам и горам, искал, думал, страдал.', text='Это чувство родства с ним дает мне силы жить здесь.', right_context='Элементы русской архитектуры - резные деревянные балкончики и наличники - напоминают Абрамцево, белоснежные и бледно-розовые усадьбы, заросшие сиренью, возвращают меня в нашу тихую подмосковную жизнь. Из влажной туманной зимы, из голубой мглы и одиночества Баден в апреле возрождается безграничными полями огромных сиреневых крокусов и пением птиц.', full_analysis='<S ID="10">\n<W DOM="2" FEAT="A ЕД СРЕД ИМ" ID="1" KSNAME="ЭТОТ" LEMMA="ЭТОТ" LINK="опред">Это</W>\n<W DOM="6" FEAT="S ЕД СРЕД ИМ НЕОД" ID="2" LEMMA="ЧУВСТВО" LINK="предик">чувство</W>\n<W DOM="2" FEAT="S ЕД СРЕД РОД НЕОД" ID="3" LEMMA="РОДСТВО" LINK="1-компл">родства</W>\n<W DOM="3" FEAT="PR" ID="4" KSNAME="С3" LEMMA="С" LINK="1-компл">с</W>\n<W DOM="4" FEAT="S ЕД МУЖ ТВОР ОД" ID="5" KSNAME="НЕГО1" LEMMA="ОН" LINK="предл">ним</W>\n<W DOM="_root" FEAT="V НЕСОВ ИЗЪЯВ НЕПРОШ ЕД 3-Л" ID="6" KSNAME="ДАВАТЬ1" LEMMA="ДАВАТЬ">дает</W>\n<W DOM="6" FEAT="S ЕД ЖЕН ДАТ ОД" ID="7" LEMMA="Я" LINK="2-компл">мне</W>\n<W DOM="6" FEAT="S МН ЖЕН ВИН НЕОД" ID="8" LEMMA="СИЛА" LINK="1-компл">силы</W>\n<W DOM="8" FEAT="V НЕСОВ ИНФ" ID="9" LEMMA="ЖИТЬ" LINK="1-компл">жить</W>\n<W DOM="9" FEAT="ADV" ID="10" LEMMA="ЗДЕСЬ" LINK="1-компл">здесь</W>.\n</S>', sent_pos_chain='PRON S S PR PRON V PRON S V ADV', has_many_dos=0, has_many_ios=0, has_nodetype_in_our_forms=0, verb_inf='давать', verb='дает', verb_feats='mood=изъяв|aspect=несов|tense=непрош|person=3-л|number=ед', verb_has_neg=0, DO_group='силы жить здесь', IO_group='мне', DO_had_appos=0, IO_had_appos=0, DO_has_relcl=False, IO_has_relcl=False, DO_has_wh_relcl=False, IO_has_wh_relcl=False, DO_has_participle=False, IO_has_participle=False, DO_depth=2, IO_depth=0, DO_length=3, IO_length=1, DO_pos_feat_chain='V+representation=инф|aspect=несов ADV S+gender=жен|number=мн|case=вин|animacy=неод', IO_pos_feat_chain='PRON+gender=жен|number=ед|case=дат|animacy=од', DO='силы', DO_pos='S', DO_lemma='сила', DO_animacy='неод', DO_case='вин', DO_number='мн', IO='мне', IO_pos='PRON', IO_head='дает', IO_head_pos='V', IO_lemma='я', IO_animacy='од', IO_case='дат', IO_number='ед', order='V IO DO')]

# %%
print(*tokens, sep='\n')
# Out:
# <Word({'form': 'это', 'id': 1, 'dom': 2, 'link': 'опред', 'pos': 'PRON' 'lemma': 'этот', 'feat': {'gender': 'сред', 'number': 'ед', 'case': 'им'}}, children=[]), parent=(2, 'чувство')>
# <Word({'form': 'чувство', 'id': 2, 'dom': 6, 'link': 'предик', 'pos': 'S' 'lemma': 'чувство', 'feat': {'gender': 'сред', 'number': 'ед', 'case': 'им', 'animacy': 'неод'}}, children=[(1, 'это'), (3, 'родства'), (4, 'с'), (5, 'ним')]), parent=(6, 'дает')>
# <Word({'form': 'родства', 'id': 3, 'dom': 2, 'link': '1-компл', 'pos': 'S' 'lemma': 'родство', 'feat': {'gender': 'сред', 'number': 'ед', 'case': 'род', 'animacy': 'неод'}}, children=[(4, 'с'), (5, 'ним')]), parent=(2, 'чувство')>
# <Word({'form': 'с', 'id': 4, 'dom': 3, 'link': '1-компл', 'pos': 'PR' 'lemma': 'с', 'feat': {}}, children=[(5, 'ним')]), parent=(3, 'родства')>
# <Word({'form': 'ним', 'id': 5, 'dom': 4, 'link': 'предл', 'pos': 'PRON' 'lemma': 'он', 'feat': {'gender': 'муж', 'number': 'ед', 'case': 'твор', 'animacy': 'од'}}, children=[]), parent=(4, 'с')>
# <Word({'form': 'дает', 'id': 6, 'dom': _root, 'link': '_root', 'pos': 'V' 'lemma': 'давать', 'feat': {'mood': 'изъяв', 'aspect': 'несов', 'tense': 'непрош', 'person': '3-л', 'number': 'ед'}}, children=[(2, 'чувство'), (7, 'мне'), (8, 'силы'), (1, 'это'), (3, 'родства'), (9, 'жить'), (4, 'с'), (10, 'здесь'), (5, 'ним')]), parent=None>
# <Word({'form': 'мне', 'id': 7, 'dom': 6, 'link': '2-компл', 'pos': 'PRON' 'lemma': 'я', 'feat': {'gender': 'жен', 'number': 'ед', 'case': 'дат', 'animacy': 'од'}}, children=[]), parent=(6, 'дает')>
# <Word({'form': 'силы', 'id': 8, 'dom': 6, 'link': '1-компл', 'pos': 'S' 'lemma': 'сила', 'feat': {'gender': 'жен', 'number': 'мн', 'case': 'вин', 'animacy': 'неод'}}, children=[(9, 'жить'), (10, 'здесь')]), parent=(6, 'дает')>
# <Word({'form': 'жить', 'id': 9, 'dom': 8, 'link': '1-компл', 'pos': 'V' 'lemma': 'жить', 'feat': {'representation': 'инф', 'aspect': 'несов'}}, children=[(10, 'здесь')]), parent=(8, 'силы')>
# <Word({'form': 'здесь', 'id': 10, 'dom': 9, 'link': '1-компл', 'pos': 'ADV' 'lemma': 'здесь', 'feat': {}}, children=[]), parent=(9, 'жить')>

# %%
token = tokens[1]
print(text, end='\n\n')
for attr in ('group_str', 'children_depth'):
    print(f"{attr}: {getattr(token, attr)}\n"
          f"{f'no_appos_{attr}'}: {getattr(token, f'no_appos_{attr}')}\n"
    )

attr = 'group'
print(
    f"len_{attr}: {len(getattr(token, attr))}\n"
    f"len_{f'no_appos_{attr}'}: {len(getattr(token, f'no_appos_{attr}'))}\n"
 )
# Out:
# Это чувство родства с ним дает мне силы жить здесь.
#
# group_str: это чувство родства с ним
# no_appos_group_str: это чувство родства с ним
#
# children_depth: 3
# no_appos_children_depth: 3
#
# len_group: 5
# len_no_appos_group: 5

# %%
def parse_sent_in_file_by_num(short_filename, sent_num, return_tokens_list=True):
    file = syntagrus_dir / Path(short_filename)
    file_soup = get_soup(file).find('body')
    
    sents = file_soup.find_all('S', recursive=False)
    sent = sents[sent_num-1]
    
    res, tokens = parse_sent(
        sents[182], get_pos_to_feats_format(),
        return_tokens_list=return_tokens_list
    )
    
    return res, tokens

# %%
gr = tokens.filter(id=5)[0].group_str
r = get_pos_chain(tokens.filter(id=5)[0].group, include_feat=True, include_feat_name=True)

print(gr, r, sep='\n')
# Out:
# ним
# PRON+gender=муж|number=ед|case=твор|animacy=од

# %%
tokens[4]
# Out:
# Word({'form': 'ним', 'id': 5, 'dom': 4, 'link': 'предл', 'lemma': 'он', 'feat': {'gender': 'муж', 'number': 'ед', 'case': 'твор', 'animacy': 'од'}, 'pos': 'PRON'}, children={})

# %%
words = parse_sent(sentences[3], get_pos_to_feats_format())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-ba03659c1619> in <module>
# ----> 1 words = parse_sent(sentences[3], get_pos_to_feats_format())
#
# NameError: name 'sentences' is not defined

# %%
print(*words.filter(link='1-компл'), sep='\n')

# %%
words[0].group_str

# %%
def do_search(files, num_first_files=None):
    total_passing, total_regex = 0, 0
    
    if num_first_files:
        files = files[:num_first_files]
    
    examples = {}
    files_dfs = []
    for file in tqdm(files):
        soup = get_soup(file)
        
        doc_body = soup.find('body')
        
        sents = find_sentences_do_io(doc_body)
        num_regex_sents = len(sents)
        
        unique_file_path = file.relative_to(syntagrus_dir)
        path_str = str(unique_file_path).replace('\\', '/')
        examples[path_str] = [str(sent) for sent in sents]
                        
        good_sents = []
        for sent in sents:
            parsed_sent = parse_sent(sent, get_pos_to_feats_format())
            if parsed_sent:
                good_sents.extend(parsed_sent)
                
        num_passing_sents = len(good_sents)
        print(f'file is `{unique_file_path}`, there are {num_passing_sents} passing sentences '
              f'(were {num_regex_sents} by regex)')
        total_passing += num_passing_sents
        total_regex += num_regex_sents
        
        good_sents_table = pd.DataFrame(good_sents)
        good_sents_table.insert(0, 'source', path_str)
        files_dfs.append(good_sents_table)
    
    print(f'passing {total_passing} among {total_regex} found by regex')
    return pd.concat(files_dfs), total_passing, total_regex

# %%
# %%time
corpus_base, total_passing, total_regex = do_search(files)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=729.0), HTML(value='')))
# file is `2003\anketa.tgt`, there are 16 passing sentences (were 26 by regex)
# file is `2003\armeniya.tgt`, there are 6 passing sentences (were 15 by regex)
# file is `2003\artist_mimansa.tgt`, there are 39 passing sentences (were 75 by regex)
# file is `2003\ataka.tgt`, there are 1 passing sentences (were 3 by regex)
# file is `2003\atlanty_i_atlantologi.tgt`, there are 15 passing sentences (were 22 by regex)
# file is `2003\avtomatizatsiya.tgt`, there are 6 passing sentences (were 15 by regex)
# file is `2003\a_on_myatezhnyi.tgt`, there are 20 passing sentences (were 35 by regex)
# file is `2003\baklanov.tgt`, there are 54 passing sentences (were 82 by regex)
# file is `2003\batareika.tgt`, there are 2 passing sentences (were 8 by regex)
# file is `2003\bessonnitsa.tgt`, there are 6 passing sentences (were 13 by regex)
# file is `2003\bez_epokhi.tgt`, there are 11 passing sentences (were 15 by regex)
# file is `2003\biologiya.tgt`, there are 15 passing sentences (were 20 by regex)
# file is `2003\bionika.tgt`, there are 10 passing sentences (were 22 by regex)
# file is `2003\bolshie_peremeny.tgt`, there are 15 passing sentences (were 24 by regex)
# file is `2003\chelovek_oshibka_prirody.tgt`, there are 7 passing sentences (were 14 by regex)
# file is `2003\chto_doktor_propisal.tgt`, there are 17 passing sentences (were 25 by regex)
# file is `2003\delit_na_vosem.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2003\dom_pod_solntsem.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `2003\dvoe_v_dekabre.tgt`, there are 10 passing sentences (were 33 by regex)
# file is `2003\dvortsovyi_makiyazh.tgt`, there are 13 passing sentences (were 15 by regex)
# file is `2003\ekspluatatsiya_elity.tgt`, there are 12 passing sentences (were 23 by regex)
# file is `2003\ezhednevnaya_simfoniya.tgt`, there are 10 passing sentences (were 11 by regex)
# file is `2003\faraony_sobstvennoi_personoi.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2003\fitoterapiya.tgt`, there are 11 passing sentences (were 11 by regex)
# file is `2003\gorodskoe_slonovodstvo.tgt`, there are 9 passing sentences (were 20 by regex)
# file is `2003\igrushki_bogov.tgt`, there are 9 passing sentences (were 16 by regex)
# file is `2003\interaktiv.tgt`, there are 6 passing sentences (were 10 by regex)
# file is `2003\internet-zavisimost.tgt`, there are 8 passing sentences (were 12 by regex)
# file is `2003\istoriya_tualeta.tgt`, there are 5 passing sentences (were 7 by regex)
# file is `2003\i_evro_takoi_molodoi.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2003\i_k_nim_ne_zarastet_narodnaya_tropa.tgt`, there are 13 passing sentences (were 25 by regex)
# file is `2003\i_slepye_prozreyut.tgt`, there are 4 passing sentences (were 11 by regex)
# file is `2003\khranilishcha.tgt`, there are 17 passing sentences (were 17 by regex)
# file is `2003\komu_dostanetsya_chingiskhan.tgt`, there are 11 passing sentences (were 14 by regex)
# file is `2003\krupnaya_kala.tgt`, there are 5 passing sentences (were 5 by regex)
# file is `2003\lyubit_drakona.tgt`, there are 14 passing sentences (were 21 by regex)
# file is `2003\manekeny.tgt`, there are 5 passing sentences (were 7 by regex)
# file is `2003\metis.tgt`, there are 6 passing sentences (were 11 by regex)
# file is `2003\nalog_na_tainu.tgt`, there are 14 passing sentences (were 23 by regex)
# file is `2003\nelegalnaya_perepis.tgt`, there are 10 passing sentences (were 13 by regex)
# file is `2003\nelzya_sebya_delit.tgt`, there are 13 passing sentences (were 22 by regex)
# file is `2003\nepotoplyaemye.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `2003\nobelevskie_premii.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `2003\obratnaya_reaktsiya.tgt`, there are 4 passing sentences (were 4 by regex)
# file is `2003\ochishchenie_olkhona.tgt`, there are 10 passing sentences (were 16 by regex)
# file is `2003\okhota.tgt`, there are 11 passing sentences (were 14 by regex)
# file is `2003\opasnaya_blizost.tgt`, there are 6 passing sentences (were 11 by regex)
# file is `2003\optimizm.tgt`, there are 12 passing sentences (were 22 by regex)
# file is `2003\perekrestok.tgt`, there are 11 passing sentences (were 17 by regex)
# file is `2003\perestanovka_mebeli.tgt`, there are 7 passing sentences (were 15 by regex)
# file is `2003\piramida.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `2003\plastikovaya_krepost.tgt`, there are 16 passing sentences (were 21 by regex)
# file is `2003\platno.tgt`, there are 8 passing sentences (were 14 by regex)
# file is `2003\plesnite_koldovstva.tgt`, there are 12 passing sentences (were 19 by regex)
# file is `2003\portret_fridy.tgt`, there are 4 passing sentences (were 5 by regex)
# file is `2003\pravilo_75.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2003\prilet_ptits.tgt`, there are 18 passing sentences (were 37 by regex)
# file is `2003\privatizatsiya_istorii.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2003\propoved_na_zadannuyu_temu.tgt`, there are 15 passing sentences (were 23 by regex)
# file is `2003\razvedka.tgt`, there are 2 passing sentences (were 13 by regex)
# file is `2003\robototekhnika.tgt`, there are 10 passing sentences (were 15 by regex)
# file is `2003\roboty.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `2003\rtut.tgt`, there are 2 passing sentences (were 4 by regex)
# file is `2003\shok_bez_trepeta.tgt`, there are 17 passing sentences (were 30 by regex)
# file is `2003\somnambula_v_tumane.tgt`, there are 33 passing sentences (were 56 by regex)
# file is `2003\son.tgt`, there are 4 passing sentences (were 8 by regex)
# file is `2003\spam.tgt`, there are 3 passing sentences (were 4 by regex)
# file is `2003\sputniki.tgt`, there are 4 passing sentences (were 12 by regex)
# file is `2003\stolknovenie_vermeer.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2003\taezhnyi_ofshor.tgt`, there are 14 passing sentences (were 25 by regex)
# file is `2003\taina_zakovannaya_v_led.tgt`, there are 2 passing sentences (were 9 by regex)
# file is `2003\to_v_zhar_to_v_kholod.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `2003\tyurma_britanskoi_korony.tgt`, there are 7 passing sentences (were 13 by regex)
# file is `2003\tyurma_dlya_svekrovei.tgt`, there are 12 passing sentences (were 11 by regex)
# file is `2003\uidya_iz_skazki.tgt`, there are 9 passing sentences (were 17 by regex)
# file is `2003\uroki_nord-osta.tgt`, there are 5 passing sentences (were 14 by regex)
# file is `2003\uteshenie.tgt`, there are 0 passing sentences (were 3 by regex)
# file is `2003\vash_personalnyi_nimb.tgt`, there are 5 passing sentences (were 17 by regex)
# file is `2003\vremya_torgovli.tgt`, there are 5 passing sentences (were 6 by regex)
# file is `2003\vyzhivshii_kamikadze.tgt`, there are 25 passing sentences (were 49 by regex)
# file is `2003\v_zimu_bez_grippa.tgt`, there are 3 passing sentences (were 5 by regex)
# file is `2003\zdorovie_na_zavtra.tgt`, there are 6 passing sentences (were 14 by regex)
# file is `2003\zemlya_naiznanku.tgt`, there are 14 passing sentences (were 18 by regex)
# file is `2003\zhivotnye_mukhi.tgt`, there are 8 passing sentences (were 8 by regex)
# file is `2003\zhores.tgt`, there are 28 passing sentences (were 57 by regex)
# file is `2004\andrei_ashkerov.tgt`, there are 11 passing sentences (were 15 by regex)
# file is `2004\tarifnaya_viselitsa.tgt`, there are 18 passing sentences (were 23 by regex)
# file is `2005\blesnuli_masterstvom.tgt`, there are 0 passing sentences (were 0 by regex)
# file is `2005\bolshe_kandidatov.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `2005\byt_modnym.tgt`, there are 11 passing sentences (were 13 by regex)
# file is `2005\delitsya_vlastiyu.tgt`, there are 2 passing sentences (were 4 by regex)
# file is `2005\dvukhprotsentnaya_reforma.tgt`, there are 9 passing sentences (were 14 by regex)
# file is `2005\gubarev.tgt`, there are 12 passing sentences (were 23 by regex)
# file is `2005\istochniki_rosta.tgt`, there are 4 passing sentences (were 12 by regex)
# file is `2005\kaprossiya.tgt`, there are 4 passing sentences (were 6 by regex)
# file is `2005\kompartii.tgt`, there are 2 passing sentences (were 3 by regex)
# file is `2005\kruglyi_stol.tgt`, there are 0 passing sentences (were 2 by regex)
# file is `2005\kvartira_na_depozit.tgt`, there are 5 passing sentences (were 15 by regex)
# file is `2005\mamleev_charli.tgt`, there are 38 passing sentences (were 66 by regex)
# file is `2005\mamleev_svadba.tgt`, there are 17 passing sentences (were 22 by regex)
# file is `2005\monopolizatsiya_kanalizatsii.tgt`, there are 12 passing sentences (were 19 by regex)
# file is `2005\muzhei_ne_obeshchal.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `2005\na_levom_flange.tgt`, there are 6 passing sentences (were 10 by regex)
# file is `2005\neftyanye_kacheli.tgt`, there are 1 passing sentences (were 3 by regex)
# file is `2005\nichego_chelovecheskogo.tgt`, there are 4 passing sentences (were 5 by regex)
# file is `2005\novyi_levyi.tgt`, there are 7 passing sentences (were 19 by regex)
# file is `2005\otkaz_ot_grefa.tgt`, there are 5 passing sentences (were 14 by regex)
# file is `2005\parlamentskaya_komissiya.tgt`, there are 1 passing sentences (were 2 by regex)
# file is `2005\po-nashemu.tgt`, there are 4 passing sentences (were 4 by regex)
# file is `2005\prodazha_zemli.tgt`, there are 4 passing sentences (were 5 by regex)
# file is `2005\shokovaya_terapiya.tgt`, there are 2 passing sentences (were 5 by regex)
# file is `2005\sluzhit_by_rad.tgt`, there are 4 passing sentences (were 19 by regex)
# file is `2005\stranitsy_voennoi_istorii.tgt`, there are 46 passing sentences (were 75 by regex)
# file is `2005\sudu_pomogayut.tgt`, there are 2 passing sentences (were 5 by regex)
# file is `2005\tokarskaya.tgt`, there are 0 passing sentences (were 1 by regex)
# file is `2005\voennaya_doktrina.tgt`, there are 15 passing sentences (were 24 by regex)
# file is `2005\voennoe_bessilie.tgt`, there are 21 passing sentences (were 24 by regex)
# file is `2005\yakovlev.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2005\yanin.tgt`, there are 15 passing sentences (were 22 by regex)
# file is `2005\zhenshchin_uravnyayut.tgt`, there are 6 passing sentences (were 6 by regex)
# file is `2006\antiterror.tgt`, there are 4 passing sentences (were 12 by regex)
# file is `2006\byudzhet.tgt`, there are 14 passing sentences (were 16 by regex)
# file is `2006\demonstratsiya_flaga.tgt`, there are 7 passing sentences (were 16 by regex)
# file is `2006\ditya_20_siezda.tgt`, there are 24 passing sentences (were 34 by regex)
# file is `2006\dobretsov.tgt`, there are 23 passing sentences (were 40 by regex)
# file is `2006\dvesti_let.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2006\gaidar.tgt`, there are 15 passing sentences (were 16 by regex)
# file is `2006\informtekhnologii.tgt`, there are 9 passing sentences (were 15 by regex)
# file is `2006\levyi_povorot.tgt`, there are 21 passing sentences (were 30 by regex)
# file is `2006\lunnye_kamni.tgt`, there are 30 passing sentences (were 59 by regex)
# file is `2006\metallovedenie.tgt`, there are 10 passing sentences (were 19 by regex)
# file is `2006\misha.tgt`, there are 49 passing sentences (were 77 by regex)
# file is `2006\muzei.tgt`, there are 3 passing sentences (were 3 by regex)
# file is `2006\neiron.tgt`, there are 20 passing sentences (were 27 by regex)
# file is `2006\piterskaya_model.tgt`, there are 15 passing sentences (were 33 by regex)
# file is `2006\predsedatel.tgt`, there are 12 passing sentences (were 18 by regex)
# file is `2006\rentgen.tgt`, there are 17 passing sentences (were 36 by regex)
# file is `2006\sluzhivoe_pravo.tgt`, there are 38 passing sentences (were 52 by regex)
# file is `2006\stylaya_krov.tgt`, there are 24 passing sentences (were 36 by regex)
# file is `2006\syuzhet.tgt`, there are 8 passing sentences (were 11 by regex)
# file is `2006\uroki.tgt`, there are 16 passing sentences (were 28 by regex)
# file is `2006\veter.tgt`, there are 15 passing sentences (were 22 by regex)
# file is `2006\vinnyi_kamen.tgt`, there are 11 passing sentences (were 21 by regex)
# file is `2006\vse_vozrastu_pokorny.tgt`, there are 16 passing sentences (were 32 by regex)
# file is `2006\vtoraya_popytka.tgt`, there are 16 passing sentences (were 23 by regex)
# file is `2006\v_pogone.tgt`, there are 15 passing sentences (were 29 by regex)
# file is `2007\beg_po_krugu.tgt`, there are 7 passing sentences (were 18 by regex)
# file is `2007\bezrybie.tgt`, there are 23 passing sentences (were 25 by regex)
# file is `2007\bob.tgt`, there are 16 passing sentences (were 26 by regex)
# file is `2007\buran.tgt`, there are 6 passing sentences (were 17 by regex)
# file is `2007\chelovek_na_tribune.tgt`, there are 15 passing sentences (were 26 by regex)
# file is `2007\chuvstvo_spravedlivosti.tgt`, there are 20 passing sentences (were 22 by regex)
# file is `2007\darts.tgt`, there are 10 passing sentences (were 22 by regex)
# file is `2007\dvigatel.tgt`, there are 13 passing sentences (were 26 by regex)
# file is `2007\ekzamen.tgt`, there are 4 passing sentences (were 5 by regex)
# file is `2007\foto.tgt`, there are 20 passing sentences (were 23 by regex)
# file is `2007\gematologiya.tgt`, there are 10 passing sentences (were 10 by regex)
# file is `2007\grechko.tgt`, there are 31 passing sentences (were 60 by regex)
# file is `2007\kak_politikov.tgt`, there are 9 passing sentences (were 15 by regex)
# file is `2007\katastrofa.tgt`, there are 0 passing sentences (were 4 by regex)
# file is `2007\kodeks_molchaniya.tgt`, there are 8 passing sentences (were 10 by regex)
# file is `2007\kovka.tgt`, there are 14 passing sentences (were 15 by regex)
# file is `2007\kto_ubil.tgt`, there are 10 passing sentences (were 14 by regex)
# file is `2007\led.tgt`, there are 21 passing sentences (were 30 by regex)
# file is `2007\lesorub.tgt`, there are 16 passing sentences (were 21 by regex)
# file is `2007\lunokhod.tgt`, there are 7 passing sentences (were 13 by regex)
# file is `2007\lyzhi.tgt`, there are 11 passing sentences (were 26 by regex)
# file is `2007\mars.tgt`, there are 15 passing sentences (were 20 by regex)
# file is `2007\mech.tgt`, there are 26 passing sentences (were 34 by regex)
# file is `2007\okhota.tgt`, there are 3 passing sentences (were 9 by regex)
# file is `2007\parovoz.tgt`, there are 7 passing sentences (were 14 by regex)
# file is `2007\pirat.tgt`, there are 8 passing sentences (were 12 by regex)
# file is `2007\podkormlennyi_natsizm.tgt`, there are 39 passing sentences (were 52 by regex)
# file is `2007\porazhenie.tgt`, there are 9 passing sentences (were 12 by regex)
# file is `2007\pravda_zalozhnikov.tgt`, there are 11 passing sentences (were 16 by regex)
# file is `2007\prevratnosti_razvitiya.tgt`, there are 20 passing sentences (were 37 by regex)
# file is `2007\pushka.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2007\pylesos.tgt`, there are 10 passing sentences (were 14 by regex)
# file is `2007\raspad_sng.tgt`, there are 5 passing sentences (were 13 by regex)
# file is `2007\remni.tgt`, there are 13 passing sentences (were 15 by regex)
# file is `2007\rumba.tgt`, there are 9 passing sentences (were 19 by regex)
# file is `2007\skulachev.tgt`, there are 20 passing sentences (were 29 by regex)
# file is `2007\sluchai_dlya_zhyuri.tgt`, there are 9 passing sentences (were 11 by regex)
# file is `2007\soldatiki.tgt`, there are 15 passing sentences (were 20 by regex)
# file is `2007\suverennaya_mutatsiya.tgt`, there are 18 passing sentences (were 35 by regex)
# file is `2007\tele.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `2007\terpenie_lopnulo.tgt`, there are 13 passing sentences (were 16 by regex)
# file is `2007\transport.tgt`, there are 2 passing sentences (were 7 by regex)
# file is `2007\tsennosti.tgt`, there are 3 passing sentences (were 9 by regex)
# file is `2007\ukho.tgt`, there are 9 passing sentences (were 16 by regex)
# file is `2007\underground.tgt`, there are 4 passing sentences (were 12 by regex)
# file is `2007\ustar.tgt`, there are 10 passing sentences (were 15 by regex)
# file is `2007\zamoroz.tgt`, there are 3 passing sentences (were 2 by regex)
# file is `2007\zheldor.tgt`, there are 10 passing sentences (were 13 by regex)
# file is `2008\bankovskii_krizis.tgt`, there are 4 passing sentences (were 6 by regex)
# file is `2008\bezrabotnye.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `2008\bronya.tgt`, there are 10 passing sentences (were 14 by regex)
# file is `2008\chem_kumushek_schitat.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `2008\chernaya_osen.tgt`, there are 10 passing sentences (were 18 by regex)
# file is `2008\chto_v_imeni.tgt`, there are 7 passing sentences (were 14 by regex)
# file is `2008\drakony.tgt`, there are 11 passing sentences (were 14 by regex)
# file is `2008\ekonomicheskii_rost.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `2008\galopom_ot_trollei.tgt`, there are 13 passing sentences (were 18 by regex)
# file is `2008\kobzon.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2008\kollaider.tgt`, there are 0 passing sentences (were 3 by regex)
# file is `2008\korrida.tgt`, there are 5 passing sentences (were 6 by regex)
# file is `2008\koshki.tgt`, there are 20 passing sentences (were 23 by regex)
# file is `2008\lego.tgt`, there are 11 passing sentences (were 15 by regex)
# file is `2008\mars_1.tgt`, there are 12 passing sentences (were 24 by regex)
# file is `2008\mars_2.tgt`, there are 12 passing sentences (were 22 by regex)
# file is `2008\molodezh.tgt`, there are 2 passing sentences (were 2 by regex)
# file is `2008\narkotiki.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2008\nedouchenie.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `2008\nekommercheskie_organizatsii.tgt`, there are 15 passing sentences (were 26 by regex)
# file is `2008\nepodiemnyi_kredit.tgt`, there are 3 passing sentences (were 10 by regex)
# file is `2008\olenina.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `2008\opasnye_prazdniki.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2008\osoboe_mnenie.tgt`, there are 5 passing sentences (were 9 by regex)
# file is `2008\otboinyi_molotok.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `2008\o_boikote_pekina.tgt`, there are 6 passing sentences (were 10 by regex)
# file is `2008\pessimist_platit_dvazhdy.tgt`, there are 12 passing sentences (were 20 by regex)
# file is `2008\poslednee_vystuplenie_prezidenta.tgt`, there are 1 passing sentences (were 5 by regex)
# file is `2008\posledstviya_krizisa.tgt`, there are 0 passing sentences (were 1 by regex)
# file is `2008\pritok_kapitala.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `2008\programma_alfa-shans.tgt`, there are 2 passing sentences (were 5 by regex)
# file is `2008\rossiya_i_vto.tgt`, there are 4 passing sentences (were 6 by regex)
# file is `2008\rynok.tgt`, there are 10 passing sentences (were 12 by regex)
# file is `2008\tolkovateli_snov.tgt`, there are 16 passing sentences (were 22 by regex)
# file is `2008\trudnosti_rosta.tgt`, there are 5 passing sentences (were 11 by regex)
# file is `2008\tseny_na_produkty.tgt`, there are 9 passing sentences (were 12 by regex)
# file is `2008\vneshnyaya_politika.tgt`, there are 21 passing sentences (were 29 by regex)
# file is `2008\vse_molchat.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `2008\v_redaktorskom_kresle.tgt`, there are 16 passing sentences (were 19 by regex)
# file is `2008\zhurnalistskoe_obrazovanie.tgt`, there are 10 passing sentences (were 20 by regex)
# file is `2009\aprelskie_tezisy_surkova.tgt`, there are 10 passing sentences (were 12 by regex)
# file is `2009\auditory.tgt`, there are 7 passing sentences (were 16 by regex)
# file is `2009\avraam_linkoln.tgt`, there are 4 passing sentences (were 6 by regex)
# file is `2009\biznes-obrazovanie.tgt`, there are 6 passing sentences (were 8 by regex)
# file is `2009\chernye_dyry.tgt`, there are 3 passing sentences (were 3 by regex)
# file is `2009\chlenstvo_v_vto.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `2009\dolgovaya_vyshka.tgt`, there are 7 passing sentences (were 15 by regex)
# file is `2009\ege.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `2009\eto_tolko_nachalo.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2009\fantasticheskie_perspektivy.tgt`, there are 2 passing sentences (were 4 by regex)
# file is `2009\final_ligi_chempionov.tgt`, there are 12 passing sentences (were 14 by regex)
# file is `2009\finansovyi_shtorm.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2009\firma_ne_garantiruet.tgt`, there are 2 passing sentences (were 6 by regex)
# file is `2009\gadzhety-neudachniki.tgt`, there are 10 passing sentences (were 18 by regex)
# file is `2009\gde_budet_vlast.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `2009\informatsionnoe_obshchestvo.tgt`, there are 9 passing sentences (were 21 by regex)
# file is `2009\innovatsionnaya_ekonomika.tgt`, there are 6 passing sentences (were 14 by regex)
# file is `2009\interviyu_medvedeva.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `2009\iz-pod_kontrolya.tgt`, there are 8 passing sentences (were 12 by regex)
# file is `2009\izobreteno_vo_sne.tgt`, there are 10 passing sentences (were 18 by regex)
# file is `2009\kholodnaya_voina.tgt`, there are 15 passing sentences (were 19 by regex)
# file is `2009\krizis_blizhe.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2009\kukla_gitlera.tgt`, there are 11 passing sentences (were 17 by regex)
# file is `2009\letayushchaya_tarelka.tgt`, there are 17 passing sentences (were 24 by regex)
# file is `2009\mgu.tgt`, there are 10 passing sentences (were 21 by regex)
# file is `2009\molodtsy.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `2009\moskva_privlekaet_menshe.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `2009\nalogovaya_sistema.tgt`, there are 13 passing sentences (were 28 by regex)
# file is `2009\natsionalnaya_assambleya.tgt`, there are 8 passing sentences (were 14 by regex)
# file is `2009\nebesnye_formatsii.tgt`, there are 6 passing sentences (were 16 by regex)
# file is `2009\nekhvatka_spetsialistov.tgt`, there are 2 passing sentences (were 8 by regex)
# file is `2009\nelishnyaya_formalnost.tgt`, there are 11 passing sentences (were 19 by regex)
# file is `2009\neudachnye_vremena.tgt`, there are 8 passing sentences (were 14 by regex)
# file is `2009\nezhilye_pomeshcheniya.tgt`, there are 9 passing sentences (were 13 by regex)
# file is `2009\novaya_model_obrazovaniya.tgt`, there are 5 passing sentences (were 5 by regex)
# file is `2009\novaya_russkaya_ruletka.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `2009\novye_neformaly.tgt`, there are 9 passing sentences (were 15 by regex)
# file is `2009\obrazovanie_-_novaya_model.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2009\obrazovatelnoe_kreditovanie.tgt`, there are 3 passing sentences (were 5 by regex)
# file is `2009\obrushenie_shkoly.tgt`, there are 6 passing sentences (were 6 by regex)
# file is `2009\oka.tgt`, there are 10 passing sentences (were 13 by regex)
# file is `2009\ot_vlasti.tgt`, there are 15 passing sentences (were 28 by regex)
# file is `2009\pastukh.tgt`, there are 9 passing sentences (were 13 by regex)
# file is `2009\peremeny_v_pravitelstve.tgt`, there are 5 passing sentences (were 9 by regex)
# file is `2009\pereselenie_na_yug.tgt`, there are 2 passing sentences (were 5 by regex)
# file is `2009\podstava_na_ekzamene.tgt`, there are 2 passing sentences (were 5 by regex)
# file is `2009\politicheskaya_zavisimost.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `2009\pora_stavit_zadachi.tgt`, there are 5 passing sentences (were 13 by regex)
# file is `2009\posledstviya_krizisa.tgt`, there are 5 passing sentences (were 12 by regex)
# file is `2009\posledstviya_nezavisimosti.tgt`, there are 9 passing sentences (were 10 by regex)
# file is `2009\poslevkusie.tgt`, there are 9 passing sentences (were 12 by regex)
# file is `2009\povyshenie_tarifov.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2009\pravila_igry.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `2009\prazdnik_obshchei_bedy.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `2009\predkrizisnyi_perekur.tgt`, there are 17 passing sentences (were 22 by regex)
# file is `2009\predvybornaya_situatsiya.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2009\prizyvy_pravitelstva_zubkova.tgt`, there are 2 passing sentences (were 4 by regex)
# file is `2009\problemy_obrazovaniya.tgt`, there are 10 passing sentences (were 18 by regex)
# file is `2009\problemy_s_khlebom.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `2009\prognoz_inflyatsii.tgt`, there are 13 passing sentences (were 20 by regex)
# file is `2009\proryvy_goda.tgt`, there are 14 passing sentences (were 27 by regex)
# file is `2009\protorgovavshiesya.tgt`, there are 10 passing sentences (were 18 by regex)
# file is `2009\rabotat_nekomu.tgt`, there are 8 passing sentences (were 9 by regex)
# file is `2009\razvilka.tgt`, there are 0 passing sentences (were 5 by regex)
# file is `2009\reforma_nds.tgt`, there are 9 passing sentences (were 16 by regex)
# file is `2009\reforma_obrazovaniya.tgt`, there are 11 passing sentences (were 15 by regex)
# file is `2009\rossiya_nuzhdaetsya_v_migrantakh.tgt`, there are 4 passing sentences (were 11 by regex)
# file is `2009\sanktsii.tgt`, there are 9 passing sentences (were 19 by regex)
# file is `2009\sdavaisya_kto_mozhet.tgt`, there are 9 passing sentences (were 15 by regex)
# file is `2009\shkola_kapitalizma.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `2009\sinie_vorotnichki.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `2009\skiltoi.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `2009\srednii_klass.tgt`, there are 2 passing sentences (were 6 by regex)
# file is `2009\status_vshe.tgt`, there are 14 passing sentences (were 20 by regex)
# file is `2009\stipendiat.tgt`, there are 9 passing sentences (were 19 by regex)
# file is `2009\svechenie_venery.tgt`, there are 2 passing sentences (were 3 by regex)
# file is `2009\taktika_melkikh_shchelchkov.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `2009\tranzit_14.tgt`, there are 7 passing sentences (were 15 by regex)
# file is `2009\tranzit_15.tgt`, there are 13 passing sentences (were 16 by regex)
# file is `2009\tranzit_16.tgt`, there are 15 passing sentences (were 18 by regex)
# file is `2009\tranzit_17.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `2009\tranzit_18.tgt`, there are 14 passing sentences (were 26 by regex)
# file is `2009\trud_i_kapital.tgt`, there are 8 passing sentences (were 10 by regex)
# file is `2009\tseny_na_zerno.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `2009\tseny_rastut.tgt`, there are 2 passing sentences (were 6 by regex)
# file is `2009\ugroza_deflyatsii.tgt`, there are 6 passing sentences (were 8 by regex)
# file is `2009\velikaya_pochinka.tgt`, there are 9 passing sentences (were 17 by regex)
# file is `2009\voina_vozrastov.tgt`, there are 5 passing sentences (were 9 by regex)
# file is `2009\vozvrashchenie_dollara.tgt`, there are 1 passing sentences (were 2 by regex)
# file is `2009\vysokie_tekhnologii.tgt`, there are 5 passing sentences (were 14 by regex)
# file is `2009\vysshaya_shkola_ekonomiki.tgt`, there are 5 passing sentences (were 9 by regex)
# file is `2009\vyzov_i_otvet.tgt`, there are 8 passing sentences (were 13 by regex)
# file is `2009\v_ozhidanii_peremen.tgt`, there are 14 passing sentences (were 31 by regex)
# file is `2009\v_zashchitu_torgashei.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `2009\zanimatelnye_tsifry.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `2009\zapretnoe_iskusstvo_2006.tgt`, there are 24 passing sentences (were 32 by regex)
# file is `2009\zavaly_rosobrnadzora.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `2009\za_pravoe_delo.tgt`, there are 3 passing sentences (were 11 by regex)
# file is `2009\zhdet_li_nas_golod.tgt`, there are 4 passing sentences (were 8 by regex)
# file is `2009\zhivaya_zemlya.tgt`, there are 7 passing sentences (were 12 by regex)
# file is `2010\bolezn_rosta.tgt`, there are 20 passing sentences (were 30 by regex)
# file is `2010\chistka_v_sporte.tgt`, there are 12 passing sentences (were 15 by regex)
# file is `2010\ekonomisty.tgt`, there are 6 passing sentences (were 13 by regex)
# file is `2010\ekstremizm.tgt`, there are 9 passing sentences (were 14 by regex)
# file is `2010\filmy_timura_bekmambetova.tgt`, there are 8 passing sentences (were 18 by regex)
# file is `2010\fizkultura_i_okolo.tgt`, there are 11 passing sentences (were 16 by regex)
# file is `2010\gibridomobil.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2010\karpov-kasparov.tgt`, there are 18 passing sentences (were 25 by regex)
# file is `2010\khudozhestvennaya_gimnastika.tgt`, there are 17 passing sentences (were 21 by regex)
# file is `2010\konkurs_otmenyaetsya.tgt`, there are 6 passing sentences (were 9 by regex)
# file is `2010\korrektsiya_mifov.tgt`, there are 11 passing sentences (were 12 by regex)
# file is `2010\kovcheg_zhana_vanie.tgt`, there are 23 passing sentences (were 30 by regex)
# file is `2010\liberaly_sdayutsya.tgt`, there are 18 passing sentences (were 26 by regex)
# file is `2010\lyzhi.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `2010\mars_3.tgt`, there are 20 passing sentences (were 29 by regex)
# file is `2010\matematika_probok.tgt`, there are 2 passing sentences (were 6 by regex)
# file is `2010\mezhdunarodnaya_olimpiada.tgt`, there are 1 passing sentences (were 5 by regex)
# file is `2010\mozgi_naprokat.tgt`, there are 19 passing sentences (were 30 by regex)
# file is `2010\nadpisi_iz_doliny_inda.tgt`, there are 10 passing sentences (were 14 by regex)
# file is `2010\paraolimpiitsy.tgt`, there are 11 passing sentences (were 19 by regex)
# file is `2010\peregrev_ekonomiki.tgt`, there are 8 passing sentences (were 11 by regex)
# file is `2010\prichiny_krizisa.tgt`, there are 7 passing sentences (were 12 by regex)
# file is `2010\profilnoe_obrazovanie.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `2010\pryamoi_ukol.tgt`, there are 3 passing sentences (were 5 by regex)
# file is `2010\psevdoobrazovanie.tgt`, there are 14 passing sentences (were 22 by regex)
# file is `2010\realnaya_politika.tgt`, there are 9 passing sentences (were 18 by regex)
# file is `2010\rodnye_i_priemnye.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `2010\rossiiskie_biznes-shkoly.tgt`, there are 17 passing sentences (were 27 by regex)
# file is `2010\russkii_dom.tgt`, there are 9 passing sentences (were 23 by regex)
# file is `2010\sokrashchenie_vuzov.tgt`, there are 1 passing sentences (were 5 by regex)
# file is `2010\spasenie_evro.tgt`, there are 8 passing sentences (were 20 by regex)
# file is `2010\tsilindry_faraona.tgt`, there are 19 passing sentences (were 34 by regex)
# file is `2010\v_perevode_s_nebesnogo.tgt`, there are 13 passing sentences (were 18 by regex)
# file is `2011\alpinizm.tgt`, there are 17 passing sentences (were 37 by regex)
# file is `2011\apraushev.tgt`, there are 14 passing sentences (were 19 by regex)
# file is `2011\banan.tgt`, there are 6 passing sentences (were 11 by regex)
# file is `2011\chto_takoe_ukhomor.tgt`, there are 2 passing sentences (were 4 by regex)
# file is `2011\facebook.tgt`, there are 19 passing sentences (were 27 by regex)
# file is `2011\formula-1.tgt`, there are 36 passing sentences (were 89 by regex)
# file is `2011\gde_zhe_shliman.tgt`, there are 9 passing sentences (were 12 by regex)
# file is `2011\grisha_perelman_devyatyi_genii.tgt`, there are 20 passing sentences (were 23 by regex)
# file is `2011\interviyu_mariny_astvatsaturyan.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `2011\lekarstva_ot_ustalosti.tgt`, there are 15 passing sentences (were 20 by regex)
# file is `2011\mariam_petrosyan.tgt`, there are 36 passing sentences (were 53 by regex)
# file is `2011\nano.tgt`, there are 31 passing sentences (were 53 by regex)
# file is `2011\otkrytoe_pismo.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `2011\petrushka.tgt`, there are 27 passing sentences (were 40 by regex)
# file is `2011\planerizm.tgt`, there are 13 passing sentences (were 37 by regex)
# file is `2011\pochemu_my_ne_s_nimi.tgt`, there are 19 passing sentences (were 23 by regex)
# file is `2011\pri_popustitelstve_robotov.tgt`, there are 6 passing sentences (were 16 by regex)
# file is `2011\radioastron.tgt`, there are 2 passing sentences (were 3 by regex)
# file is `2011\shakhmaty.tgt`, there are 34 passing sentences (were 59 by regex)
# file is `2011\sinkhronnoe_plavanie.tgt`, there are 7 passing sentences (were 12 by regex)
# file is `2011\sverkhkorotkoe_vremya.tgt`, there are 33 passing sentences (were 60 by regex)
# file is `2011\tekhnologii.tgt`, there are 10 passing sentences (were 14 by regex)
# file is `2011\traektoriya_ekologicheskoi_mysli.tgt`, there are 29 passing sentences (were 52 by regex)
# file is `2011\troitsk_kak_tsentr_novoi_moskvy.tgt`, there are 10 passing sentences (were 13 by regex)
# file is `2012\chto_delat_posle_24_dekabrya.tgt`, there are 4 passing sentences (were 11 by regex)
# file is `2012\fobos-grunt_gibel_mechty.tgt`, there are 22 passing sentences (were 40 by regex)
# file is `2012\fotograf_vladimir_mishukov_sindrom_platona.tgt`, there are 14 passing sentences (were 23 by regex)
# file is `2012\galileo_galilei.tgt`, there are 87 passing sentences (were 124 by regex)
# file is `2012\gosduma_prinyala_zakon_o_kastratsii_pedofilov.tgt`, there are 7 passing sentences (were 13 by regex)
# file is `2012\itogi_subboty.tgt`, there are 5 passing sentences (were 14 by regex)
# file is `2012\iz_pochtovykh_yashchikov.tgt`, there are 15 passing sentences (were 17 by regex)
# file is `2012\kak_sokhranit_gumanitarnuyu_nauku.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `2012\kak_voevat_s_lzhenaukoi.tgt`, there are 22 passing sentences (were 26 by regex)
# file is `2012\kak_zakupat_dorogostoyashchee_oborudovanie.tgt`, there are 9 passing sentences (were 14 by regex)
# file is `2012\kolchak.tgt`, there are 65 passing sentences (were 101 by regex)
# file is `2012\kooperativ_u_ozera.tgt`, there are 12 passing sentences (were 24 by regex)
# file is `2012\lozh_i_legitimnost.tgt`, there are 25 passing sentences (were 32 by regex)
# file is `2012\marko_polo.tgt`, there are 15 passing sentences (were 22 by regex)
# file is `2012\ne_mogu_bolshe_molchat.tgt`, there are 36 passing sentences (were 47 by regex)
# file is `2012\okhotnik_na_palachei.tgt`, there are 57 passing sentences (were 87 by regex)
# file is `2012\on_boitsya_konkurentsii.tgt`, there are 5 passing sentences (were 12 by regex)
# file is `2012\otluchenie_tserkvi.tgt`, there are 30 passing sentences (were 43 by regex)
# file is `2012\plan_razvitiya_vmf.tgt`, there are 0 passing sentences (were 0 by regex)
# file is `2012\poslednie_russkie.tgt`, there are 23 passing sentences (were 40 by regex)
# file is `2012\problema_vybora.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `2012\putin_vzyal_kurs_na_agressivnoe_uderzhanie_status-kvo.tgt`, there are 17 passing sentences (were 32 by regex)
# file is `2012\repressii.tgt`, there are 13 passing sentences (were 12 by regex)
# file is `2012\sluzhivaya_kvazinauka.tgt`, there are 9 passing sentences (were 18 by regex)
# file is `2012\sovety_oppozitsii.tgt`, there are 14 passing sentences (were 22 by regex)
# file is `2012\stalin_vozvrashchalsya.tgt`, there are 8 passing sentences (were 17 by regex)
# file is `2012\teorema_stolypina.tgt`, there are 20 passing sentences (were 27 by regex)
# file is `2012\v_konstitutsii_ne_dolzhno_byt_mesta_dlya_vozhdya.tgt`, there are 35 passing sentences (were 43 by regex)
# file is `2013\algoritm.tgt`, there are 26 passing sentences (were 34 by regex)
# file is `2013\ataman_vikhr.tgt`, there are 26 passing sentences (were 40 by regex)
# file is `2013\budushchee_medvedeva.tgt`, there are 4 passing sentences (were 6 by regex)
# file is `2013\davaite_zhit_smelo.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2013\doktor_z.tgt`, there are 28 passing sentences (were 30 by regex)
# file is `2013\doroga_v_nikuda.tgt`, there are 22 passing sentences (were 25 by regex)
# file is `2013\dvadtsat_let_spustya.tgt`, there are 22 passing sentences (were 40 by regex)
# file is `2013\es-ofshor.tgt`, there are 11 passing sentences (were 17 by regex)
# file is `2013\esli_by_k_vlasti.tgt`, there are 9 passing sentences (were 9 by regex)
# file is `2013\kamennyi_roi.tgt`, there are 6 passing sentences (were 10 by regex)
# file is `2013\katyn.tgt`, there are 12 passing sentences (were 30 by regex)
# file is `2013\khidzhaby_ne_zakazyvali.tgt`, there are 4 passing sentences (were 11 by regex)
# file is `2013\kitaiskii_krossvord.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `2013\kooperativ_lavka.tgt`, there are 12 passing sentences (were 27 by regex)
# file is `2013\literatura.tgt`, there are 17 passing sentences (were 22 by regex)
# file is `2013\martovskaya_revolyutsiya.tgt`, there are 23 passing sentences (were 36 by regex)
# file is `2013\maski.tgt`, there are 26 passing sentences (were 26 by regex)
# file is `2013\minfin_protiv_glazieva.tgt`, there are 4 passing sentences (were 5 by regex)
# file is `2013\nauka.tgt`, there are 41 passing sentences (were 64 by regex)
# file is `2013\plody_alternativnogo_prosveshcheniya.tgt`, there are 31 passing sentences (were 53 by regex)
# file is `2013\podarok_dlya_vsekh.tgt`, there are 17 passing sentences (were 24 by regex)
# file is `2013\poslednii_dovod_issledovatelya.tgt`, there are 36 passing sentences (were 57 by regex)
# file is `2013\poslednyaya_taina.tgt`, there are 3 passing sentences (were 5 by regex)
# file is `2013\povedenie.tgt`, there are 12 passing sentences (were 23 by regex)
# file is `2013\pravo_na_dukhovnuyu_pomoshch.tgt`, there are 1 passing sentences (were 8 by regex)
# file is `2013\pravo_na_obidu.tgt`, there are 10 passing sentences (were 20 by regex)
# file is `2013\preodolet_kompleks_liliputa.tgt`, there are 8 passing sentences (were 10 by regex)
# file is `2013\putin_idet_na_ty.tgt`, there are 11 passing sentences (were 13 by regex)
# file is `2013\rossiya_na_evropeiskom_fone.tgt`, there are 15 passing sentences (were 26 by regex)
# file is `2013\stalingrad.tgt`, there are 26 passing sentences (were 38 by regex)
# file is `2013\strast_dushi.tgt`, there are 15 passing sentences (were 19 by regex)
# file is `2013\sumerki_rossiiskoi_korruptsii.tgt`, there are 9 passing sentences (were 9 by regex)
# file is `2013\sverkhnovaya_ekonomika.tgt`, there are 15 passing sentences (were 26 by regex)
# file is `2013\sverzhenie_svetskogo_stroya.tgt`, there are 9 passing sentences (were 14 by regex)
# file is `2013\transplantatsiya_organov.tgt`, there are 11 passing sentences (were 17 by regex)
# file is `2013\uchebnik_istorii.tgt`, there are 7 passing sentences (were 16 by regex)
# file is `2013\ukroshchenie_stroptivogo_naukograda.tgt`, there are 20 passing sentences (were 24 by regex)
# file is `2013\zhivut_ne_dlya_radosti.tgt`, there are 5 passing sentences (were 12 by regex)
# file is `2014\bogi_menyayutsya.tgt`, there are 14 passing sentences (were 24 by regex)
# file is `2014\chto_budet_posle.tgt`, there are 59 passing sentences (were 97 by regex)
# file is `2014\chto_takoe_interesno.tgt`, there are 11 passing sentences (were 15 by regex)
# file is `2014\geroi.tgt`, there are 77 passing sentences (were 91 by regex)
# file is `2014\granin.tgt`, there are 21 passing sentences (were 26 by regex)
# file is `2014\kulturnye_olimpiitsy.tgt`, there are 19 passing sentences (were 36 by regex)
# file is `2014\na_dvukh_voinakh_1.tgt`, there are 74 passing sentences (were 116 by regex)
# file is `2014\na_dvukh_voinakh_2.tgt`, there are 44 passing sentences (were 68 by regex)
# file is `2014\o_chem_rech.tgt`, there are 11 passing sentences (were 26 by regex)
# file is `2014\sverkhnovaya_2.tgt`, there are 37 passing sentences (were 70 by regex)
# file is `2014\travin_1.tgt`, there are 54 passing sentences (were 90 by regex)
# file is `2014\travin_2.tgt`, there are 48 passing sentences (were 71 by regex)
# file is `2014\vladimir_vladimirovich.tgt`, there are 32 passing sentences (were 46 by regex)
# file is `2014\vspolokhi.tgt`, there are 65 passing sentences (were 107 by regex)
# file is `2014\vysota.tgt`, there are 20 passing sentences (were 36 by regex)
# file is `2015\blokadnoe_detstvo.tgt`, there are 67 passing sentences (were 90 by regex)
# file is `2015\donbass.tgt`, there are 8 passing sentences (were 13 by regex)
# file is `2015\glavnaya_taina_nachala_voiny.tgt`, there are 20 passing sentences (were 31 by regex)
# file is `2015\gorbachev_kak_menya_khoronili.tgt`, there are 18 passing sentences (were 25 by regex)
# file is `2015\grekhi_ukrainskie.tgt`, there are 11 passing sentences (were 15 by regex)
# file is `2015\interviyu_afanasieva.tgt`, there are 13 passing sentences (were 17 by regex)
# file is `2015\interviyu_dvorkina.tgt`, there are 13 passing sentences (were 18 by regex)
# file is `2015\interviyu_yavlinskogo.tgt`, there are 12 passing sentences (were 23 by regex)
# file is `2015\interviyu_yurgensa.tgt`, there are 13 passing sentences (were 21 by regex)
# file is `2015\iz_semeinykh_predanii.tgt`, there are 30 passing sentences (were 46 by regex)
# file is `2015\kriptografiya.tgt`, there are 12 passing sentences (were 19 by regex)
# file is `2015\nelegalnye_kholodilniki.tgt`, there are 12 passing sentences (were 21 by regex)
# file is `2015\ne_nado_vozvrashchatsya_k_yalte.tgt`, there are 13 passing sentences (were 17 by regex)
# file is `2015\oppozitsiyu_ne_pustyat.tgt`, there are 13 passing sentences (were 20 by regex)
# file is `2015\opravdanie_televideniya.tgt`, there are 30 passing sentences (were 49 by regex)
# file is `2015\pervyi_avtomobil.tgt`, there are 13 passing sentences (were 28 by regex)
# file is `2015\poroshenko_dolzhen_pobedit.tgt`, there are 31 passing sentences (were 46 by regex)
# file is `2015\pust_dolgim_budet_razgovor.tgt`, there are 24 passing sentences (were 33 by regex)
# file is `2015\razvorot_nad_atlantidoi.tgt`, there are 9 passing sentences (were 18 by regex)
# file is `2015\rezhimnyi_subiekt.tgt`, there are 14 passing sentences (were 22 by regex)
# file is `2015\spiski_shindlerov.tgt`, there are 50 passing sentences (were 78 by regex)
# file is `2015\strakhovanie_vkladov_1.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `2015\strakhovanie_vkladov_2.tgt`, there are 6 passing sentences (were 9 by regex)
# file is `2015\velikaya_neftegazovaya.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `2016\chelovek_chitayushchii.tgt`, there are 10 passing sentences (were 13 by regex)
# file is `2016\gumanisticheskaya_pedagogika.tgt`, there are 29 passing sentences (were 54 by regex)
# file is `2016\migranty_ekspaty_kosmopolity.tgt`, there are 16 passing sentences (were 20 by regex)
# file is `2016\okna_zhizni.tgt`, there are 20 passing sentences (were 36 by regex)
# file is `2016\slovo_ne_to_chem_kazhetsya.tgt`, there are 28 passing sentences (were 39 by regex)
# file is `2016\tselina_glazami_pervokursnika.tgt`, there are 22 passing sentences (were 35 by regex)
# file is `2016\ugroza_ravnopraviem.tgt`, there are 7 passing sentences (were 17 by regex)
# file is `2016\v_chem_vinovat_putin.tgt`, there are 32 passing sentences (were 48 by regex)
# file is `2017\apresyan_1.tgt`, there are 12 passing sentences (were 20 by regex)
# file is `2017\chto_gubit_nauku.tgt`, there are 9 passing sentences (were 19 by regex)
# file is `2017\eltsin.tgt`, there are 24 passing sentences (were 33 by regex)
# file is `2017\gde_zhe_vykhod.tgt`, there are 48 passing sentences (were 75 by regex)
# file is `2017\kulturnaya_revolyutsiya.tgt`, there are 35 passing sentences (were 43 by regex)
# file is `2017\nad_sinaem.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `2017\poet_i_prezident.tgt`, there are 12 passing sentences (were 20 by regex)
# file is `2017\siriiskaya_lovushka.tgt`, there are 2 passing sentences (were 7 by regex)
# file is `2017\ubiistvo_pavla_sheremeta.tgt`, there are 8 passing sentences (were 12 by regex)
# file is `2017\vsevidyashchee_oko_armii.tgt`, there are 2 passing sentences (were 4 by regex)
# file is `2017\v_poiskakh_buntovshchikov.tgt`, there are 14 passing sentences (were 25 by regex)
# file is `2018\akademicheskii_schet.tgt`, there are 9 passing sentences (were 14 by regex)
# file is `2018\boris_titov_i_1000_advokatov.tgt`, there are 16 passing sentences (were 24 by regex)
# file is `2018\budet_chto_vspomnit.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `2018\byt_li_nam_vmeste.tgt`, there are 15 passing sentences (were 27 by regex)
# file is `2018\dissidenty.tgt`, there are 28 passing sentences (were 46 by regex)
# file is `2018\dvukhpartiinaya_rossiya.tgt`, there are 5 passing sentences (were 11 by regex)
# file is `2018\gorod-sad_singapur.tgt`, there are 7 passing sentences (were 16 by regex)
# file is `2018\interviyu_granina_raznykh_let.tgt`, there are 12 passing sentences (were 19 by regex)
# file is `2018\kto_za_trampa.tgt`, there are 19 passing sentences (were 27 by regex)
# file is `2018\legkoe_dykhanie.tgt`, there are 9 passing sentences (were 18 by regex)
# file is `2018\nachalo.tgt`, there are 66 passing sentences (were 80 by regex)
# file is `2018\novye_maiskie_ukazy.tgt`, there are 8 passing sentences (were 21 by regex)
# file is `2018\odnazhdy_v_taruse.tgt`, there are 11 passing sentences (were 17 by regex)
# file is `2018\pensionnyi_vozrast.tgt`, there are 1 passing sentences (were 3 by regex)
# file is `2018\pontii_pilat.tgt`, there are 88 passing sentences (were 139 by regex)
# file is `2018\poseshchenie_muzeya.tgt`, there are 25 passing sentences (were 51 by regex)
# file is `2018\puteshestvie_v_armeniyu.tgt`, there are 80 passing sentences (were 123 by regex)
# file is `2018\pyatichasovoi_skoryi.tgt`, there are 38 passing sentences (were 70 by regex)
# file is `2018\rech_zaliznyaka.tgt`, there are 19 passing sentences (were 19 by regex)
# file is `2018\roman_pak_u_granina.tgt`, there are 16 passing sentences (were 23 by regex)
# file is `2018\v_strane_mormonov.tgt`, there are 50 passing sentences (were 71 by regex)
# file is `2018\zvukovidy.tgt`, there are 20 passing sentences (were 34 by regex)
# file is `2019\baden-baden.tgt`, there are 15 passing sentences (were 32 by regex)
# file is `2019\dvadtsat_let_defoltu.tgt`, there are 12 passing sentences (were 23 by regex)
# file is `2019\interviyu_nazarova.tgt`, there are 17 passing sentences (were 27 by regex)
# file is `2019\kartinki_imperii.tgt`, there are 47 passing sentences (were 72 by regex)
# file is `2019\lingvistika_i_morzhevanie.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `2019\medvedev_ostanetsya_s_partiei.tgt`, there are 6 passing sentences (were 11 by regex)
# file is `2019\obraztsovyi_oppozitsionnyi_kandidat.tgt`, there are 34 passing sentences (were 53 by regex)
# file is `2019\ochen_affektnoe_ubiistvo.tgt`, there are 20 passing sentences (were 24 by regex)
# file is `2019\podkidysh.tgt`, there are 84 passing sentences (were 125 by regex)
# file is `2019\pokhozhdeniya_ryadovogo_podpisanta.tgt`, there are 18 passing sentences (were 29 by regex)
# file is `2019\poslednyaya_prosba.tgt`, there are 24 passing sentences (were 36 by regex)
# file is `2019\publichnye_meropriyatiya.tgt`, there are 23 passing sentences (were 26 by regex)
# file is `2019\rasstrel_v_kerchi.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `2019\reforma_ran.tgt`, there are 20 passing sentences (were 35 by regex)
# file is `2019\sekta_radikalnogo_feminizma.tgt`, there are 15 passing sentences (were 20 by regex)
# file is `2019\sotvori_sebe_bankira.tgt`, there are 20 passing sentences (were 35 by regex)
# file is `2019\vtoraya_mirovaya_voina.tgt`, there are 88 passing sentences (were 160 by regex)
# file is `2019\zanimatelnaya_estetika.tgt`, there are 46 passing sentences (were 77 by regex)
# file is `2019\znaet_li_ob_etom_vozhd.tgt`, there are 16 passing sentences (were 33 by regex)
# file is `2020_corpus2_0\chelovek_okazalsya_ne_nuzhen.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `2020_corpus2_0\fenomen_antichnosti.tgt`, there are 27 passing sentences (were 40 by regex)
# file is `2020_corpus2_0\gastronomicheskie_khroniki.tgt`, there are 63 passing sentences (were 100 by regex)
# file is `2020_corpus2_0\iz_zhizni_odnogo_ezha.tgt`, there are 31 passing sentences (were 52 by regex)
# file is `2020_corpus2_0\kakie_nashi_gody_1.tgt`, there are 75 passing sentences (were 122 by regex)
# file is `2020_corpus2_0\khochu_byt_negrom.tgt`, there are 28 passing sentences (were 35 by regex)
# file is `2020_corpus2_0\konets_ekonomicheskogo_rosta.tgt`, there are 20 passing sentences (were 30 by regex)
# file is `2020_corpus2_0\kto_nasledil.tgt`, there are 24 passing sentences (were 30 by regex)
# file is `2020_corpus2_0\malenkii_prints.tgt`, there are 84 passing sentences (were 137 by regex)
# file is `2020_corpus2_0\milaya_reptiliya.tgt`, there are 29 passing sentences (were 46 by regex)
# file is `2020_corpus2_0\muraviinyi_kosmos.tgt`, there are 39 passing sentences (were 50 by regex)
# file is `2020_corpus2_0\papa-yumorist.tgt`, there are 40 passing sentences (were 65 by regex)
# file is `2020_corpus2_0\parallelnyi_mir.tgt`, there are 28 passing sentences (were 47 by regex)
# file is `2020_corpus2_0\peredacha.tgt`, there are 33 passing sentences (were 56 by regex)
# file is `2020_corpus2_0\pisma_schastiya.tgt`, there are 31 passing sentences (were 43 by regex)
# file is `2020_corpus2_0\poslannik_iz_proshlogo.tgt`, there are 29 passing sentences (were 44 by regex)
# file is `2020_corpus2_0\velikoe_pereselenie.tgt`, there are 24 passing sentences (were 46 by regex)
# file is `2020_rffi\gryadet_li_apokalipsis.tgt`, there are 9 passing sentences (were 26 by regex)
# file is `2020_rffi\indoneziya_ot_ada_do_raya.tgt`, there are 53 passing sentences (were 97 by regex)
# file is `2020_rffi\instrument_yazyka_1.tgt`, there are 61 passing sentences (were 96 by regex)
# file is `2020_rffi\instrument_yazyka_2.tgt`, there are 80 passing sentences (were 118 by regex)
# file is `2020_rffi\moskva_2042.tgt`, there are 73 passing sentences (were 122 by regex)
# file is `2020_rffi\nyuta_federmesser.tgt`, there are 31 passing sentences (were 47 by regex)
# file is `2020_rffi\ognev.tgt`, there are 51 passing sentences (were 82 by regex)
# file is `2020_rffi\trudnosti_ponimaniya.tgt`, there are 31 passing sentences (were 65 by regex)
# file is `news\meinert-ranks.tgt`, there are 17 passing sentences (were 31 by regex)
# file is `news\panyushkin.tgt`, there are 6 passing sentences (were 13 by regex)
# file is `news\ya_01.tgt`, there are 8 passing sentences (were 13 by regex)
# file is `news\ya_02.tgt`, there are 5 passing sentences (were 11 by regex)
# file is `news\ya_03.tgt`, there are 6 passing sentences (were 11 by regex)
# file is `news\ya_04.tgt`, there are 2 passing sentences (were 6 by regex)
# file is `news\ya_05.tgt`, there are 2 passing sentences (were 7 by regex)
# file is `news\ya_06.tgt`, there are 5 passing sentences (were 12 by regex)
# file is `news\ya_09.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `news\ya_10.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `news\ya_11.tgt`, there are 3 passing sentences (were 4 by regex)
# file is `news\ya_12.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `news\ya_13.tgt`, there are 1 passing sentences (were 10 by regex)
# file is `news\ya_14.tgt`, there are 2 passing sentences (were 12 by regex)
# file is `news\ya_15.tgt`, there are 4 passing sentences (were 13 by regex)
# file is `news\ya_16.tgt`, there are 2 passing sentences (were 12 by regex)
# file is `news\ya_17.tgt`, there are 9 passing sentences (were 20 by regex)
# file is `news\ya_18.tgt`, there are 9 passing sentences (were 13 by regex)
# file is `news\ya_19.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `news\ya_20.tgt`, there are 6 passing sentences (were 9 by regex)
# file is `news\ya_21.tgt`, there are 2 passing sentences (were 8 by regex)
# file is `news\ya_22.tgt`, there are 15 passing sentences (were 16 by regex)
# file is `news\ya_23.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `news\ya_24.tgt`, there are 7 passing sentences (were 11 by regex)
# file is `news\ya_25.tgt`, there are 6 passing sentences (were 11 by regex)
# file is `news\ya_26.tgt`, there are 11 passing sentences (were 16 by regex)
# file is `news\ya_27.tgt`, there are 2 passing sentences (were 8 by regex)
# file is `news\ya_30.tgt`, there are 2 passing sentences (were 12 by regex)
# file is `news\ya_31.tgt`, there are 2 passing sentences (were 8 by regex)
# file is `news\ya_32.tgt`, there are 7 passing sentences (were 11 by regex)
# file is `news\ya_33.tgt`, there are 1 passing sentences (were 6 by regex)
# file is `news\ya_34.tgt`, there are 0 passing sentences (were 4 by regex)
# file is `news\ya_35.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `news\ya_36.tgt`, there are 7 passing sentences (were 11 by regex)
# file is `news\ya_37.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `news\ya_38.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `news\ya_39.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `news\ya_40.tgt`, there are 4 passing sentences (were 11 by regex)
# file is `news\ya_41.tgt`, there are 6 passing sentences (were 9 by regex)
# file is `news\ya_42.tgt`, there are 6 passing sentences (were 15 by regex)
# file is `news\ya_43.tgt`, there are 5 passing sentences (were 11 by regex)
# file is `news\ya_44.tgt`, there are 5 passing sentences (were 6 by regex)
# file is `news\ya_45.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `news\ya_46.tgt`, there are 1 passing sentences (were 2 by regex)
# file is `news\ya_47.tgt`, there are 0 passing sentences (were 4 by regex)
# file is `news\ya_48.tgt`, there are 4 passing sentences (were 8 by regex)
# file is `news\ya_49.tgt`, there are 6 passing sentences (were 9 by regex)
# file is `news\ya_50.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `news\ya_51.tgt`, there are 5 passing sentences (were 13 by regex)
# file is `news\ya_52.tgt`, there are 1 passing sentences (were 7 by regex)
# file is `news\ya_53.tgt`, there are 4 passing sentences (were 9 by regex)
# file is `news\ya_54.tgt`, there are 3 passing sentences (were 9 by regex)
# file is `news\ya_55.tgt`, there are 8 passing sentences (were 10 by regex)
# file is `news\ya_56.tgt`, there are 1 passing sentences (were 3 by regex)
# file is `news\ya_58.tgt`, there are 6 passing sentences (were 14 by regex)
# file is `news\ya_59.tgt`, there are 7 passing sentences (were 11 by regex)
# file is `news\ya_60.tgt`, there are 8 passing sentences (were 16 by regex)
# file is `news\ya_70.tgt`, there are 4 passing sentences (were 16 by regex)
# file is `news\ya_72.tgt`, there are 10 passing sentences (were 17 by regex)
# file is `news\ya_73.tgt`, there are 2 passing sentences (were 9 by regex)
# file is `news\ya_74.tgt`, there are 7 passing sentences (were 11 by regex)
# file is `news\ya_75.tgt`, there are 14 passing sentences (were 21 by regex)
# file is `news\ya_76.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `news\ya_77.tgt`, there are 3 passing sentences (were 4 by regex)
# file is `news\ya_78.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `news\ya_79.tgt`, there are 6 passing sentences (were 17 by regex)
# file is `news\ya_90.tgt`, there are 5 passing sentences (were 12 by regex)
# file is `news\ya_91.tgt`, there are 0 passing sentences (were 0 by regex)
# file is `news\ya_92.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `news\ya_93.tgt`, there are 10 passing sentences (were 21 by regex)
# file is `news\ya_94.tgt`, there are 7 passing sentences (were 10 by regex)
# file is `news\ya_96.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `news\ya_97.tgt`, there are 6 passing sentences (were 9 by regex)
# file is `uppsala\bitov_1.tgt`, there are 37 passing sentences (were 66 by regex)
# file is `uppsala\bitov_2.tgt`, there are 28 passing sentences (were 54 by regex)
# file is `uppsala\bitov_3.tgt`, there are 37 passing sentences (were 53 by regex)
# file is `uppsala\grekova_1.tgt`, there are 29 passing sentences (were 42 by regex)
# file is `uppsala\grekova_2.tgt`, there are 45 passing sentences (were 68 by regex)
# file is `uppsala\grekova_3.tgt`, there are 32 passing sentences (were 54 by regex)
# file is `uppsala\korp_210.tgt`, there are 22 passing sentences (were 34 by regex)
# file is `uppsala\korp_220.tgt`, there are 12 passing sentences (were 25 by regex)
# file is `uppsala\korp_230.tgt`, there are 3 passing sentences (were 3 by regex)
# file is `uppsala\korp_240.tgt`, there are 22 passing sentences (were 37 by regex)
# file is `uppsala\korp_250.tgt`, there are 5 passing sentences (were 12 by regex)
# file is `uppsala\korp_261.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `uppsala\korp_262.tgt`, there are 3 passing sentences (were 4 by regex)
# file is `uppsala\korp_263.tgt`, there are 3 passing sentences (were 5 by regex)
# file is `uppsala\korp_264.tgt`, there are 7 passing sentences (were 12 by regex)
# file is `uppsala\korp_265.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `uppsala\korp_266.tgt`, there are 8 passing sentences (were 13 by regex)
# file is `uppsala\korp_409.tgt`, there are 5 passing sentences (were 9 by regex)
# file is `uppsala\korp_601.tgt`, there are 5 passing sentences (were 14 by regex)
# file is `uppsala\korp_602.tgt`, there are 6 passing sentences (were 14 by regex)
# file is `uppsala\korp_603.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `uppsala\korp_604.tgt`, there are 2 passing sentences (were 9 by regex)
# file is `uppsala\korp_605.tgt`, there are 2 passing sentences (were 2 by regex)
# file is `uppsala\korp_606.tgt`, there are 11 passing sentences (were 13 by regex)
# file is `uppsala\korp_607.tgt`, there are 5 passing sentences (were 8 by regex)
# file is `uppsala\korp_608.tgt`, there are 2 passing sentences (were 3 by regex)
# file is `uppsala\korp_609.tgt`, there are 8 passing sentences (were 10 by regex)
# file is `uppsala\korp_610.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `uppsala\korp_611.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `uppsala\korp_612.tgt`, there are 4 passing sentences (were 11 by regex)
# file is `uppsala\korp_613.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `uppsala\korp_614.tgt`, there are 4 passing sentences (were 10 by regex)
# file is `uppsala\korp_615.tgt`, there are 8 passing sentences (were 11 by regex)
# file is `uppsala\korp_616.tgt`, there are 11 passing sentences (were 14 by regex)
# file is `uppsala\korp_617.tgt`, there are 2 passing sentences (were 8 by regex)
# file is `uppsala\korp_618.tgt`, there are 10 passing sentences (were 21 by regex)
# file is `uppsala\korp_619.tgt`, there are 18 passing sentences (were 25 by regex)
# file is `uppsala\korp_620.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `uppsala\korp_621.tgt`, there are 20 passing sentences (were 28 by regex)
# file is `uppsala\korp_622.tgt`, there are 13 passing sentences (were 18 by regex)
# file is `uppsala\korp_623.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `uppsala\korp_624.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `uppsala\korp_625.tgt`, there are 2 passing sentences (were 3 by regex)
# file is `uppsala\korp_626.tgt`, there are 0 passing sentences (were 3 by regex)
# file is `uppsala\korp_627.tgt`, there are 14 passing sentences (were 18 by regex)
# file is `uppsala\korp_628.tgt`, there are 1 passing sentences (were 3 by regex)
# file is `uppsala\korp_701.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `uppsala\korp_702.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `uppsala\korp_703.tgt`, there are 3 passing sentences (were 6 by regex)
# file is `uppsala\korp_704.tgt`, there are 3 passing sentences (were 9 by regex)
# file is `uppsala\korp_705.tgt`, there are 2 passing sentences (were 10 by regex)
# file is `uppsala\korp_706.tgt`, there are 3 passing sentences (were 8 by regex)
# file is `uppsala\korp_707.tgt`, there are 1 passing sentences (were 4 by regex)
# file is `uppsala\korp_708.tgt`, there are 9 passing sentences (were 10 by regex)
# file is `uppsala\korp_709.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `uppsala\korp_710.tgt`, there are 4 passing sentences (were 8 by regex)
# file is `uppsala\korp_711.tgt`, there are 9 passing sentences (were 10 by regex)
# file is `uppsala\korp_712.tgt`, there are 6 passing sentences (were 12 by regex)
# file is `uppsala\korp_713.tgt`, there are 10 passing sentences (were 10 by regex)
# file is `uppsala\korp_714.tgt`, there are 5 passing sentences (were 10 by regex)
# file is `uppsala\korp_716.tgt`, there are 5 passing sentences (were 7 by regex)
# file is `uppsala\korp_717.tgt`, there are 8 passing sentences (were 9 by regex)
# file is `uppsala\korp_718.tgt`, there are 5 passing sentences (were 7 by regex)
# file is `uppsala\korp_719.tgt`, there are 2 passing sentences (were 6 by regex)
# file is `uppsala\korp_720.tgt`, there are 4 passing sentences (were 6 by regex)
# file is `uppsala\korp_721.tgt`, there are 6 passing sentences (were 7 by regex)
# file is `uppsala\korp_722.tgt`, there are 3 passing sentences (were 7 by regex)
# file is `uppsala\korp_723.tgt`, there are 4 passing sentences (were 7 by regex)
# file is `uppsala\korp_724.tgt`, there are 7 passing sentences (were 9 by regex)
# file is `uppsala\korp_725.tgt`, there are 8 passing sentences (were 9 by regex)
# file is `uppsala\korp_726.tgt`, there are 15 passing sentences (were 19 by regex)
# file is `uppsala\nagibin_1.tgt`, there are 36 passing sentences (were 69 by regex)
# file is `uppsala\nagibin_2.tgt`, there are 36 passing sentences (were 49 by regex)
# file is `uppsala\nagibin_3.tgt`, there are 12 passing sentences (were 15 by regex)
# file is `uppsala\nagibin_4.tgt`, there are 14 passing sentences (were 19 by regex)
#
# passing 9612 among 15697 found by regex
# Wall time: 2min 45s

# %%
def cast_bool_cols_to_int(df: pd.DataFrame) -> pd.DataFrame:
    subword_bool_cols_to_int = ['has', 'is']
    pat_bool_cols_to_int = [rf'(\b|_){sub}(\b|_)' for sub in subword_bool_cols_to_int]

    for colname in df.columns:
        if any(re.search(pat, colname) for pat in pat_bool_cols_to_int):
            df.loc[:, colname] = df[colname].astype(int)

# %%
cast_bool_cols_to_int(corpus_base)

corpus = corpus_base.rename_axis('file_idx').reset_index()
corpus.loc[:, 'full_analysis'] = corpus['full_analysis'].str.replace('\n', ' | ')

# %%
path = Path('./syntagrus/result/syntagrus_6_1+context.csv')
path.parent.mkdir(parents=True, exist_ok=True)

#ID!
corpus.to_csv(path, decimal=',')

# %%
# ### ТОЛЬКО НОВЫЕ КОЛОНКИ

# upd_cols = ['file_idx', 'source'] + NEW_COLS
# corpus_upd = corpus[upd_cols]
# corpus_upd.loc[:, 'file_source_idx'] = corpus_upd.apply(lambda row: f'{row.file_idx}_{row.source}', axis=1)

# %%
# path = Path('./syntagrus/result/syntagrus_4_newonly.csv')
# path.parent.mkdir(parents=True, exist_ok=True)
# corpus_upd.to_csv(path)

# %%
corpus[corpus['DO_has_relcl']==1]
# Out:
#       file_idx                          source sent_num_file  \
# 22           0         2003/artist_mimansa.tgt             4
# 42          20         2003/artist_mimansa.tgt           237
# 55          33         2003/artist_mimansa.tgt           368
# 64           2  2003/atlanty_i_atlantologi.tgt            33
# 68           6  2003/atlanty_i_atlantologi.tgt            54
# ...        ...                             ...           ...
# 9508         9            uppsala/korp_726.tgt            35
# 9519         5           uppsala/nagibin_1.tgt            46
# 9549        35           uppsala/nagibin_1.tgt           270
# 9552         2           uppsala/nagibin_2.tgt            15
# 9555         5           uppsala/nagibin_2.tgt            31
#
#                                            left_context  \
# 22    Это случилось вечером, в третьем акте. Илью Ил...
# 42    От такого кошмара у Ильи Ильича выступила испа...
# 55    Еще двое вышли, но один вошел… Один вышел, ост...
# 64    В мае 2001 года в заливе Гуанаакабибес, на зап...
# 68    Ищут следы Атлантиды не только в Западном полу...
# ...                                                 ...
# 9508  Следовательно, наши предки на Волыни и в Галич...
# 9519  Он вернулся, вернулся сам, не дождавшись меня,...
# 9549  Но почему же началось это с Тенненбаума, котор...
# 9552  Все знали, что оно будет, это наступление, и ч...
# 9555  Жена все приняла на себя. В трудную минуту жиз...
#
#                                                    text  \
# 22    Будучи одет в малиновую ливрею с галунами, бел...
# 42    Он пересиливал себя, вставал и ходил по комнат...
# 55    Уж совсем было освободился директор - и тут на...
# 64    При горизонтальном сканировании глубоководные ...
# 68    Так, в 1973 году американская подводная лодка ...
# ...                                                 ...
# 9508  Святой равноапостольный князь Владимир Великий...
# 9519  - Обедать!.. - послышался голос мамы, и, груст...
# 9549  Очень сильная, очень настоящая любовь делает п...
# 9552  Ради этого младший лейтенант Павлов скрывал от...
# 9555  С непостижимой быстротой и неприметной затрато...
#
#                                           right_context  \
# 22    Он мирно стоял с подносом в кулисе № 2, ожидая...
# 42    И все это было так ужасно, просто конец света....
# 55    Гости ушли через час, когда приемная уже ломил...
# 64    Руководитель экспедиции Полина Зелицкая заявил...
# 68    Американскому правительству было тотчас доложе...
# ...                                                 ...
# 9508  Следовательно, и духовная власть упомянутого в...
# 9519  Путешествие так и не состоялось. Но зато сколь...
# 9549  Вопреки очевидности, я где-то на дне души не в...
# 9552  Он был преступно недальновиден: думал, что рас...
# 9555  Возле поселка находился санаторий, там шло стр...
#
#                                           full_analysis  \
# 22    <S ID="4"> | <W DOM="17" FEAT="V НЕСОВ ДЕЕПР Н...
# 42    <S ID="237"> | <W DOM="2" FEAT="S ЕД МУЖ ИМ ОД...
# 55    <S ID="368"> | <W DOM="4" FEAT="PART" ID="1" K...
# 64    <S ID="33"> | <W DOM="6" FEAT="PR" ID="1" KSNA...
# 68    <S ID="54"> | <W DOM="9" FEAT="ADV" ID="1" LEM...
# ...                                                 ...
# 9508  <S ID="35"> | <W DOM="3" FEAT="A ЕД МУЖ ИМ" ID...
# 9519  <S ID="46"> | - <W DOM="2" FEAT="V НЕСОВ ИНФ" ...
# 9549  <S ID="270"> | <W DOM="2" FEAT="ADV" ID="1" LE...
# 9552  <S ID="15"> | <W DOM="6" FEAT="PR" ID="1" LEMM...
# 9555  <S ID="31"> | <W DOM="8" FEAT="PR" ID="1" KSNA...
#
#                                          sent_pos_chain  has_many_dos  \
# 22    V V PR A S PR S A S CONJ S PR S S S V V V PR S...             0
# 42    PRON V PRON V CONJ V PR S V PR S ADV V PRON S ...             0
# 55    PART ADV PRON V S CONJ ADV V S A PR S PR S PR ...             0
# 64    PR A S A S V PR S S A A S A PR A S PR ADV A CO...             0
# 68                ADV PR NUM S A A S ADV V PR S S S V S             0
# ...                                                 ...           ...
# 9508  A A S S A V S PR S PRON S S PRON V PART PART S...             0
# 9519  V V S S CONJ ADV V S PRON ADV V PR V S PR A S ...             0
# 9549  ADV A ADV A S V S PRON S PART PRON A PRON V PR...             0
# 9552    PR PRON A S S V PR PRON CONJ PR PRON S V PRON S             0
# 9555  PR A S CONJ A S S V PRON PR NUM S PR S S PR S ...             0
#
#       has_many_ios  ...  DO_number          IO IO_pos   IO_head  IO_head_pos  \
# 22               0  ...         мн   балеринам      S   раздать            V
# 42               0  ...         ед      одеяло      S       под           PR
# 55               0  ...         ед     кабинет      S         в           PR
# 64               0  ...         ед         дне      S        на           PR
# 68               0  ...         мн     берегов      S         у           PR
# ...            ...  ...        ...         ...    ...       ...          ...
# 9508             0  ...         ед      князем      S  назначил            V
# 9519             0  ...         ед    взглядом      S    окинув            V
# 9549             0  ...         ед   провидцем      S    делает            V
# 9552             0  ...         ед        себя   PRON        от           PR
# 9555             0  ...         ед  километрах      S         в           PR
#
#       IO_lemma IO_animacy  IO_case  IO_number    order
# 22    балерина         од      дат         мн  V IO DO
# 42      одеяло       неод      вин         ед  V IO DO
# 55     кабинет       неод      вин         ед  V IO DO
# 64         дно       неод       пр         ед  V IO DO
# 68       берег       неод      род         мн  V IO DO
# ...        ...        ...      ...        ...      ...
# 9508     князь         од     твор         ед  V IO DO
# 9519    взгляд       неод     твор         ед  V IO DO
# 9549  провидец         од     твор         ед  V IO DO
# 9552      себя         од      род         ед  V IO DO
# 9555  километр       неод       пр         мн  V IO DO
#
# [732 rows x 44 columns]

# %%
corp = pd.read_csv('./syntagrus/result/syntagrus.csv')
